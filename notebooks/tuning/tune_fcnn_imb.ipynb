# %% [markdown]
# # Tuning the FCNN classifier
#
# Hyperparameter sweep for the **fully connected neural network classifier** for producing results with various **degrees of dataset imbalance**. Optimize the hyperparameters for the worst-case imbalance configuration. Optimization conducted by means of the tree-structured Parzen estimator.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import copy

# %%
# Sci-kit learn for machine learning tasks
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer

# %%
# TensorFlow and Keras for neural networks
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras import layers
from keras.regularizers import l2
from keras import metrics
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# HyperOptfor Bayesian optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
import sys

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# ## Load and process data

# %%
# Load training set
train_set_file  = "train_set_imb_0.csv"
train_set = pd.read_csv(train_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])

# %%
# Tokenize texts and get features
max_words = 5000
max_len = 55
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts_train)
sequences_train = tokenizer.texts_to_sequences(texts_train)
features_train = sequence.pad_sequences(sequences_train, maxlen=max_len, padding='post', truncating='post')

# %% [markdown]
# ## Define hyperparameter search space and objective function

# %%
# Define the search space for hyperparameterss
hyperparam_space = {'n_units': scope.int(hp.quniform('n_units', 32, 256, q=1)),
                    'dropout_rate': hp.uniform('dropout_rate', 0.25, 0.75),
                    'l2_val': hp.loguniform('l2_val', np.log(1e-6), np.log(1e-3)),
                    'embedding_dim' : scope.int(hp.quniform('embedding_dim', 64, 256, q=1)),
                    'max_words' : max_words,
                    'max_len' : max_len,
                    'batch_size' : scope.int(hp.quniform('batch_size', 16, 128, q=1)),
                    'epochs' : scope.int(hp.quniform('epochs', 16, 128, q=1)),
                    'learning_rate': hp.loguniform('learning_rate', np.log(1e-7), np.log(1e-4))
                    }

# %%
# Define the objective function for optimization
def objective(params):   
    print ('Params testing: ', params)

    # Split dataset into training validation sets
    inp_train, inp_valid, lbl_train, lbl_valid = train_test_split(features_train, labels_train, 
                                                                  test_size=0.15, 
                                                                  random_state=12345, 
                                                                  stratify=labels_train)
    
    # Compute class weights for compensation the imbalance in classes
    class_weights = class_weight.compute_class_weight(class_weight = "balanced",
                                        classes = np.unique(lbl_train),
                                        y = lbl_train)
    class_weights = dict(zip(np.unique(lbl_train), class_weights))

    # Define optimizer
    opt = Adam(learning_rate=params['learning_rate'], 
                   beta_1 = 0.9,
                   beta_2 = 0.99,
                   epsilon = 1e-07,
                   amsgrad = False)

    # Define sequential neural arhitecture
    model = Sequential()
    model.add(layers.Embedding(params['max_words'], params['embedding_dim'], input_length=params['max_len']))
    model.add(layers.Dropout(params['dropout_rate']))
    model.add(layers.Dense(units=params['n_units'], input_dim=params['embedding_dim'], kernel_initializer='glorot_uniform', activation='relu', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))
    model.add(layers.Flatten())
    model.add(layers.Dense(1, input_dim=params['n_units'], kernel_initializer='glorot_uniform', activation='sigmoid', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))

    # Build model
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=[metrics.AUC(name='auc_pr', curve="PR")])
    #model.summary()

    # Fit model
    model.fit(inp_train, lbl_train, epochs=params['epochs'], batch_size=params['batch_size'], verbose = 0, class_weight=class_weights)

    # Compute performance of the trial
    pred_scores = (model.predict(inp_valid) > 0.5).astype("int32")
    f1 = f1_score(lbl_valid, pred_scores)
    print('DONE!      F1 = ' + str(f1))
    sys.stdout.flush() 
    return {'loss': -f1, 'status': STATUS_OK}

# %% [markdown]
# ## Run Bayesian optimization with Tree Parzen Estimator

# %%
trials = Trials()
best = fmin(objective, hyperparam_space, algo=tpe.suggest, max_evals=500, trials=trials)
print('Best hyperparams: ', best)
# Out:
# Params testing:
# {'batch_size': 126, 'dropout_rate': 0.6102470844512687, 'embedding_dim': 243, 'epochs': 82, 'l2_val': 0.00032461372323497827, 'learning_rate': 7.823001434529953e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 50}
# DONE!      F1 = 0.1309255079006772
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.5186404691233188, 'embedding_dim': 195, 'epochs': 60, 'l2_val': 8.541741490635707e-05, 'learning_rate': 2.704321334155036e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 238}
# DONE!      F1 = 0.5806451612903226
# Params testing:
# {'batch_size': 79, 'dropout_rate': 0.27666944158900775, 'embedding_dim': 120, 'epochs': 82, 'l2_val': 0.0004454906000006143, 'learning_rate': 2.31703277695321e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 145}
# DONE!      F1 = 0.5413533834586467
# Params testing:
# {'batch_size': 66, 'dropout_rate': 0.5280621112111963, 'embedding_dim': 130, 'epochs': 51, 'l2_val': 1.4799040165944676e-06, 'learning_rate': 5.17236381566811e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 92}
# DONE!      F1 = 0.5967741935483871
# Params testing:
# {'batch_size': 89, 'dropout_rate': 0.3685656015212512, 'embedding_dim': 254, 'epochs': 38, 'l2_val': 0.0005847786443051598, 'learning_rate': 2.0415089243886134e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 232}
# DONE!      F1 = 0.0
# Params testing:
# {'batch_size': 94, 'dropout_rate': 0.3942632396263825, 'embedding_dim': 238, 'epochs': 18, 'l2_val': 5.978779728581495e-06, 'learning_rate': 1.436532000263818e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 160}
# DONE!      F1 = 0.1415929203539823
# Params testing:
# {'batch_size': 99, 'dropout_rate': 0.3557792326558055, 'embedding_dim': 227, 'epochs': 46, 'l2_val': 7.156605608016667e-06, 'learning_rate': 8.377727562837023e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 187}
# DONE!      F1 = 0.09160305343511449
# Params testing:
# {'batch_size': 92, 'dropout_rate': 0.29639543266060314, 'embedding_dim': 107, 'epochs': 87, 'l2_val': 2.7719579977609218e-06, 'learning_rate': 1.3125324439870134e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 248}
# DONE!      F1 = 0.41975308641975306
# Params testing:
# {'batch_size': 104, 'dropout_rate': 0.42792444504604193, 'embedding_dim': 150, 'epochs': 108, 'l2_val': 4.081635669670359e-06, 'learning_rate': 4.444798894068076e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 68}
# DONE!      F1 = 0.13246753246753246
# Params testing:
# {'batch_size': 109, 'dropout_rate': 0.7306325119774989, 'embedding_dim': 183, 'epochs': 76, 'l2_val': 5.887171327964676e-06, 'learning_rate': 2.449894566046034e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 73}
# DONE!      F1 = 0.0303030303030303
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.5211958781204666, 'embedding_dim': 127, 'epochs': 110, 'l2_val': 0.0002975647638190152, 'learning_rate': 2.258031102374031e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 194}
# DONE!      F1 = 0.15000000000000002
# Params testing:
# {'batch_size': 39, 'dropout_rate': 0.45175124311303994, 'embedding_dim': 103, 'epochs': 21, 'l2_val': 0.00016872898102266782, 'learning_rate': 7.348108143877859e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 199}
# DONE!      F1 = 0.13229571984435795
# Params testing:
# {'batch_size': 50, 'dropout_rate': 0.6103427375915228, 'embedding_dim': 225, 'epochs': 54, 'l2_val': 0.0004795531055045654, 'learning_rate': 8.688908801394775e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 194}
# DONE!      F1 = 0.616822429906542
# Params testing:
# {'batch_size': 34, 'dropout_rate': 0.5994916286363383, 'embedding_dim': 105, 'epochs': 53, 'l2_val': 1.3000460862535235e-06, 'learning_rate': 6.961607154414683e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 249}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'batch_size': 24, 'dropout_rate': 0.558628050909842, 'embedding_dim': 116, 'epochs': 80, 'l2_val': 9.500338421437785e-05, 'learning_rate': 1.6248072949723638e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 165}
# DONE!      F1 = 0.2206896551724138
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.702122443357795, 'embedding_dim': 113, 'epochs': 117, 'l2_val': 1.034824972885896e-05, 'learning_rate': 3.0184004911781045e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 132}
# DONE!      F1 = 0.136986301369863
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.5533717820438533, 'embedding_dim': 216, 'epochs': 17, 'l2_val': 0.0002876450585161937, 'learning_rate': 9.88117649583848e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 200}
# DONE!      F1 = 0.15277777777777776
# Params testing:
# {'batch_size': 20, 'dropout_rate': 0.3246417795493376, 'embedding_dim': 83, 'epochs': 54, 'l2_val': 2.1260745595494212e-05, 'learning_rate': 3.0753359974659146e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 132}
# DONE!      F1 = 0.5555555555555555
# Params testing:
# {'batch_size': 54, 'dropout_rate': 0.578703820293373, 'embedding_dim': 191, 'epochs': 90, 'l2_val': 0.0001107848746009204, 'learning_rate': 7.513421784229591e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 87}
# DONE!      F1 = 0.12322274881516586
# Params testing:
# {'batch_size': 104, 'dropout_rate': 0.2944324510037271, 'embedding_dim': 113, 'epochs': 48, 'l2_val': 5.882348686687289e-06, 'learning_rate': 3.843474915516228e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 226}
# DONE!      F1 = 0.5413533834586467
# Params testing:
# {'batch_size': 44, 'dropout_rate': 0.6529950673852788, 'embedding_dim': 160, 'epochs': 33, 'l2_val': 4.571579580481156e-05, 'learning_rate': 8.886051952194676e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 253}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.683407670672521, 'embedding_dim': 64, 'epochs': 33, 'l2_val': 4.15823628640344e-05, 'learning_rate': 9.703042611859387e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 255}
# DONE!      F1 = 0.5982905982905983
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.6570585837958014, 'embedding_dim': 171, 'epochs': 67, 'l2_val': 2.1197459254288133e-05, 'learning_rate': 5.950338742736336e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 220}
# DONE!      F1 = 0.21476510067114093
# Params testing:
# {'batch_size': 48, 'dropout_rate': 0.6364328396025869, 'embedding_dim': 148, 'epochs': 35, 'l2_val': 4.505620209823525e-05, 'learning_rate': 7.101915895596305e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 254}
# DONE!      F1 = 0.6306306306306306
# Params testing:
# {'batch_size': 30, 'dropout_rate': 0.46797032280319795, 'embedding_dim': 78, 'epochs': 28, 'l2_val': 1.1133237208066802e-06, 'learning_rate': 5.97877939087898e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 219}
# DONE!      F1 = 0.20134228187919465
# Params testing:
# {'batch_size': 76, 'dropout_rate': 0.7488928072841662, 'embedding_dim': 148, 'epochs': 41, 'l2_val': 1.775330581640336e-05, 'learning_rate': 5.3992989077926793e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 109}
# DONE!      F1 = 0.5076923076923077
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.6155511870511596, 'embedding_dim': 90, 'epochs': 63, 'l2_val': 2.524480486649492e-06, 'learning_rate': 1.445333288805784e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 178}
# DONE!      F1 = 0.23333333333333334
# Params testing:
# {'batch_size': 18, 'dropout_rate': 0.4859831457839484, 'embedding_dim': 138, 'epochs': 98, 'l2_val': 0.0009265763505227155, 'learning_rate': 4.433110116289545e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 213}
# DONE!      F1 = 0.302158273381295
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.636312984251505, 'embedding_dim': 96, 'epochs': 69, 'l2_val': 5.946693045791181e-05, 'learning_rate': 5.406123298566124e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 39}
# DONE!      F1 = 0.578125
# Params testing:
# {'batch_size': 47, 'dropout_rate': 0.5820516981633489, 'embedding_dim': 66, 'epochs': 30, 'l2_val': 1.4143299701719786e-05, 'learning_rate': 1.8071450425438406e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 242}
# DONE!      F1 = 0.1565217391304348
# Params testing:
# {'batch_size': 122, 'dropout_rate': 0.7005254534396526, 'embedding_dim': 172, 'epochs': 62, 'l2_val': 0.0001959522401832765, 'learning_rate': 8.727120029897008e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 210}
# DONE!      F1 = 0.14736842105263157
# Params testing:
# {'batch_size': 32, 'dropout_rate': 0.5849656697681519, 'embedding_dim': 142, 'epochs': 24, 'l2_val': 3.0826636912573605e-05, 'learning_rate': 2.267113947421671e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 256}
# DONE!      F1 = 0.2535211267605634
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.7467628707571216, 'embedding_dim': 161, 'epochs': 57, 'l2_val': 6.265914429944386e-05, 'learning_rate': 5.8689433529212224e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 235}
# DONE!      F1 = 0.5892857142857143
# Params testing:
# {'batch_size': 58, 'dropout_rate': 0.5008471968832047, 'embedding_dim': 200, 'epochs': 39, 'l2_val': 1.833816513620734e-06, 'learning_rate': 3.386476339791395e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 164}
# DONE!      F1 = 0.49315068493150693
# Params testing:
# {'batch_size': 68, 'dropout_rate': 0.669149197028921, 'embedding_dim': 126, 'epochs': 45, 'l2_val': 3.0738077906030256e-05, 'learning_rate': 3.2925448054349472e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 177}
# DONE!      F1 = 0.0303030303030303
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.542288332195124, 'embedding_dim': 80, 'epochs': 71, 'l2_val': 1.0297934365618004e-05, 'learning_rate': 9.704977632614852e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 142}
# DONE!      F1 = 0.6199999999999999
# Params testing:
# {'batch_size': 81, 'dropout_rate': 0.6320485730170747, 'embedding_dim': 138, 'epochs': 42, 'l2_val': 1.0566156218510508e-06, 'learning_rate': 1.6220738263853458e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 111}
# DONE!      F1 = 0.08284023668639054
# Params testing:
# {'batch_size': 41, 'dropout_rate': 0.6932200376702352, 'embedding_dim': 102, 'epochs': 36, 'l2_val': 0.0001615220740281464, 'learning_rate': 2.1778453543769063e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 243}
# DONE!      F1 = 0.2131147540983607
# Params testing:
# {'batch_size': 62, 'dropout_rate': 0.4151226820770704, 'embedding_dim': 207, 'epochs': 27, 'l2_val': 4.149940836061742e-06, 'learning_rate': 6.956179801889299e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 178}
# DONE!      F1 = 0.5625
# Params testing:
# {'batch_size': 33, 'dropout_rate': 0.5871090380391536, 'embedding_dim': 178, 'epochs': 50, 'l2_val': 0.00011903195312423941, 'learning_rate': 1.0238610682507396e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 231}
# DONE!      F1 = 0.14958448753462603
# Params testing:
# {'batch_size': 50, 'dropout_rate': 0.7279222414755343, 'embedding_dim': 129, 'epochs': 88, 'l2_val': 1.1138331626264924e-05, 'learning_rate': 4.0247430300771946e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 56}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'batch_size': 24, 'dropout_rate': 0.2558311494949237, 'embedding_dim': 255, 'epochs': 16, 'l2_val': 6.41564135055277e-05, 'learning_rate': 9.507328787021403e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 150}
# DONE!      F1 = 0.24
# Params testing:
# {'batch_size': 18, 'dropout_rate': 0.5092181653271727, 'embedding_dim': 153, 'epochs': 75, 'l2_val': 0.0007271612750553213, 'learning_rate': 1.62899280464638e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 205}
# DONE!      F1 = 0.5671641791044777
# Params testing:
# {'batch_size': 119, 'dropout_rate': 0.4397610760944801, 'embedding_dim': 120, 'epochs': 59, 'l2_val': 3.0397811995829177e-06, 'learning_rate': 1.080878015773803e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 185}
# DONE!      F1 = 0.13247172859450726
# Params testing:
# {'batch_size': 24, 'dropout_rate': 0.5298720494229927, 'embedding_dim': 93, 'epochs': 97, 'l2_val': 1.7179869951470132e-06, 'learning_rate': 7.148688220027185e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 243}
# DONE!      F1 = 0.5789473684210527
# Params testing:
# {'batch_size': 57, 'dropout_rate': 0.7188690591179718, 'embedding_dim': 72, 'epochs': 127, 'l2_val': 7.770981614314003e-06, 'learning_rate': 4.461054836592445e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 114}
# DONE!      F1 = 0.15151515151515152
# Params testing:
# {'batch_size': 84, 'dropout_rate': 0.3891876670330757, 'embedding_dim': 110, 'epochs': 23, 'l2_val': 0.00041944340845356625, 'learning_rate': 2.5637072604291545e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 226}
# DONE!      F1 = 0.1818181818181818
# Params testing:
# {'batch_size': 51, 'dropout_rate': 0.604885646940773, 'embedding_dim': 166, 'epochs': 54, 'l2_val': 0.00021684341873657104, 'learning_rate': 4.337106769277099e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 155}
# DONE!      F1 = 0.5833333333333334
# Params testing:
# {'batch_size': 35, 'dropout_rate': 0.5623264091683501, 'embedding_dim': 240, 'epochs': 83, 'l2_val': 8.613517497851657e-05, 'learning_rate': 6.8044020525600496e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 250}
# DONE!      F1 = 0.2926829268292682
# Params testing:
# {'batch_size': 45, 'dropout_rate': 0.4706126348336526, 'embedding_dim': 186, 'epochs': 66, 'l2_val': 2.6216127846084726e-05, 'learning_rate': 2.3306641621820793e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 90}
# DONE!      F1 = 0.11320754716981131
# Params testing:
# {'batch_size': 75, 'dropout_rate': 0.6281746122162047, 'embedding_dim': 150, 'epochs': 45, 'l2_val': 4.383055256847521e-06, 'learning_rate': 1.2210795867948562e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 32}
# DONE!      F1 = 0.19672131147540983
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.6776352407823937, 'embedding_dim': 120, 'epochs': 20, 'l2_val': 3.9965004485349423e-05, 'learning_rate': 3.3587820963426183e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 121}
# DONE!      F1 = 0.1616161616161616
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.6525526455605494, 'embedding_dim': 134, 'epochs': 78, 'l2_val': 0.0001315499273068363, 'learning_rate': 7.354522238921645e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 192}
# DONE!      F1 = 0.5961538461538461
# Params testing:
# {'batch_size': 41, 'dropout_rate': 0.6038048098915287, 'embedding_dim': 232, 'epochs': 51, 'l2_val': 1.6932632693168083e-05, 'learning_rate': 2.9274122429348046e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 97}
# DONE!      F1 = 0.556390977443609
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.5315560556715206, 'embedding_dim': 99, 'epochs': 36, 'l2_val': 7.514164528958906e-06, 'learning_rate': 1.579149025542741e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 169}
# DONE!      F1 = 0.15412844036697249
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.712873829041041, 'embedding_dim': 200, 'epochs': 33, 'l2_val': 0.00024275685187244355, 'learning_rate': 4.915106066047511e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 71}
# DONE!      F1 = 0.09473684210526316
# Params testing:
# {'batch_size': 16, 'dropout_rate': 0.3659134885748222, 'embedding_dim': 216, 'epochs': 73, 'l2_val': 0.00033332971756981487, 'learning_rate': 4.6065150718853847e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 218}
# DONE!      F1 = 0.16666666666666669
# Params testing:
# {'batch_size': 21, 'dropout_rate': 0.3359094011849363, 'embedding_dim': 84, 'epochs': 106, 'l2_val': 2.311825232880793e-06, 'learning_rate': 1.9085077561423617e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 205}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 100, 'dropout_rate': 0.5591536291620306, 'embedding_dim': 108, 'epochs': 83, 'l2_val': 5.1610885330738505e-05, 'learning_rate': 1.242832359511695e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 134}
# DONE!      F1 = 0.24637681159420288
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.4793857175263739, 'embedding_dim': 145, 'epochs': 56, 'l2_val': 7.593652386113244e-05, 'learning_rate': 4.746505850751931e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 226}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 112, 'dropout_rate': 0.45343961286791207, 'embedding_dim': 154, 'epochs': 128, 'l2_val': 3.219313390675667e-06, 'learning_rate': 2.397366920384651e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 60}
# DONE!      F1 = 0.1966101694915254
# Params testing:
# {'batch_size': 29, 'dropout_rate': 0.6428606233267613, 'embedding_dim': 180, 'epochs': 65, 'l2_val': 5.4519198786466755e-06, 'learning_rate': 1.2509427115887944e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 255}
# DONE!      F1 = 0.09523809523809523
# Params testing:
# {'batch_size': 48, 'dropout_rate': 0.5728901822734713, 'embedding_dim': 90, 'epochs': 94, 'l2_val': 1.435072648184787e-06, 'learning_rate': 3.1828877742469406e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 236}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 36, 'dropout_rate': 0.7376631494395469, 'embedding_dim': 123, 'epochs': 42, 'l2_val': 2.4376088348525065e-05, 'learning_rate': 7.4757724708391716e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 188}
# DONE!      F1 = 0.14634146341463414
# Params testing:
# {'batch_size': 42, 'dropout_rate': 0.6150668016939156, 'embedding_dim': 73, 'epochs': 121, 'l2_val': 3.782831829363485e-05, 'learning_rate': 2.99280291078446e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 199}
# DONE!      F1 = 0.10666666666666667
# Params testing:
# {'batch_size': 89, 'dropout_rate': 0.5349680150371735, 'embedding_dim': 64, 'epochs': 71, 'l2_val': 1.1230272466993123e-05, 'learning_rate': 9.188353777901154e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 81}
# DONE!      F1 = 0.6138613861386139
# Params testing:
# {'batch_size': 77, 'dropout_rate': 0.5373984751845872, 'embedding_dim': 86, 'epochs': 48, 'l2_val': 1.3838688553602326e-05, 'learning_rate': 9.65634315748448e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 139}
# DONE!      F1 = 0.5961538461538461
# Params testing:
# {'batch_size': 94, 'dropout_rate': 0.49271416717992966, 'embedding_dim': 77, 'epochs': 62, 'l2_val': 8.376106551360126e-06, 'learning_rate': 6.046206108862558e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 122}
# DONE!      F1 = 0.5765765765765765
# Params testing:
# {'batch_size': 72, 'dropout_rate': 0.545863076395398, 'embedding_dim': 105, 'epochs': 103, 'l2_val': 1.3431865560634255e-06, 'learning_rate': 3.641346315270715e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 100}
# DONE!      F1 = 0.625
# Params testing:
# {'batch_size': 65, 'dropout_rate': 0.5991313921877266, 'embedding_dim': 103, 'epochs': 103, 'l2_val': 2.0690380144847778e-06, 'learning_rate': 3.4869973036877906e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 100}
# DONE!      F1 = 0.6206896551724138
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.5486023203574432, 'embedding_dim': 248, 'epochs': 115, 'l2_val': 1.4512843194124461e-06, 'learning_rate': 7.955661743845222e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 81}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.6593901616031559, 'embedding_dim': 138, 'epochs': 123, 'l2_val': 1.1749130504348278e-06, 'learning_rate': 4.830340281545278e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 49}
# DONE!      F1 = 0.6407766990291262
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.6745500702895242, 'embedding_dim': 133, 'epochs': 121, 'l2_val': 1.2263660616497976e-06, 'learning_rate': 2.429159905252575e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 42}
# DONE!      F1 = 0.48226950354609927
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.5153462807641868, 'embedding_dim': 166, 'epochs': 113, 'l2_val': 3.4505529447354834e-06, 'learning_rate': 1.5356277558911025e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 65}
# DONE!      F1 = 0.49275362318840576
# Params testing:
# {'batch_size': 84, 'dropout_rate': 0.665577020204378, 'embedding_dim': 115, 'epochs': 121, 'l2_val': 5.478443845644042e-06, 'learning_rate': 1.922702884566344e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 49}
# DONE!      F1 = 0.5504587155963303
# Params testing:
# {'batch_size': 98, 'dropout_rate': 0.6902297774504188, 'embedding_dim': 140, 'epochs': 103, 'l2_val': 1.0544938830247865e-06, 'learning_rate': 4.684516088987086e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 78}
# DONE!      F1 = 0.5585585585585585
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.628131195149837, 'embedding_dim': 156, 'epochs': 125, 'l2_val': 1.8448285288468132e-05, 'learning_rate': 4.278270793114735e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 97}
# DONE!      F1 = 0.2619047619047619
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.41989072124743115, 'embedding_dim': 175, 'epochs': 111, 'l2_val': 9.96172531291299e-05, 'learning_rate': 4.0529250371087826e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 40}
# DONE!      F1 = 0.6285714285714286
# Params testing:
# {'batch_size': 56, 'dropout_rate': 0.4064399501400475, 'embedding_dim': 174, 'epochs': 110, 'l2_val': 0.00014810573259247704, 'learning_rate': 6.068072758191083e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 34}
# DONE!      F1 = 0.6
# Params testing:
# {'batch_size': 54, 'dropout_rate': 0.3045895254597607, 'embedding_dim': 193, 'epochs': 92, 'l2_val': 9.564989197179111e-05, 'learning_rate': 2.6977099055167327e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 46}
# DONE!      F1 = 0.5892857142857143
# Params testing:
# {'batch_size': 46, 'dropout_rate': 0.3905924481064757, 'embedding_dim': 187, 'epochs': 118, 'l2_val': 0.0006453044129685133, 'learning_rate': 1.2528255198519193e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 58}
# DONE!      F1 = 0.5588235294117647
# Params testing:
# {'batch_size': 59, 'dropout_rate': 0.25469246466271855, 'embedding_dim': 209, 'epochs': 125, 'l2_val': 4.844013452593829e-05, 'learning_rate': 1.1205709249729475e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 37}
# DONE!      F1 = 0.45070422535211263
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.4308408109966403, 'embedding_dim': 164, 'epochs': 86, 'l2_val': 7.396849036071119e-05, 'learning_rate': 8.198103979102153e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 67}
# DONE!      F1 = 0.19834710743801653
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.4540554578407837, 'embedding_dim': 198, 'epochs': 113, 'l2_val': 0.00018668173134577394, 'learning_rate': 4.1444708624182274e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 55}
# DONE!      F1 = 0.6078431372549019
# Params testing:
# {'batch_size': 79, 'dropout_rate': 0.2742674642441679, 'embedding_dim': 169, 'epochs': 99, 'l2_val': 3.426230432430888e-05, 'learning_rate': 6.360547054685688e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 44}
# DONE!      F1 = 0.09195402298850575
# Params testing:
# {'batch_size': 62, 'dropout_rate': 0.3458176148847788, 'embedding_dim': 158, 'epochs': 109, 'l2_val': 0.00011358013336884527, 'learning_rate': 5.682968303727104e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 76}
# DONE!      F1 = 0.19148936170212766
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.36448338381791406, 'embedding_dim': 146, 'epochs': 106, 'l2_val': 0.0005196156010847479, 'learning_rate': 2.2275953445079537e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 105}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'batch_size': 26, 'dropout_rate': 0.7106540910687597, 'embedding_dim': 176, 'epochs': 117, 'l2_val': 0.0009161652124488651, 'learning_rate': 5.288935717334704e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 126}
# DONE!      F1 = 0.5426356589147288
# Params testing:
# {'batch_size': 49, 'dropout_rate': 0.38470256331215574, 'embedding_dim': 183, 'epochs': 94, 'l2_val': 0.00035896477908653766, 'learning_rate': 9.758951862773549e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 88}
# DONE!      F1 = 0.4444444444444444
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.41000417724351446, 'embedding_dim': 220, 'epochs': 78, 'l2_val': 2.7007360434989175e-05, 'learning_rate': 2.901172804072959e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 155}
# DONE!      F1 = 0.6306306306306306
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.49987052150201783, 'embedding_dim': 233, 'epochs': 27, 'l2_val': 0.0002669197015258106, 'learning_rate': 8.269801826129939e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 148}
# DONE!      F1 = 0.5833333333333334
# Params testing:
# {'batch_size': 36, 'dropout_rate': 0.40220269599517006, 'embedding_dim': 222, 'epochs': 80, 'l2_val': 2.6947647320576818e-05, 'learning_rate': 1.7250941987794492e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 155}
# DONE!      F1 = 0.5692307692307692
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.377682262057992, 'embedding_dim': 248, 'epochs': 19, 'l2_val': 9.025632236540283e-06, 'learning_rate': 2.777470324495955e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 183}
# DONE!      F1 = 0.16
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.5700484070780246, 'embedding_dim': 206, 'epochs': 68, 'l2_val': 6.7441589600985395e-06, 'learning_rate': 6.561704183548383e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 170}
# DONE!      F1 = 0.611111111111111
# Params testing:
# {'batch_size': 106, 'dropout_rate': 0.3243280492286074, 'embedding_dim': 132, 'epochs': 75, 'l2_val': 1.277844105683827e-05, 'learning_rate': 1.8536740077258329e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 212}
# DONE!      F1 = 0.2076502732240437
# Params testing:
# {'batch_size': 39, 'dropout_rate': 0.5891466991980062, 'embedding_dim': 151, 'epochs': 59, 'l2_val': 1.6087744660016393e-05, 'learning_rate': 1.3992810942003794e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 162}
# DONE!      F1 = 0.3636363636363636
# Params testing:
# {'batch_size': 21, 'dropout_rate': 0.6462654255900789, 'embedding_dim': 125, 'epochs': 30, 'l2_val': 4.7386940531227575e-06, 'learning_rate': 2.8159036681865308e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 171}
# DONE!      F1 = 0.5309734513274337
# Params testing:
# {'batch_size': 87, 'dropout_rate': 0.4429616143515358, 'embedding_dim': 144, 'epochs': 89, 'l2_val': 6.74319573181989e-05, 'learning_rate': 1.075439710708518e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 116}
# DONE!      F1 = 0.31343283582089554
# Params testing:
# {'batch_size': 113, 'dropout_rate': 0.7493313904794704, 'embedding_dim': 138, 'epochs': 85, 'l2_val': 5.527497329447988e-05, 'learning_rate': 4.155456133691439e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 138}
# DONE!      F1 = 0.19607843137254902
# Params testing:
# {'batch_size': 47, 'dropout_rate': 0.4643064375228745, 'embedding_dim': 118, 'epochs': 37, 'l2_val': 1.882090389262992e-05, 'learning_rate': 9.941771165044388e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 196}
# DONE!      F1 = 0.6037735849056604
# Params testing:
# {'batch_size': 44, 'dropout_rate': 0.47765216168431773, 'embedding_dim': 161, 'epochs': 79, 'l2_val': 2.1186975101508195e-05, 'learning_rate': 2.0274749919887093e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 157}
# DONE!      F1 = 0.5669291338582677
# Params testing:
# {'batch_size': 34, 'dropout_rate': 0.732541719601849, 'embedding_dim': 223, 'epochs': 48, 'l2_val': 4.170683425891699e-05, 'learning_rate': 6.792547454128495e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 128}
# DONE!      F1 = 0.1732283464566929
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.5242747250791449, 'embedding_dim': 189, 'epochs': 52, 'l2_val': 0.00013392436203962365, 'learning_rate': 4.913494310338009e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 205}
# DONE!      F1 = 0.6324786324786325
# Params testing:
# {'batch_size': 124, 'dropout_rate': 0.5241370053182931, 'embedding_dim': 213, 'epochs': 51, 'l2_val': 0.00041904714147683337, 'learning_rate': 4.737255612515671e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 147}
# DONE!      F1 = 0.6165413533834586
# Params testing:
# {'batch_size': 101, 'dropout_rate': 0.2714330316895728, 'embedding_dim': 227, 'epochs': 64, 'l2_val': 0.00016637541598803622, 'learning_rate': 3.206939817178373e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 204}
# DONE!      F1 = 0.5811965811965812
# Params testing:
# {'batch_size': 92, 'dropout_rate': 0.30261839809593827, 'embedding_dim': 188, 'epochs': 23, 'l2_val': 0.0007738078266453885, 'learning_rate': 7.941011098391589e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 189}
# DONE!      F1 = 0.5629629629629629
# Params testing:
# {'batch_size': 97, 'dropout_rate': 0.6165149704323775, 'embedding_dim': 170, 'epochs': 44, 'l2_val': 0.00014700600865575177, 'learning_rate': 6.798705827030678e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 240}
# DONE!      F1 = 0.5818181818181818
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.6928552642915774, 'embedding_dim': 136, 'epochs': 33, 'l2_val': 0.00021089301498938837, 'learning_rate': 1.0546351024955415e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 230}
# DONE!      F1 = 0.13008130081300814
# Params testing:
# {'batch_size': 81, 'dropout_rate': 0.6569115017507718, 'embedding_dim': 111, 'epochs': 55, 'l2_val': 7.965287025002047e-05, 'learning_rate': 5.752246582750152e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 217}
# DONE!      F1 = 0.6050420168067226
# Params testing:
# {'batch_size': 108, 'dropout_rate': 0.3161306685912012, 'embedding_dim': 234, 'epochs': 60, 'l2_val': 1.7880195930469041e-06, 'learning_rate': 1.611331164952836e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 176}
# DONE!      F1 = 0.3790849673202614
# Params testing:
# {'batch_size': 112, 'dropout_rate': 0.34120070043327283, 'embedding_dim': 202, 'epochs': 40, 'l2_val': 0.00038043802080645934, 'learning_rate': 2.6039952759583623e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 208}
# DONE!      F1 = 0.36764705882352944
# Params testing:
# {'batch_size': 117, 'dropout_rate': 0.35102909723413267, 'embedding_dim': 218, 'epochs': 70, 'l2_val': 0.00023021633236210297, 'learning_rate': 8.594967948493655e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 143}
# DONE!      F1 = 0.1487603305785124
# Params testing:
# {'batch_size': 127, 'dropout_rate': 0.5102074679454963, 'embedding_dim': 248, 'epochs': 57, 'l2_val': 0.0002972841978188889, 'learning_rate': 3.4065881531478876e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 183}
# DONE!      F1 = 0.513888888888889
# Params testing:
# {'batch_size': 103, 'dropout_rate': 0.42678395093499705, 'embedding_dim': 196, 'epochs': 77, 'l2_val': 0.0005202152874552094, 'learning_rate': 5.0977517059993356e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 222}
# DONE!      F1 = 0.16551724137931034
# Params testing:
# {'batch_size': 78, 'dropout_rate': 0.4074171655679501, 'embedding_dim': 181, 'epochs': 73, 'l2_val': 3.5607428580578954e-06, 'learning_rate': 3.6869006876607635e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 152}
# DONE!      F1 = 0.18181818181818182
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.46225134633820164, 'embedding_dim': 243, 'epochs': 62, 'l2_val': 3.184074193116032e-05, 'learning_rate': 1.3944949520298268e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 176}
# DONE!      F1 = 0.3546099290780142
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.4389050406859676, 'embedding_dim': 190, 'epochs': 30, 'l2_val': 0.00012730382795273073, 'learning_rate': 5.480784462508198e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 194}
# DONE!      F1 = 0.1394169835234474
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.5929527133096415, 'embedding_dim': 97, 'epochs': 52, 'l2_val': 8.75249570973094e-05, 'learning_rate': 9.837089608626246e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 244}
# DONE!      F1 = 0.6326530612244898
# Params testing:
# {'batch_size': 96, 'dropout_rate': 0.592943972883115, 'embedding_dim': 93, 'epochs': 44, 'l2_val': 9.208155504887205e-05, 'learning_rate': 9.019761684180216e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 247}
# DONE!      F1 = 0.5945945945945946
# Params testing:
# {'batch_size': 75, 'dropout_rate': 0.6241622801465998, 'embedding_dim': 88, 'epochs': 52, 'l2_val': 0.00010520184709783038, 'learning_rate': 1.3809911162268415e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 248}
# DONE!      F1 = 0.12396694214876032
# Params testing:
# {'batch_size': 73, 'dropout_rate': 0.5658182150752761, 'embedding_dim': 96, 'epochs': 48, 'l2_val': 0.00017548596955204603, 'learning_rate': 5.057121636110916e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 229}
# DONE!      F1 = 0.578512396694215
# Params testing:
# {'batch_size': 91, 'dropout_rate': 0.4948301546088873, 'embedding_dim': 68, 'epochs': 25, 'l2_val': 6.097020139016827e-05, 'learning_rate': 3.865019909967345e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 221}
# DONE!      F1 = 0.21487603305785122
# Params testing:
# {'batch_size': 87, 'dropout_rate': 0.5747817144703955, 'embedding_dim': 122, 'epochs': 67, 'l2_val': 3.622668790353284e-05, 'learning_rate': 3.006313339372525e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 202}
# DONE!      F1 = 0.10862619808306709
# Params testing:
# {'batch_size': 94, 'dropout_rate': 0.703940053579931, 'embedding_dim': 130, 'epochs': 39, 'l2_val': 0.0002652969109599374, 'learning_rate': 2.1728840541571888e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 237}
# DONE!      F1 = 0.19607843137254902
# Params testing:
# {'batch_size': 115, 'dropout_rate': 0.6648539184202328, 'embedding_dim': 100, 'epochs': 34, 'l2_val': 0.0001480233456538703, 'learning_rate': 7.595742751306614e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 253}
# DONE!      F1 = 0.5223880597014925
# Params testing:
# {'batch_size': 102, 'dropout_rate': 0.5571133259328882, 'embedding_dim': 80, 'epochs': 42, 'l2_val': 4.540729611055325e-05, 'learning_rate': 2.6516433908105925e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 215}
# DONE!      F1 = 0.12865497076023394
# Params testing:
# {'batch_size': 107, 'dropout_rate': 0.6794112021874579, 'embedding_dim': 142, 'epochs': 58, 'l2_val': 0.0006020936787467835, 'learning_rate': 2.1920615609172744e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 208}
# DONE!      F1 = 0.08917197452229299
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.6457969640885084, 'embedding_dim': 127, 'epochs': 47, 'l2_val': 5.425870471941346e-05, 'learning_rate': 9.901389169185383e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 233}
# DONE!      F1 = 0.6346153846153846
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.6012628106414684, 'embedding_dim': 114, 'epochs': 50, 'l2_val': 5.2360217522969153e-05, 'learning_rate': 3.837352515097421e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 245}
# DONE!      F1 = 0.1111111111111111
# Params testing:
# {'batch_size': 99, 'dropout_rate': 0.7437549792783268, 'embedding_dim': 108, 'epochs': 17, 'l2_val': 2.242949985418353e-05, 'learning_rate': 9.472699611065907e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 234}
# DONE!      F1 = 0.30158730158730157
# Params testing:
# {'batch_size': 66, 'dropout_rate': 0.7254881533261875, 'embedding_dim': 76, 'epochs': 21, 'l2_val': 6.994088409888889e-05, 'learning_rate': 1.6610648926903797e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 85}
# DONE!      F1 = 0.0
# Params testing:
# {'batch_size': 78, 'dropout_rate': 0.6191689896874095, 'embedding_dim': 84, 'epochs': 55, 'l2_val': 8.365230657054412e-05, 'learning_rate': 6.250827553873669e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 256}
# DONE!      F1 = 0.5585585585585585
# Params testing:
# {'batch_size': 88, 'dropout_rate': 0.6334127073360353, 'embedding_dim': 127, 'epochs': 65, 'l2_val': 9.222120022073881e-06, 'learning_rate': 2.0087227622501074e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 241}
# DONE!      F1 = 0.12121212121212122
# Params testing:
# {'batch_size': 63, 'dropout_rate': 0.6849807992180805, 'embedding_dim': 116, 'epochs': 37, 'l2_val': 1.4212951860374028e-05, 'learning_rate': 3.959191052341828e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 224}
# DONE!      F1 = 0.5178571428571429
# Params testing:
# {'batch_size': 122, 'dropout_rate': 0.6419393548392277, 'embedding_dim': 70, 'epochs': 46, 'l2_val': 2.7297253037573716e-05, 'learning_rate': 8.440711437649436e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 93}
# DONE!      F1 = 0.13959390862944163
# Params testing:
# {'batch_size': 58, 'dropout_rate': 0.5815393862685093, 'embedding_dim': 97, 'epochs': 92, 'l2_val': 1.0844402114811336e-05, 'learning_rate': 8.415975938102386e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 53}
# DONE!      F1 = 0.6019417475728155
# Params testing:
# {'batch_size': 110, 'dropout_rate': 0.6076766399878347, 'embedding_dim': 105, 'epochs': 28, 'l2_val': 0.000113118143223258, 'learning_rate': 1.3545812529200862e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 105}
# DONE!      F1 = 0.13986013986013987
# Params testing:
# {'batch_size': 92, 'dropout_rate': 0.7016197436510577, 'embedding_dim': 93, 'epochs': 74, 'l2_val': 2.392982720777211e-06, 'learning_rate': 1.8261518000404445e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 64}
# DONE!      F1 = 0.3063063063063063
# Params testing:
# {'batch_size': 76, 'dropout_rate': 0.6663151802116368, 'embedding_dim': 149, 'epochs': 84, 'l2_val': 3.148588550651178e-05, 'learning_rate': 5.572040311473729e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 166}
# DONE!      F1 = 0.611111111111111
# Params testing:
# {'batch_size': 68, 'dropout_rate': 0.6528566439425819, 'embedding_dim': 120, 'epochs': 81, 'l2_val': 6.12485929398748e-06, 'learning_rate': 9.893211517342778e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 198}
# DONE!      F1 = 0.6213592233009707
# Params testing:
# {'batch_size': 105, 'dropout_rate': 0.7141288828176188, 'embedding_dim': 111, 'epochs': 100, 'l2_val': 5.873169092408242e-05, 'learning_rate': 7.240388941764903e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 71}
# DONE!      F1 = 0.16470588235294117
# Params testing:
# {'batch_size': 72, 'dropout_rate': 0.6380044133627816, 'embedding_dim': 155, 'epochs': 60, 'l2_val': 4.07275077263491e-05, 'learning_rate': 1.6903502070488753e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 117}
# DONE!      F1 = 0.09523809523809523
# Params testing:
# {'batch_size': 84, 'dropout_rate': 0.5943472995665591, 'embedding_dim': 64, 'epochs': 70, 'l2_val': 1.5449773614790488e-05, 'learning_rate': 2.4445690692878665e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 252}
# DONE!      F1 = 0.4411764705882353
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.6741957276140855, 'embedding_dim': 163, 'epochs': 46, 'l2_val': 2.7019592881621524e-06, 'learning_rate': 4.288806099090923e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 190}
# DONE!      F1 = 0.6190476190476191
# Params testing:
# {'batch_size': 119, 'dropout_rate': 0.5428234879529733, 'embedding_dim': 129, 'epochs': 30, 'l2_val': 0.00019091453356611036, 'learning_rate': 1.0568784394649378e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 132}
# DONE!      F1 = 0.1149425287356322
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.5587585481021348, 'embedding_dim': 140, 'epochs': 48, 'l2_val': 8.908126068204614e-05, 'learning_rate': 4.7192833221190515e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 228}
# DONE!      F1 = 0.5546218487394958
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.5221062912486457, 'embedding_dim': 124, 'epochs': 54, 'l2_val': 0.00011962465098403867, 'learning_rate': 7.151714720337068e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 234}
# DONE!      F1 = 0.594059405940594
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.6114270237980644, 'embedding_dim': 184, 'epochs': 53, 'l2_val': 0.00032747776034989097, 'learning_rate': 3.198700379702327e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 213}
# DONE!      F1 = 0.576
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.4866451286019642, 'embedding_dim': 167, 'epochs': 63, 'l2_val': 0.0001331623508687272, 'learning_rate': 6.247120729140592e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 218}
# DONE!      F1 = 0.6037735849056604
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.5487044323425009, 'embedding_dim': 136, 'epochs': 42, 'l2_val': 0.0002363290484109503, 'learning_rate': 1.0243341026102323e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 243}
# DONE!      F1 = 0.10285714285714284
# Params testing:
# {'batch_size': 66, 'dropout_rate': 0.506493842350285, 'embedding_dim': 158, 'epochs': 50, 'l2_val': 4.8428834030362654e-05, 'learning_rate': 9.779884026842029e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 182}
# DONE!      F1 = 0.5871559633027522
# Params testing:
# {'batch_size': 89, 'dropout_rate': 0.5330678188713, 'embedding_dim': 102, 'epochs': 68, 'l2_val': 2.0297851922733962e-05, 'learning_rate': 3.59782424940598e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 238}
# DONE!      F1 = 0.5806451612903226
# Params testing:
# {'batch_size': 86, 'dropout_rate': 0.5788188051435385, 'embedding_dim': 152, 'epochs': 39, 'l2_val': 7.287377205678328e-05, 'learning_rate': 5.334081040086218e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 209}
# DONE!      F1 = 0.5625
# Params testing:
# {'batch_size': 77, 'dropout_rate': 0.5168750603958441, 'embedding_dim': 146, 'epochs': 44, 'l2_val': 6.132321830320513e-05, 'learning_rate': 8.340297949560025e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 224}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 98, 'dropout_rate': 0.6233427044018555, 'embedding_dim': 173, 'epochs': 57, 'l2_val': 0.0001022432092271637, 'learning_rate': 2.8517966462282906e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 256}
# DONE!      F1 = 0.5161290322580645
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.6586125048973254, 'embedding_dim': 204, 'epochs': 62, 'l2_val': 0.00045909283170515226, 'learning_rate': 7.367283298754841e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 249}
# DONE!      F1 = 0.5892857142857143
# Params testing:
# {'batch_size': 83, 'dropout_rate': 0.6468515409069859, 'embedding_dim': 193, 'epochs': 33, 'l2_val': 0.00020426872893446906, 'learning_rate': 2.329023392188117e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 233}
# DONE!      F1 = 0.17543859649122806
# Params testing:
# {'batch_size': 93, 'dropout_rate': 0.5909157655996462, 'embedding_dim': 211, 'epochs': 36, 'l2_val': 0.00014227175795405083, 'learning_rate': 4.5070058077962904e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 201}
# DONE!      F1 = 0.5263157894736842
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.5673437673019478, 'embedding_dim': 177, 'epochs': 60, 'l2_val': 0.0002825441344411313, 'learning_rate': 5.183944661673353e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 193}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.7210010368609485, 'embedding_dim': 134, 'epochs': 72, 'l2_val': 2.3962413192619604e-05, 'learning_rate': 2.0013170250249313e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 206}
# DONE!      F1 = 0.3157894736842105
# Params testing:
# {'batch_size': 101, 'dropout_rate': 0.6902993942904567, 'embedding_dim': 117, 'epochs': 41, 'l2_val': 0.000752623248549617, 'learning_rate': 1.6750178538489352e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 160}
# DONE!      F1 = 0.19607843137254902
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.47615037799388327, 'embedding_dim': 160, 'epochs': 52, 'l2_val': 0.00017234119322642294, 'learning_rate': 1.2392975625958139e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 174}
# DONE!      F1 = 0.23076923076923075
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.6337252011718955, 'embedding_dim': 80, 'epochs': 66, 'l2_val': 3.5404065488731085e-05, 'learning_rate': 6.0401032200686094e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 214}
# DONE!      F1 = 0.5789473684210527
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.6072183435205774, 'embedding_dim': 106, 'epochs': 25, 'l2_val': 8.184486692474588e-05, 'learning_rate': 6.014570635744437e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 231}
# DONE!      F1 = 0.1111111111111111
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.5824621256308814, 'embedding_dim': 91, 'epochs': 47, 'l2_val': 4.3501096039062305e-05, 'learning_rate': 6.995010579446914e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 180}
# DONE!      F1 = 0.576271186440678
# Params testing:
# {'batch_size': 110, 'dropout_rate': 0.5525879097007087, 'embedding_dim': 131, 'epochs': 31, 'l2_val': 1.2519198437417016e-05, 'learning_rate': 1.4896136289485405e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 187}
# DONE!      F1 = 0.23414634146341465
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.7371180812006688, 'embedding_dim': 144, 'epochs': 49, 'l2_val': 0.00040931047436695384, 'learning_rate': 9.854438635291728e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 220}
# DONE!      F1 = 0.6017699115044246
# Params testing:
# {'batch_size': 86, 'dropout_rate': 0.7037093617917616, 'embedding_dim': 148, 'epochs': 43, 'l2_val': 5.4193896059367894e-05, 'learning_rate': 8.516344838300423e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 238}
# DONE!      F1 = 0.6086956521739131
# Params testing:
# {'batch_size': 58, 'dropout_rate': 0.5357107340694592, 'embedding_dim': 112, 'epochs': 56, 'l2_val': 2.884313042227098e-05, 'learning_rate': 3.5891631640655164e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 225}
# DONE!      F1 = 0.5625
# Params testing:
# {'batch_size': 96, 'dropout_rate': 0.6818657986210864, 'embedding_dim': 126, 'epochs': 38, 'l2_val': 0.00010523090154156936, 'learning_rate': 3.0056661780732334e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 243}
# DONE!      F1 = 0.28125
# Params testing:
# {'batch_size': 77, 'dropout_rate': 0.48835587981778134, 'embedding_dim': 87, 'epochs': 35, 'l2_val': 6.978764674115966e-05, 'learning_rate': 4.702328957003764e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 167}
# DONE!      F1 = 0.4736842105263158
# Params testing:
# {'batch_size': 104, 'dropout_rate': 0.5977733432810133, 'embedding_dim': 120, 'epochs': 52, 'l2_val': 0.0009471904014832201, 'learning_rate': 2.6265476910707797e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 251}
# DONE!      F1 = 0.34074074074074073
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.5023741519117974, 'embedding_dim': 100, 'epochs': 76, 'l2_val': 9.21600885329012e-05, 'learning_rate': 9.17030195434227e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 123}
# DONE!      F1 = 0.17391304347826086
# Params testing:
# {'batch_size': 83, 'dropout_rate': 0.6213520378542206, 'embedding_dim': 74, 'epochs': 59, 'l2_val': 0.00012961692260688042, 'learning_rate': 9.954320107166711e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 110}
# DONE!      F1 = 0.6415094339622642
# Params testing:
# {'batch_size': 88, 'dropout_rate': 0.6600899901470543, 'embedding_dim': 71, 'epochs': 65, 'l2_val': 0.0005197816409204761, 'learning_rate': 6.553109648689991e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 105}
# DONE!      F1 = 0.5470085470085471
# Params testing:
# {'batch_size': 49, 'dropout_rate': 0.6697759696642877, 'embedding_dim': 76, 'epochs': 69, 'l2_val': 0.00024296573383434034, 'learning_rate': 9.907195247734038e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 94}
# DONE!      F1 = 0.5871559633027522
# Params testing:
# {'batch_size': 100, 'dropout_rate': 0.6252199490308005, 'embedding_dim': 84, 'epochs': 88, 'l2_val': 0.00016417787654230017, 'learning_rate': 7.937928860892593e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 34}
# DONE!      F1 = 0.5309734513274337
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.6466572079545997, 'embedding_dim': 67, 'epochs': 62, 'l2_val': 0.00035477085330051214, 'learning_rate': 5.688653454793486e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 62}
# DONE!      F1 = 0.5573770491803278
# Params testing:
# {'batch_size': 79, 'dropout_rate': 0.6157626504767436, 'embedding_dim': 95, 'epochs': 55, 'l2_val': 1.7231291483999303e-05, 'learning_rate': 8.725732318269466e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 110}
# DONE!      F1 = 0.034482758620689655
# Params testing:
# {'batch_size': 54, 'dropout_rate': 0.6968142792229536, 'embedding_dim': 74, 'epochs': 82, 'l2_val': 3.54680241206249e-05, 'learning_rate': 8.795937491671287e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 138}
# DONE!      F1 = 0.607142857142857
# Params testing:
# ...
# Params testing:
# {'batch_size': 24, 'dropout_rate': 0.5415836799502047, 'embedding_dim': 203, 'epochs': 112, 'l2_val': 2.2192302086474013e-05, 'learning_rate': 2.0577407084934948e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 172}
# DONE!      F1 = 0.6000000000000001
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.4947247178766762, 'embedding_dim': 199, 'epochs': 115, 'l2_val': 2.545491946007021e-05, 'learning_rate': 9.784445620642213e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 181}
# DONE!      F1 = 0.5223880597014925
# Params testing:
# {'batch_size': 77, 'dropout_rate': 0.5213604714230979, 'embedding_dim': 134, 'epochs': 128, 'l2_val': 6.978752112591209e-05, 'learning_rate': 4.093594278069663e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 146}
# DONE!      F1 = 0.6199999999999999
# Params testing:
# {'batch_size': 87, 'dropout_rate': 0.48280351122639575, 'embedding_dim': 161, 'epochs': 118, 'l2_val': 0.00016167986620655735, 'learning_rate': 2.8199207732976646e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 158}
# DONE!      F1 = 0.5981308411214953
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.6088054101909826, 'embedding_dim': 179, 'epochs': 59, 'l2_val': 0.0005705159338152499, 'learning_rate': 5.835654470670645e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 200}
# DONE!      F1 = 0.591304347826087
# Params testing:
# {'batch_size': 26, 'dropout_rate': 0.7104672339955926, 'embedding_dim': 168, 'epochs': 108, 'l2_val': 1.5166715641299235e-05, 'learning_rate': 6.7711768769425e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 187}
# DONE!      F1 = 0.16216216216216214
# Params testing:
# {'batch_size': 66, 'dropout_rate': 0.38977336481125485, 'embedding_dim': 148, 'epochs': 82, 'l2_val': 4.109786143515077e-05, 'learning_rate': 8.749291784750675e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 114}
# DONE!      F1 = 0.6037735849056604
# Params testing:
# {'batch_size': 34, 'dropout_rate': 0.559893229547623, 'embedding_dim': 139, 'epochs': 65, 'l2_val': 5.851052730566144e-05, 'learning_rate': 7.139586240779895e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 122}
# DONE!      F1 = 0.616822429906542
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.6317478423032886, 'embedding_dim': 188, 'epochs': 77, 'l2_val': 1.4561549007405353e-06, 'learning_rate': 4.6227722527904467e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 218}
# DONE!      F1 = 0.607142857142857
# Params testing:
# {'batch_size': 81, 'dropout_rate': 0.6167195343414678, 'embedding_dim': 124, 'epochs': 55, 'l2_val': 0.00021112881297857974, 'learning_rate': 3.24380501684978e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 143}
# DONE!      F1 = 0.5285714285714287
# Params testing:
# {'batch_size': 123, 'dropout_rate': 0.7268983578651366, 'embedding_dim': 158, 'epochs': 102, 'l2_val': 1.1643015215557803e-05, 'learning_rate': 1.4549894772105724e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 166}
# DONE!      F1 = 0.2905982905982906
# Params testing:
# {'batch_size': 63, 'dropout_rate': 0.5469252882716085, 'embedding_dim': 131, 'epochs': 125, 'l2_val': 4.091742683176079e-05, 'learning_rate': 5.15571864824873e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 149}
# DONE!      F1 = 0.5882352941176471
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.41417396806306384, 'embedding_dim': 212, 'epochs': 61, 'l2_val': 5.048214579921698e-05, 'learning_rate': 2.341440069317462e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 206}
# DONE!      F1 = 0.5629629629629629
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.33433341819893625, 'embedding_dim': 171, 'epochs': 87, 'l2_val': 0.00036784819904544895, 'learning_rate': 3.746195903964259e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 52}
# DONE!      F1 = 0.6285714285714286
# Params testing:
# {'batch_size': 57, 'dropout_rate': 0.42794164468975876, 'embedding_dim': 183, 'epochs': 120, 'l2_val': 0.00028737858009692137, 'learning_rate': 1.8930489287229968e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 192}
# DONE!      F1 = 0.6017699115044246
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.44783198335280483, 'embedding_dim': 208, 'epochs': 72, 'l2_val': 2.9425113273093525e-05, 'learning_rate': 2.542690793116895e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 45}
# DONE!      F1 = 0.0
# Params testing:
# {'batch_size': 23, 'dropout_rate': 0.5927160105394754, 'embedding_dim': 155, 'epochs': 98, 'l2_val': 1.8020318445212454e-05, 'learning_rate': 1.1904695064671688e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 174}
# DONE!      F1 = 0.59375
# Params testing:
# {'batch_size': 16, 'dropout_rate': 0.5134015874991612, 'embedding_dim': 238, 'epochs': 89, 'l2_val': 2.662399439415937e-06, 'learning_rate': 8.104514205578393e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 138}
# DONE!      F1 = 0.5666666666666668
# Params testing:
# {'batch_size': 36, 'dropout_rate': 0.5289264323166859, 'embedding_dim': 195, 'epochs': 110, 'l2_val': 1.3891792732949352e-05, 'learning_rate': 1.6147474086792593e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 186}
# DONE!      F1 = 0.5950413223140496
# Params testing:
# {'batch_size': 48, 'dropout_rate': 0.5741426061217352, 'embedding_dim': 127, 'epochs': 123, 'l2_val': 8.910126254770321e-05, 'learning_rate': 6.0490387210917635e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 71}
# DONE!      F1 = 0.27956989247311825
# Params testing:
# {'batch_size': 29, 'dropout_rate': 0.46371225828856977, 'embedding_dim': 231, 'epochs': 105, 'l2_val': 9.303809216406927e-06, 'learning_rate': 9.286951945364476e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 160}
# DONE!      F1 = 0.5343511450381679
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.5996062187720368, 'embedding_dim': 146, 'epochs': 114, 'l2_val': 6.996576320904009e-05, 'learning_rate': 4.829597809998058e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 127}
# DONE!      F1 = 0.2127659574468085
# Params testing:
# {'batch_size': 84, 'dropout_rate': 0.6597171947930054, 'embedding_dim': 166, 'epochs': 80, 'l2_val': 0.0001275611894250726, 'learning_rate': 6.55924544779353e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 203}
# DONE!      F1 = 0.6407766990291262
# Params testing:
# {'batch_size': 92, 'dropout_rate': 0.6909066491476685, 'embedding_dim': 163, 'epochs': 70, 'l2_val': 0.00013509823544844145, 'learning_rate': 8.897122866539182e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 212}
# DONE!      F1 = 0.6037735849056604
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.6692854043093164, 'embedding_dim': 151, 'epochs': 94, 'l2_val': 2.5167454550162583e-05, 'learning_rate': 6.92497265936606e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 203}
# DONE!      F1 = 0.5849056603773585
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.6545001623223932, 'embedding_dim': 154, 'epochs': 79, 'l2_val': 0.00017012403079159517, 'learning_rate': 6.220438923669697e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 225}
# DONE!      F1 = 0.5769230769230769
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.7169244405668743, 'embedding_dim': 166, 'epochs': 83, 'l2_val': 0.000103570545926085, 'learning_rate': 7.350123888195132e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 228}
# DONE!      F1 = 0.5740740740740741
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.6902230787090874, 'embedding_dim': 174, 'epochs': 73, 'l2_val': 0.00018599668279409683, 'learning_rate': 9.073166957998528e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 219}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 88, 'dropout_rate': 0.6785656220442431, 'embedding_dim': 148, 'epochs': 85, 'l2_val': 5.5053840922563526e-05, 'learning_rate': 5.260173369773306e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 194}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'batch_size': 99, 'dropout_rate': 0.70774299678369, 'embedding_dim': 161, 'epochs': 81, 'l2_val': 8.027500797546968e-05, 'learning_rate': 5.444742209509961e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 194}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'batch_size': 96, 'dropout_rate': 0.7421902170203437, 'embedding_dim': 156, 'epochs': 86, 'l2_val': 0.00012537933618222093, 'learning_rate': 9.672242455367428e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 198}
# DONE!      F1 = 0.5981308411214953
# Params testing:
# {'batch_size': 89, 'dropout_rate': 0.6642160100086926, 'embedding_dim': 147, 'epochs': 91, 'l2_val': 0.0002296219739775818, 'learning_rate': 9.891221117539125e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 208}
# DONE!      F1 = 0.6019417475728155
# Params testing:
# {'batch_size': 87, 'dropout_rate': 0.6777572494568191, 'embedding_dim': 169, 'epochs': 86, 'l2_val': 0.00014993662582976739, 'learning_rate': 6.267573602860705e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 202}
# DONE!      F1 = 0.627450980392157
# Params testing:
# {'batch_size': 78, 'dropout_rate': 0.7291367069431912, 'embedding_dim': 177, 'epochs': 84, 'l2_val': 8.530500867277816e-05, 'learning_rate': 4.85334494807068e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 215}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 103, 'dropout_rate': 0.6418164030101566, 'embedding_dim': 163, 'epochs': 92, 'l2_val': 6.5809002272762e-05, 'learning_rate': 9.903641404319874e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 197}
# DONE!      F1 = 0.6213592233009707
# Params testing:
# {'batch_size': 93, 'dropout_rate': 0.6988840013864541, 'embedding_dim': 173, 'epochs': 78, 'l2_val': 0.00010234416761440156, 'learning_rate': 7.428272837690358e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 190}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'batch_size': 84, 'dropout_rate': 0.6816852033029802, 'embedding_dim': 159, 'epochs': 84, 'l2_val': 4.8072628367773304e-05, 'learning_rate': 5.5942357930184116e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 204}
# DONE!      F1 = 0.6019417475728155
# Params testing:
# {'batch_size': 101, 'dropout_rate': 0.6478602892319716, 'embedding_dim': 152, 'epochs': 75, 'l2_val': 6.35199601672156e-05, 'learning_rate': 8.28367802156543e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 211}
# DONE!      F1 = 0.6285714285714286
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.6576171414591229, 'embedding_dim': 180, 'epochs': 80, 'l2_val': 5.528355851900478e-05, 'learning_rate': 4.3259886743444665e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 223}
# DONE!      F1 = 0.15235008103727712
# Params testing:
# {'batch_size': 83, 'dropout_rate': 0.7041754074585811, 'embedding_dim': 164, 'epochs': 89, 'l2_val': 7.522095981894604e-05, 'learning_rate': 4.1888056385408234e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 183}
# DONE!      F1 = 0.6238532110091743
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.7224125904862225, 'embedding_dim': 143, 'epochs': 82, 'l2_val': 0.00011135619463757122, 'learning_rate': 7.998430292374726e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 187}
# DONE!      F1 = 0.611111111111111
# Params testing:
# {'batch_size': 86, 'dropout_rate': 0.6719751582925783, 'embedding_dim': 170, 'epochs': 88, 'l2_val': 0.0002613907868684578, 'learning_rate': 6.394163499916831e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 196}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'batch_size': 97, 'dropout_rate': 0.6410321482900907, 'embedding_dim': 149, 'epochs': 76, 'l2_val': 0.0001397313303627947, 'learning_rate': 3.431624872752294e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 209}
# DONE!      F1 = 0.578125
# Params testing:
# {'batch_size': 93, 'dropout_rate': 0.624930291265376, 'embedding_dim': 157, 'epochs': 85, 'l2_val': 0.00011807348576436092, 'learning_rate': 4.7055240457904445e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 204}
# DONE!      F1 = 0.6238532110091743
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.7178570211139492, 'embedding_dim': 175, 'epochs': 90, 'l2_val': 0.00019999385712359403, 'learning_rate': 3.964513454880502e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 191}
# DONE!      F1 = 0.5945945945945946
# Params testing:
# {'batch_size': 76, 'dropout_rate': 0.6884069544504923, 'embedding_dim': 167, 'epochs': 80, 'l2_val': 8.770942339856582e-05, 'learning_rate': 5.526985815086484e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 215}
# DONE!      F1 = 0.6296296296296297
# Params testing:
# {'batch_size': 106, 'dropout_rate': 0.7469578057323031, 'embedding_dim': 186, 'epochs': 95, 'l2_val': 5.6032646922929466e-05, 'learning_rate': 7.687716711054188e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 182}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'batch_size': 88, 'dropout_rate': 0.6638011227781085, 'embedding_dim': 153, 'epochs': 78, 'l2_val': 3.684649950234802e-05, 'learning_rate': 2.819068218608087e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 175}
# DONE!      F1 = 0.5470085470085471
# Params testing:
# {'batch_size': 110, 'dropout_rate': 0.6309731755811715, 'embedding_dim': 182, 'epochs': 92, 'l2_val': 0.00015841219996662263, 'learning_rate': 5.852376718433102e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 198}
# DONE!      F1 = 0.12380952380952381
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.7380029722013123, 'embedding_dim': 136, 'epochs': 74, 'l2_val': 0.00045185696328848163, 'learning_rate': 6.258236664981862e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 201}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 98, 'dropout_rate': 0.6797821438990567, 'embedding_dim': 147, 'epochs': 94, 'l2_val': 4.3466427617813636e-05, 'learning_rate': 7.065572231572818e-07, 'max_len': 55, 'max_words': 5000, 'n_units': 222}
# DONE!      F1 = 0.11764705882352942
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.7067242562819336, 'embedding_dim': 159, 'epochs': 87, 'l2_val': 7.60017316322369e-05, 'learning_rate': 9.960786290828272e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 188}
# DONE!      F1 = 0.5981308411214953
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.6943460620144104, 'embedding_dim': 164, 'epochs': 83, 'l2_val': 9.880663622145555e-05, 'learning_rate': 3.635580314360595e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 177}
# DONE!      F1 = 0.6306306306306306
# Params testing:
# {'batch_size': 100, 'dropout_rate': 0.645607951967433, 'embedding_dim': 178, 'epochs': 88, 'l2_val': 5.029989059681838e-05, 'learning_rate': 6.8086406850531e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 169}
# DONE!      F1 = 0.594059405940594
# Params testing:
# {'batch_size': 91, 'dropout_rate': 0.6738792585382208, 'embedding_dim': 142, 'epochs': 97, 'l2_val': 0.00030153033863909967, 'learning_rate': 4.690955097777881e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 183}
# DONE!      F1 = 0.6476190476190475
# Params testing:
# {'batch_size': 118, 'dropout_rate': 0.6625383910607437, 'embedding_dim': 130, 'epochs': 94, 'l2_val': 0.0003892382425715704, 'learning_rate': 9.745416449021391e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 217}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 103, 'dropout_rate': 0.7168250419960596, 'embedding_dim': 121, 'epochs': 98, 'l2_val': 0.0005498673165451241, 'learning_rate': 5.006386615684979e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 229}
# DONE!      F1 = 0.6126126126126126
# Params testing:
# {'batch_size': 113, 'dropout_rate': 0.6529635678698077, 'embedding_dim': 140, 'epochs': 96, 'l2_val': 0.0009856554658917768, 'learning_rate': 4.462421813897194e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 214}
# DONE!      F1 = 0.6126126126126126
# Params testing:
# {'batch_size': 108, 'dropout_rate': 0.6720518181776879, 'embedding_dim': 132, 'epochs': 99, 'l2_val': 0.0006447410852370958, 'learning_rate': 7.665757714579728e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 205}
# DONE!      F1 = 0.6095238095238096
# 100%|██████████| 500/500 [4:22:19<00:00, 31.48s/it, best loss: -0.6481481481481481]
# Best hyperparams:  {'batch_size': 26.0, 'dropout_rate': 0.412649987050131, 'embedding_dim': 173.0, 'epochs': 99.0, 'l2_val': 1.1319794133260141e-05, 'learning_rate': 1.935639771089876e-05, 'n_units': 184.0}
