# %% [markdown]
# # Tuning the KNN classifier
#
# Hyperparameter sweep for the **$k$ nearest neighbors classifier** for producing results with various **degrees of dataset imbalance**. Optimize the hyperparameters for the worst-case imbalance configuration. Optimization conducted by means of the tree-structured Parzen estimator.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import copy
import sys

# %%
# Sci-kit learn for machine learning tasks
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# HyperOptfor Bayesian optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# ## Load and process data

# %%
# Load training set
train_set_file  = "train_set_imb_0.csv"
train_set = pd.read_csv(train_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])

# %% [markdown]
# ## Define hyperparameter search space and objective function

# %%
# Define the search space for hyperparameterss
hyperparam_space = {'leaf_size': scope.int(hp.qloguniform('leaf_size', np.log(1e1), np.log(1e3), q=1)),
                    'n_neighbors': scope.int(hp.quniform('n_neighbors', 3, 150, q=1)),
                    'max_features': scope.int(hp.qloguniform('max_features', np.log(5e4), np.log(5e5), q=1)),
                    'vectorizer': hp.choice('vectorizer', ['tfidf', 'count']),
                    'weights': hp.choice('weights', ['uniform', 'distance'])
                    }

# %%
# Define the objective function for optimization
def objective(params):   
    print ('Params testing: ', params)

    # Split dataset into training validation sets
    inp_train, inp_valid, lbl_train, lbl_valid = train_test_split(texts_train, labels_train, 
                                                                  test_size=0.15, 
                                                                  random_state=12345, 
                                                                  stratify=labels_train)
    
    # Compute class weights for compensation the imbalance in classes
    class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes = np.unique(lbl_train), y = lbl_train)
    class_weights = dict(zip(np.unique(lbl_train), class_weights))

    # Set vectorizer
    if params['vectorizer']=='tfidf':
        vectorizer = TfidfVectorizer(max_features=params['max_features'], lowercase=True, analyzer='word', dtype=np.float32)
    elif params['vectorizer']=='count':
        vectorizer = CountVectorizer()
    else:
        sys.exit("Unsupported vectorizer!")

    # Fit vectorizer
    vectorizer.fit(inp_train)
    features_train = vectorizer.transform(inp_train)
    features_valid = vectorizer.transform(inp_valid)

    # Define the model
    model = KNeighborsClassifier(n_neighbors=2*params['n_neighbors']+1, leaf_size=params['leaf_size'], weights=params['weights'], algorithm='auto')    
    
    # Fit the model
    model.fit(features_train, lbl_train)

    # Compute performance of the trial
    pred_scores = (model.predict(features_valid) > 0.5).astype("int32")
    f1 = f1_score(lbl_valid, pred_scores)
    print('DONE!      F1 = ' + str(f1))
    sys.stdout.flush() 
    return {'loss': -f1, 'status': STATUS_OK}

# %% [markdown]
# ## Run Bayesian optimization with Tree Parzen Estimator

# %%
trials = Trials()
best = fmin(objective, hyperparam_space, algo=tpe.suggest, max_evals=1e3, trials=trials)
print('Best hyperparams: ', best)
# Out:
# Params testing:
# {'leaf_size': 156, 'max_features': 149724, 'n_neighbors': 5, 'p': 2, 'vectorizer': 'count', 'weights': 'distance'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size':
 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 130, 'max_features': 116732, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 40, 'max_features': 125968, 'n_neighbors': 4, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 88, 'max_features': 223672, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 105, 'max_features': 81232, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 55, 'max_features': 431063, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 55, 'max_features': 432172, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'count', 'weights': 'uniform'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 50, 'max_features': 381202, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 159, 'max_features': 88052, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 109, 'max_features': 60861, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 107, 'max_features': 61190, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 116, 'max_features': 70132, 'n_neighbors': 3, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 59, 'max_features': 498924, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 223, 'max_features': 123447, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 38, 'max_features': 80624, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 34, 'max_features': 194390, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 924, 'max_features': 203234, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 183, 'max_features': 172138, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'count', 'weights': 'uniform'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 81, 'max_features': 263628, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 194, 'max_features': 327453, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 41, 'max_features': 72236, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 51, 'max_features': 218893, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 63, 'max_features': 217169, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 30, 'max_features': 357255, 'n_neighbors': 3, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 28, 'max_features': 464752, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 27, 'max_features': 146462, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 786, 'max_features': 52524, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 42, 'max_features': 453329, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'count', 'weights': 'uniform'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 743, 'max_features': 239604, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 134, 'max_features': 155013, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 46, 'max_features': 406851, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 127, 'max_features': 64950, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 129, 'max_features': 70490, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 49, 'max_features': 409874, 'n_neighbors': 2, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 115, 'max_features': 159243, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 146, 'max_features': 158687, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 272, 'max_features': 62013, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 214, 'max_features': 85621, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'count', 'weights': 'distance'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 954, 'max_features': 101412, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 145, 'max_features': 379452, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 25, 'max_features': 164746, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 73, 'max_features': 150626, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 75, 'max_features': 147183, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 77, 'max_features': 179096, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 295, 'max_features': 77242, 'n_neighbors': 3, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 667, 'max_features': 67698, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 245, 'max_features': 85651, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 30, 'max_features': 55820, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'count', 'weights': 'uniform'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 463, 'max_features': 54180, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 134, 'max_features': 342581, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 153, 'max_features': 354579, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 152, 'max_features': 323125, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 41, 'max_features': 281200, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 608, 'max_features': 388072, 'n_neighbors': 2, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 598, 'max_features': 310255, 'n_neighbors': 5, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.27692307692307694
# Params testing:
# {'leaf_size': 34, 'max_features': 256078, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 44, 'max_features': 285773, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 136, 'max_features': 302257, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 863, 'max_features': 190822, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'count', 'weights': 'distance'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 87, 'max_features': 498454, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 798, 'max_features': 181034, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 771, 'max_features': 195969, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 625, 'max_features': 185861, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 478, 'max_features': 52032, 'n_neighbors': 3, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 218, 'max_features': 93768, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 112, 'max_features': 90749, 'n_neighbors': 6, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.27692307692307694
# Params testing:
# {'leaf_size': 261, 'max_features': 102976, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 83, 'max_features': 53328, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'count', 'weights': 'uniform'}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'leaf_size': 68, 'max_features': 477000, 'n_neighbors': 4, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'leaf_size': 27, 'max_features': 172176, 'n_neighbors': 2, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.19354838709677416
# Params testing:
# {'leaf_size': 35, 'max_features': 164606, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 707, 'max_features': 200912, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 689, 'max_features': 196878, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 877, 'max_features': 205920, 'n_neighbors': 4, 'p': 1, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.0
# Params testing:
# {'leaf_size': 57, 'max_features': 428485, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'uniform'}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'leaf_size': 970, 'max_features': 189949, 'n_neighbors': 3, 'p': 2, 'vectorizer': 'tfidf', 'weights': 'distance'}
# DONE!      F1 = 0.30303030303030304
# 100%|██████████| 1000/1000.0 [07:48<00:00,  2.13it/s, best loss: -0.30303030303030304]
# Best hyperparams:  {'leaf_size': 97.0, 'max_features': 361035.0, 'n_neighbors': 3.0, 'p': 1, 'vectorizer': 0, 'weights': 1}
