# %% [markdown]
# # Tuning the SVM classifier
#
# Hyperparameter sweep for the **support vector machine classifier** for producing results with various **degrees of dataset imbalance**. Optimize the hyperparameters for the worst-case imbalance configuration. Optimization conducted by means of the tree-structured Parzen estimator.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import copy

# %%
# Sci-kit learn for machine learning tasks
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.svm import SVC

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# HyperOptfor Bayesian optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
import sys

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# ## Load and process data

# %%
# Load training set
train_set_file  = "train_set_imb_0.csv"
train_set = pd.read_csv(train_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])

# %% [markdown]
# ## Define hyperparameter search space and objective function

# %%
# Define the search space for hyperparameterss
hyperparam_space = {'max_features': scope.int(hp.qloguniform('max_features', np.log(1e3), np.log(1e5), q=1)),
                    'c_param': hp.loguniform('c_param', np.log(1), np.log(1e3)),
                    'vectorizer': hp.choice('vectorizer', ['tfidf', 'count']),
                    }

# %%
# Define the objective function for optimization
def objective(params):   
    print ('Params testing: ', params)

    # Split dataset into training validation sets
    inp_train, inp_valid, lbl_train, lbl_valid = train_test_split(texts_train, labels_train, 
                                                                  test_size=0.15, 
                                                                  random_state=12345, 
                                                                  stratify=labels_train)
    
    # Compute class weights for compensation the imbalance in classes
    class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes = np.unique(lbl_train), y = lbl_train)
    class_weights = dict(zip(np.unique(lbl_train), class_weights))

    # Set vectorizer
    if params['vectorizer']=='tfidf':
        vectorizer = TfidfVectorizer(max_features=params['max_features'], lowercase=True, analyzer='word', dtype=np.float32)
    elif params['vectorizer']=='count':
        vectorizer = CountVectorizer()
    else:
        sys.exit("Unsupported vectorizer!")

    # Fit vectorizer
    vectorizer.fit(inp_train)
    features_train = vectorizer.transform(inp_train)
    features_valid = vectorizer.transform(inp_valid)

    # Define the model
    model = SVC(kernel='linear', C=params['c_param'], gamma='auto', class_weight=class_weights)

    # Fit the model
    model.fit(features_train, lbl_train)

    # Compute performance of the trial
    pred_scores = (model.predict(features_valid) > 0.5).astype("int32")
    f1 = f1_score(lbl_valid, pred_scores)
    print('DONE!      F1 = ' + str(f1))
    sys.stdout.flush() 
    return {'loss': -f1, 'status': STATUS_OK}

# %% [markdown]
# ## Run Bayesian optimization with Tree Parzen Estimator

# %%
trials = Trials()
best = fmin(objective, hyperparam_space, algo=tpe.suggest, max_evals=500, trials=trials)
print('Best hyperparams: ', best)
# Out:
# Params testing:
# {'c_param': 982.7619957471281, 'max_features': 1609, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6065573770491803
# Params testing:
# {'c_param': 130.75159230815453, 'max_features': 1971, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.576271186440678
# Params testing:
# {'c_param': 86.3958885700212, 'max_features': 16385, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6470588235294118
# Params testing:
# {'c_param': 2.107326861843191, 'max_features': 5221, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 408.3040682389376, 'max_features': 60024, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 46.38355710652067, 'max_features': 34388, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6470588235294118
# Params testing:
# {'c_param': 13.517291389782756, 'max_features': 2945, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 24.18851575133561, 'max_features': 3297, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 10.13396210282726, 'max_features': 6040, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6407766990291262
# Params testing:
# {'c_param':
 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 33.62062858552768, 'max_features': 5824, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6470588235294118
# Params testing:
# {'c_param': 22.83922191854022, 'max_features': 9966, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 86.21753256818666, 'max_features': 33718, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.1605824552871875, 'max_features': 7332, 'vectorizer': 'count'}
# DONE!      F1 = 0.6599999999999999
# Params testing:
# {'c_param': 1.76481645247649, 'max_features': 1430, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.459658467444736, 'max_features': 16656, 'vectorizer': 'count'}
# DONE!      F1 = 0.6732673267326733
# Params testing:
# {'c_param': 10.54343268886464, 'max_features': 12092, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 2.533973276122531, 'max_features': 4118, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.00460210842099, 'max_features': 3117, 'vectorizer': 'count'}
# DONE!      F1 = 0.6599999999999999
# Params testing:
# {'c_param': 637.713638576673, 'max_features': 1218, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.5793144963995125, 'max_features': 1081, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.3300631796417037, 'max_features': 1001, 'vectorizer': 'count'}
# DONE!      F1 = 0.6732673267326733
# Params testing:
# {'c_param': 2.0789733496879643, 'max_features': 1059, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.648745346039479, 'max_features': 1233, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 4.2582282945723335, 'max_features': 1163, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 515.8433266125668, 'max_features': 50986, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 295.54069131852583, 'max_features': 37851, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 27.214734199875153, 'max_features': 42254, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 14.50427727482092, 'max_features': 43606, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 1.1322898789029976, 'max_features': 1018, 'vectorizer': 'count'}
# DONE!      F1 = 0.6599999999999999
# Params testing:
# {'c_param': 336.90363438590805, 'max_features': 4548, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 58.21250302891876, 'max_features': 19542, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 51.76831837536791, 'max_features': 15058, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 44.18835478341192, 'max_features': 12879, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 61.59383080749675, 'max_features': 14344, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 37.9409697067054, 'max_features': 99628, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 15.86239455124001, 'max_features': 63093, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 21.081074306451722, 'max_features': 87539, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 17.677474062730287, 'max_features': 84269, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 16.06748335361651, 'max_features': 78092, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 24.884868295438338, 'max_features': 62320, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 63.01586778903164, 'max_features': 30081, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 78.34386277793753, 'max_features': 25859, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 13.537262544466582, 'max_features': 33539, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 12.093065685244799, 'max_features': 36387, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 11.618593230188111, 'max_features': 20889, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 7.125442345261628, 'max_features': 17143, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 5.912682874721547, 'max_features': 23145, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6470588235294118
# Params testing:
# {'c_param': 33.633125828999, 'max_features': 6307, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 9.558264521752625, 'max_features': 19249, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 5.90408574775398, 'max_features': 21714, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 2.873350248956162, 'max_features': 17345, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 2.580435834518221, 'max_features': 25370, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 19.49191251192223, 'max_features': 74452, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 19.984983562671047, 'max_features': 55048, 'vectorizer': 'count'}
# DONE!      F1 = 0.6799999999999999
# Params testing:
# {'c_param': 3.838374760735547, 'max_features': 2783, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6915887850467289
# Params testing:
# {'c_param': 3.9653817832133624, 'max_features': 2911, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'c_param': 259.53306585592827, 'max_features': 1377, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6333333333333333
# Params testing:
# {'c_param': 1.8638585953274949, 'max_features': 2494, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6428571428571428
# Params testing:
# {'c_param': 10.174763500753613, 'max_features': 2260, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6371681415929203
# Params testing:
# {'c_param': 2.8570908734734433, 'max_features': 2710, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6981132075471698
# Params testing:
# {'c_param': 4.610193016010433, 'max_features': 94219, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6666666666666667
# Params testing:
# {'c_param': 7.9176125360882015, 'max_features': 2650, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6728971962616823
# Params testing:
# {'c_param': 26.450102871118354, 'max_features': 3486, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'c_param': 3.6903969651747452, 'max_features': 2709, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6915887850467289
# Params testing:
# {'c_param': 2.905240899397626, 'max_features': 3746, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6422018348623852
# Params testing:
# {'c_param': 3.220571155581693, 'max_features': 4925, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6476190476190475
# Params testing:
# {'c_param': 4.383408605614125, 'max_features': 1899, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'c_param': 5.155048479977801, 'max_features': 2314, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6422018348623852
# Params testing:
# {'c_param': 3.538069069043546, 'max_features': 2878, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6728971962616823
# Params testing:
# {'c_param': 7.70873486214969, 'max_features': 1813, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6086956521739131
# Params testing:
# {'c_param': 2.241446720008373, 'max_features': 2129, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6206896551724138
# Params testing:
# {'c_param': 4.7454738303299235, 'max_features': 2539, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.679245283018868
# Params testing:
# {'c_param': 3.788607677297095, 'max_features': 3459, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'c_param': 2.54652622485626, 'max_features': 1587, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6031746031746031
# Params testing:
# {'c_param': 6.26683843544679, 'max_features': 3162, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'c_param': 5.441593320141751, 'max_features': 3776, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'c_param': 3.7750391603899907, 'max_features': 2655, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6851851851851852
# Params testing:
# {'c_param': 2.8637241508228883, 'max_features': 2712, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6981132075471698
# Params testing:
# {'c_param': 2.922370036759597, 'max_features': 2768, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6981132075471698
# Params testing:
# {'c_param': 1.265780660907473, 'max_features': 2405, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'c_param': 2.01943266563558, 'max_features': 2726, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6909090909090909
# Params testing:
# {'c_param': 2.0054417816972943, 'max_features': 3035, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'c_param': 1.467634260381262, 'max_features': 2762, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6727272727272727
# Params testing:
# {'c_param': 2.912190757603931, 'max_features': 1951, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6101694915254237
# Params testing:
# {'c_param': 2.505189925163282, 'max_features': 3316, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'c_param': 2.1403579802251698, 'max_features': 1701, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6031746031746031
# Params testing:
# {'c_param': 1.6363948931058419, 'max_features': 4235, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'c_param': 1.2367328579570807, 'max_features': 2466, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6379310344827586
# Params testing:
# {'c_param': 1.0000143040884715, 'max_features': 3631, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6379310344827586
# Params testing:
# {'c_param': 3.3436673396410135, 'max_features': 2048, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.625
# Params testing:
# {'c_param': 2.852923659475936, 'max_features': 2952, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.679245283018868
# Params testing:
# {'c_param': 1.8193104914752136, 'max_features': 4498, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'c_param': 2.3446591737777736, 'max_features': 2725, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6915887850467289
# Params testing:
# {'c_param': 2.3529380919904237, 'max_features': 2306, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6491228070175439
# Params testing:
# {'c_param': 4.232870396272616, 'max_features': 4072, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6422018348623852
# Params testing:
# {'c_param': 3.4280096573102394, 'max_features': 3433, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'c_param': 1.3565378603586036, 'max_features': 1970, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.608
# Params testing:
# {'c_param': 4.866955085133731, 'max_features': 3103, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'c_param': 1.524494793674294, 'max_features': 2432, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6428571428571428
# Params testing:
# {'c_param': 1.0275921817848028, 'max_features': 1684, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5873015873015874
# Params testing:
# {'c_param': 2.367803799688682, 'max_features': 2201, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6434782608695652
# Params testing:
# {'c_param': 2.7848711061238944, 'max_features': 3872, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'c_param': 4.193846855908797, 'max_features': 2595, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6728971962616823
# Params testing:
# {'c_param': 1.7644375639372971, 'max_features': 1508, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6031746031746031
# Params testing:
# {'c_param': 3.204796997934038, 'max_features': 4621, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'c_param': 6.653811506920848, 'max_features': 5261, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6407766990291262
# Params testing:
# {'c_param': 3.9039070764675685, 'max_features': 1819, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'c_param': 1.153448931602669, 'max_features': 3379, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6379310344827586
# Params testing:
# {'c_param': 5.664803092328134, 'max_features': 2872, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.6728971962616823
# 100%|██████████| 500/500 [05:26<00:00,  1.53it/s, best loss: -0.6981132075471698]
# Best hyperparams:  {'c_param': 2.8570908734734433, 'max_features': 2710.0, 'vectorizer': 0}
