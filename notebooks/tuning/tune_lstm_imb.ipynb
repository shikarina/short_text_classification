# %% [markdown]
# # Tuning the LSTM neural classifier
#
# Hyperparameter sweep for the **LSTM neural network classifier** for producing results with various **degrees of dataset imbalance**. Optimize the hyperparameters for the worst-case imbalance configuration. Optimization conducted by means of the tree-structured Parzen estimator.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import copy

# %%
# Sci-kit learn for machine learning tasks
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer

# %%
# TensorFlow and Keras for neural networks
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras import layers
from keras.layers.wrappers import Bidirectional
from keras.regularizers import l2
from keras import metrics
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# HyperOptfor Bayesian optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
import sys

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# # Load and process data

# %%
# Load training set
train_set_file  = "train_set_imb_0.csv"
train_set = pd.read_csv(train_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])

# %%
# Tokenize texts and get features
max_words = 5000
max_len = 55
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts_train)
sequences_train = tokenizer.texts_to_sequences(texts_train)
features_train = sequence.pad_sequences(sequences_train, maxlen=max_len, padding='post', truncating='post')

# %% [markdown]
# # Define hyperparameter search space and objective function

# %%
# Define the search space for hyperparameterss
hyperparam_space = {'n_units': scope.int(hp.quniform('n_units', 8, 256, q=1)),
         'dropout_rate': hp.uniform('dropout_rate', 0.25, 0.75),
         'l2_val': hp.loguniform('l2_val', np.log(1e-6), np.log(1e-3)),
         'embedding_dim' : scope.int(hp.quniform('emb_dim', 64, 256, q=1)),
         'max_words' : max_words,
         'max_len' : max_len,
         'share_valid': hp.uniform('share_valid', 0.1, 0.3),
         'batch_size' : scope.int(hp.quniform('batch_size', 16, 128, q=1)),
         'epochs' : scope.int(hp.quniform('epochs', 16, 128, q=1)),
         'learning_rate': hp.loguniform('learning_rate', np.log(1e-6), np.log(1e-3))
         }

# %%
# Define the objective function for optimization
def objective(params):   
    print ('Params testing: ', params)

    # Split dataset into training validation sets
    inp_train, inp_valid, lbl_train, lbl_valid = train_test_split(features_train, labels_train, 
                                                                  test_size = params['share_valid'], 
                                                                  random_state=12345, 
                                                                  stratify=labels_train)
    
    # Compute class weights for compensation the imbalance in classes
    class_weights = class_weight.compute_class_weight(class_weight = "balanced",
                                        classes = np.unique(lbl_train),
                                        y = lbl_train)
    class_weights = dict(zip(np.unique(lbl_train), class_weights))

    # Define optimizer
    opt = Adam(learning_rate=params['learning_rate'], 
                   beta_1 = 0.9,
                   beta_2 = 0.99,
                   epsilon = 1e-07,
                   amsgrad = False)

    # Define sequential neural arhitecture
    model = Sequential()
    model.add(layers.Embedding(params['max_words'], params['embedding_dim'], input_length=params['max_len']))
    model.add(Bidirectional(layers.LSTM(params['n_units'], dropout=params['dropout_rate'], recurrent_dropout=0, unroll=False, kernel_initializer='glorot_uniform')))
    model.add(layers.Dense(1, kernel_initializer='glorot_uniform', activation='sigmoid', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))

    # Build model
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=[metrics.AUC(name='auc_pr', curve="PR")])
    model.summary()

    # Fit model
    model.fit(inp_train, lbl_train, epochs=params['epochs'], batch_size=params['batch_size'], verbose = 0, class_weight=class_weights)

    # Compute performance of the trial
    pred_scores = (model.predict(inp_valid) > 0.5).astype("int32")
    f1 = f1_score(lbl_valid, pred_scores)
    print('DONE! \n F1 = ' + str(f1))
    sys.stdout.flush() 
    return {'loss': -f1, 'status': STATUS_OK}

# %% [markdown]
# # Run Bayesian optimization with Tree Parzen Estimator

# %%
trials = Trials()
best = fmin(objective, hyperparam_space, algo=tpe.suggest, max_evals=500, trials=trials)
print('Best hyperparams: ', best)
# Out:
# Params testing:
# {'batch_size': 114, 'dropout_rate': 0.6365341596419964, 'embedding_dim': 116, 'epochs': 103, 'l2_val': 0.0005813373294702327, 'learning_rate': 5.728963011201465e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 85, 'share_valid': 0.2301767548199458}
# Model: "sequential"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding (Embedding)       (None, 55, 116)           580000
#
#  bidirectional (Bidirectiona  (None, 170)              137360
#
#  l)
#
#  dense (Dense)               (None, 1)                 171
#
# =================================================================
#
# Total params: 717,531
#
# Trainable params: 717,531
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.3551401869158879
# Params testing:
# {'batch_size': 88, 'dropout_rate': 0.2878827994756361, 'embedding_dim': 103, 'epochs': 90, 'l2_val': 0.00011099808504498261, 'learning_rate': 3.782222005229568e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 254, 'share_valid': 0.21539149453539225}
# Model: "sequential_1"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_1 (Embedding)     (None, 55, 103)           515000
#
#  bidirectional_1 (Bidirectio  (None, 508)              727456
#
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 509
#
# =================================================================
#
# Total params: 1,242,965
#
# Trainable params: 1,242,965
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.6029411764705882
# Params testing:
# {'batch_size': 20, 'dropout_rate': 0.6535985717324887, 'embedding_dim': 155, 'epochs': 57, 'l2_val': 1.7499751121738984e-05, 'learning_rate': 2.1350099969627827e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 181, 'share_valid': 0.13138386358788337}
# Model: "sequential_2"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_2 (Embedding)     (None, 55, 155)           775000
#
#  bidirectional_2 (Bidirectio  (None, 362)              487976
#
#  nal)
#
#  dense_2 (Dense)             (None, 1)                 363
#
# =================================================================
#
# Total params: 1,263,339
#
# Trainable params: 1,263,339
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.30107526881720426
# Params testing:
# {'batch_size': 32, 'dropout_rate': 0.7217455626901909, 'embedding_dim': 134, 'epochs': 44, 'l2_val': 0.0009555640325608085, 'learning_rate': 0.00011191410372188308, 'max_len': 55, 'max_words': 5000, 'n_units': 111, 'share_valid': 0.14422441887322318}
# Model: "sequential_3"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_3 (Embedding)     (None, 55, 134)           670000
#
#  bidirectional_3 (Bidirectio  (None, 222)              218448
#
#  nal)
#
#  dense_3 (Dense)             (None, 1)                 223
#
# =================================================================
#
# Total params: 888,671
#
# Trainable params: 888,671
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5254237288135594
# Params testing:
# {'batch_size': 56, 'dropout_rate': 0.6405743665644916, 'embedding_dim': 232, 'epochs': 74, 'l2_val': 9.417549859735302e-05, 'learning_rate': 1.4480807669670809e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 92, 'share_valid': 0.26712480680261297}
# Model: "sequential_4"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_4 (Embedding)     (None, 55, 232)           1160000
#
#  bidirectional_4 (Bidirectio  (None, 184)              239200
#
#  nal)
#
#  dense_4 (Dense)             (None, 1)                 185
#
# =================================================================
#
# Total params: 1,399,385
#
# Trainable params: 1,399,385
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5585585585585586
# Params testing:
# {'batch_size': 77, 'dropout_rate': 0.6056439444177926, 'embedding_dim': 150, 'epochs': 94, 'l2_val': 0.0003370892089635842, 'learning_rate': 0.0008169272981617738, 'max_len': 55, 'max_words': 5000, 'n_units': 37, 'share_valid': 0.2691934781080818}
# Model: "sequential_5"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_5 (Embedding)     (None, 55, 150)           750000
#
#  bidirectional_5 (Bidirectio  (None, 74)               55648
#
#  nal)
#
#  dense_5 (Dense)             (None, 1)                 75
#
# =================================================================
#
# Total params: 805,723
#
# Trainable params: 805,723
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.6067415730337078
# Params testing:
# {'batch_size': 40, 'dropout_rate': 0.3883770734176155, 'embedding_dim': 176, 'epochs': 36, 'l2_val': 1.0487187333265885e-05, 'learning_rate': 1.1529294518614372e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 200, 'share_valid': 0.15854658276280384}
# Model: "sequential_6"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_6 (Embedding)     (None, 55, 176)           880000
#
#  bidirectional_6 (Bidirectio  (None, 400)              603200
#
#  nal)
#
#  dense_6 (Dense)             (None, 1)                 401
#
# =================================================================
#
# Total params: 1,483,601
#
# Trainable params: 1,483,601
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.2608695652173913
# Params testing:
# {'batch_size': 99, 'dropout_rate': 0.7372450464923421, 'embedding_dim': 191, 'epochs': 61, 'l2_val': 1.1878203215144326e-05, 'learning_rate': 0.00015722336122080867, 'max_len': 55, 'max_words': 5000, 'n_units': 175, 'share_valid': 0.17534831527413633}
# Model: "sequential_7"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_7 (Embedding)     (None, 55, 191)           955000
#
#  bidirectional_7 (Bidirectio  (None, 350)              513800
#
#  nal)
#
#  dense_7 (Dense)             (None, 1)                 351
#
# =================================================================
#
# Total params: 1,469,151
#
# Trainable params: 1,469,151
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5166666666666667
# Params testing:
# {'batch_size': 105, 'dropout_rate': 0.6422285021300681, 'embedding_dim': 173, 'epochs': 32, 'l2_val': 1.447480001227133e-06, 'learning_rate': 7.508952541397965e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 112, 'share_valid': 0.29828510864696034}
# Model: "sequential_8"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_8 (Embedding)     (None, 55, 173)           865000
#
#  bidirectional_8 (Bidirectio  (None, 224)              256256
#
#  nal)
#
#  dense_8 (Dense)             (None, 1)                 225
#
# =================================================================
#
# Total params: 1,121,481
#
# Trainable params: 1,121,481
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.30405405405405406
# Params testing:
# {'batch_size': 57, 'dropout_rate': 0.7296348714258982, 'embedding_dim': 98, 'epochs': 57, 'l2_val': 4.197194502538495e-06, 'learning_rate': 2.953050741559859e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 47, 'share_valid': 0.13144173714086085}
# Model: "sequential_9"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_9 (Embedding)     (None, 55, 98)            490000
#
#  bidirectional_9 (Bidirectio  (None, 94)               54896
#
#  nal)
#
#  dense_9 (Dense)             (None, 1)                 95
#
# =================================================================
#
# Total params: 544,991
#
# Trainable params: 544,991
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.3636363636363636
# Params testing:
# {'batch_size': 96, 'dropout_rate': 0.4864823856337103, 'embedding_dim': 242, 'epochs': 77, 'l2_val': 3.6688691316841383e-05, 'learning_rate': 1.690174894943233e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 131, 'share_valid': 0.23869498396495992}
# Model: "sequential_10"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_10 (Embedding)    (None, 55, 242)           1210000
#
#  bidirectional_10 (Bidirecti  (None, 262)              391952
#
#  onal)
#
#  dense_10 (Dense)            (None, 1)                 263
#
# =================================================================
#
# Total params: 1,602,215
#
# Trainable params: 1,602,215
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5104166666666667
# Params testing:
# {'batch_size': 86, 'dropout_rate': 0.6906822765882632, 'embedding_dim': 153, 'epochs': 77, 'l2_val': 9.969317103619249e-05, 'learning_rate': 8.230688663988356e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 13, 'share_valid': 0.1941271508657668}
# Model: "sequential_11"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_11 (Embedding)    (None, 55, 153)           765000
#
#  bidirectional_11 (Bidirecti  (None, 26)               17368
#
#  onal)
#
#  dense_11 (Dense)            (None, 1)                 27
#
# =================================================================
#
# Total params: 782,395
#
# Trainable params: 782,395
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.41935483870967744
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.4059440649233314, 'embedding_dim': 154, 'epochs': 66, 'l2_val': 4.282599173748271e-05, 'learning_rate': 0.0001689584676295742, 'max_len': 55, 'max_words': 5000, 'n_units': 86, 'share_valid': 0.27752915760596425}
# Model: "sequential_12"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_12 (Embedding)    (None, 55, 154)           770000
#
#  bidirectional_12 (Bidirecti  (None, 172)              165808
#
#  onal)
#
#  dense_12 (Dense)            (None, 1)                 173
#
# =================================================================
#
# Total params: 935,981
#
# Trainable params: 935,981
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5842696629213484
# Params testing:
# {'batch_size': 120, 'dropout_rate': 0.3622087668441023, 'embedding_dim': 162, 'epochs': 36, 'l2_val': 1.0400903049133978e-05, 'learning_rate': 0.00018739634974921767, 'max_len': 55, 'max_words': 5000, 'n_units': 247, 'share_valid': 0.23809076646602903}
# Model: "sequential_13"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_13 (Embedding)    (None, 55, 162)           810000
#
#  bidirectional_13 (Bidirecti  (None, 494)              810160
#
#  onal)
#
#  dense_13 (Dense)            (None, 1)                 495
#
# =================================================================
#
# Total params: 1,620,655
#
# Trainable params: 1,620,655
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5185185185185185
# Params testing:
# {'batch_size': 107, 'dropout_rate': 0.26622831958947846, 'embedding_dim': 242, 'epochs': 63, 'l2_val': 0.0005034905553112324, 'learning_rate': 5.752158343809962e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 54, 'share_valid': 0.10722270616393062}
# Model: "sequential_14"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_14 (Embedding)    (None, 55, 242)           1210000
#
#  bidirectional_14 (Bidirecti  (None, 108)              128304
#
#  onal)
#
#  dense_14 (Dense)            (None, 1)                 109
#
# =================================================================
#
# Total params: 1,338,413
#
# Trainable params: 1,338,413
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.4838709677419355
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.5986751382768406, 'embedding_dim': 170, 'epochs': 41, 'l2_val': 1.7013835950605228e-05, 'learning_rate': 1.7115124989350982e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 235, 'share_valid': 0.14606677173896793}
# Model: "sequential_15"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_15 (Embedding)    (None, 55, 170)           850000
#
#  bidirectional_15 (Bidirecti  (None, 470)              763280
#
#  onal)
#
#  dense_15 (Dense)            (None, 1)                 471
#
# =================================================================
#
# Total params: 1,613,751
#
# Trainable params: 1,613,751
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.2616822429906542
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.3079751438362156, 'embedding_dim': 67, 'epochs': 99, 'l2_val': 1.2544866972616266e-05, 'learning_rate': 0.00022150139692794007, 'max_len': 55, 'max_words': 5000, 'n_units': 127, 'share_valid': 0.22229313877073265}
# Model: "sequential_16"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_16 (Embedding)    (None, 55, 67)            335000
#
#  bidirectional_16 (Bidirecti  (None, 254)              198120
#
#  onal)
#
#  dense_16 (Dense)            (None, 1)                 255
#
# =================================================================
#
# Total params: 533,375
#
# Trainable params: 533,375
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.6068965517241379
# Params testing:
# {'batch_size': 120, 'dropout_rate': 0.5704973971069448, 'embedding_dim': 96, 'epochs': 113, 'l2_val': 0.00034098761308587786, 'learning_rate': 0.00021296491870052188, 'max_len': 55, 'max_words': 5000, 'n_units': 246, 'share_valid': 0.11145145834439361}
# Model: "sequential_17"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_17 (Embedding)    (None, 55, 96)            480000
#
#  bidirectional_17 (Bidirecti  (None, 492)              675024
#
#  onal)
#
#  dense_17 (Dense)            (None, 1)                 493
#
# =================================================================
#
# Total params: 1,155,517
#
# Trainable params: 1,155,517
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.48275862068965514
# Params testing:
# {'batch_size': 42, 'dropout_rate': 0.3834821315025186, 'embedding_dim': 74, 'epochs': 60, 'l2_val': 3.2032893067458914e-05, 'learning_rate': 5.155726946968915e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 105, 'share_valid': 0.22785459100006558}
# Model: "sequential_18"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_18 (Embedding)    (None, 55, 74)            370000
#
#  bidirectional_18 (Bidirecti  (None, 210)              151200
#
#  onal)
#
#  dense_18 (Dense)            (None, 1)                 211
#
# =================================================================
#
# Total params: 521,411
#
# Trainable params: 521,411
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5986394557823129
# Params testing:
# {'batch_size': 103, 'dropout_rate': 0.747003257944618, 'embedding_dim': 242, 'epochs': 109, 'l2_val': 0.00012430274193004652, 'learning_rate': 4.918230163286221e-06, 'max_len': 55, 'max_words': 5000, 'n_units': 133, 'share_valid': 0.25314966093327274}
# Model: "sequential_19"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_19 (Embedding)    (None, 55, 242)           1210000
#
#  bidirectional_19 (Bidirecti  (None, 266)              400064
#
#  onal)
#
#  dense_19 (Dense)            (None, 1)                 267
#
# =================================================================
#
# Total params: 1,610,331
#
# Trainable params: 1,610,331
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.3815028901734104
# Params testing:
# {'batch_size': 65, 'dropout_rate': 0.5136227986699707, 'embedding_dim': 66, 'epochs': 122, 'l2_val': 3.4471386635311292e-06, 'learning_rate': 0.0009224342662915205, 'max_len': 55, 'max_words': 5000, 'n_units': 18, 'share_valid': 0.2974390443550534}
# Model: "sequential_20"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_20 (Embedding)    (None, 55, 66)            330000
#
#  bidirectional_20 (Bidirecti  (None, 36)               12240
#
#  onal)
#
#  dense_20 (Dense)            (None, 1)                 37
#
# =================================================================
#
# Total params: 342,277
#
# Trainable params: 342,277
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.46078431372549017
# Params testing:
# {'batch_size': 72, 'dropout_rate': 0.4717215523151984, 'embedding_dim': 208, 'epochs': 92, 'l2_val': 4.2052749230671485e-06, 'learning_rate': 0.0009025100384432274, 'max_len': 55, 'max_words': 5000, 'n_units': 50, 'share_valid': 0.20298208336619306}
# Model: "sequential_21"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_21 (Embedding)    (None, 55, 208)           1040000
#
#  bidirectional_21 (Bidirecti  (None, 100)              103600
#
#  onal)
#
#  dense_21 (Dense)            (None, 1)                 101
#
# =================================================================
#
# Total params: 1,143,701
#
# Trainable params: 1,143,701
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.6259541984732825
# Params testing:
# {'batch_size': 62, 'dropout_rate': 0.45488880995661174, 'embedding_dim': 210, 'epochs': 17, 'l2_val': 1.0770171475780948e-06, 'learning_rate': 0.0004610274883814017, 'max_len': 55, 'max_words': 5000, 'n_units': 151, 'share_valid': 0.1924130043021409}
# Model: "sequential_22"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_22 (Embedding)    (None, 55, 210)           1050000
#
#  bidirectional_22 (Bidirecti  (None, 302)              437296
#
#  onal)
#
#  dense_22 (Dense)            (None, 1)                 303
#
# =================================================================
#
# Total params: 1,487,599
#
# Trainable params: 1,487,599
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.48484848484848486
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.3118017696425667, 'embedding_dim': 213, 'epochs': 127, 'l2_val': 3.714033619625275e-06, 'learning_rate': 0.0004396216886742065, 'max_len': 55, 'max_words': 5000, 'n_units': 66, 'share_valid': 0.20816192542513368}
# Model: "sequential_23"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_23 (Embedding)    (None, 55, 213)           1065000
#
#  bidirectional_23 (Bidirecti  (None, 132)              147840
#
#  onal)
#
#  dense_23 (Dense)            (None, 1)                 133
#
# =================================================================
#
# Total params: 1,212,973
#
# Trainable params: 1,212,973
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5343511450381679
# Params testing:
# {'batch_size': 45, 'dropout_rate': 0.3378443950280993, 'embedding_dim': 197, 'epochs': 92, 'l2_val': 1.8044968730685104e-06, 'learning_rate': 7.370482800645708e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 216, 'share_valid': 0.17705459166168308}
# Model: "sequential_24"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_24 (Embedding)    (None, 55, 197)           985000
#
#  bidirectional_24 (Bidirecti  (None, 432)              715392
#
#  onal)
#
#  dense_24 (Dense)            (None, 1)                 433
#
# =================================================================
#
# Total params: 1,700,825
#
# Trainable params: 1,700,825
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5294117647058824
# Params testing:
# {'batch_size': 51, 'dropout_rate': 0.5141623741817879, 'embedding_dim': 217, 'epochs': 85, 'l2_val': 5.692496218731091e-06, 'learning_rate': 0.00042338265836071374, 'max_len': 55, 'max_words': 5000, 'n_units': 157, 'share_valid': 0.17818167955778702}
# Model: "sequential_25"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_25 (Embedding)    (None, 55, 217)           1085000
#
#  bidirectional_25 (Bidirecti  (None, 314)              471000
#
#  onal)
#
#  dense_25 (Dense)            (None, 1)                 315
#
# =================================================================
#
# Total params: 1,556,315
#
# Trainable params: 1,556,315
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5984251968503937
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.43400182724536734, 'embedding_dim': 256, 'epochs': 101, 'l2_val': 1.9042662529923786e-06, 'learning_rate': 0.0007195467359140405, 'max_len': 55, 'max_words': 5000, 'n_units': 69, 'share_valid': 0.21767130878875218}
# Model: "sequential_26"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_26 (Embedding)    (None, 55, 256)           1280000
#
#  bidirectional_26 (Bidirecti  (None, 138)              179952
#
#  onal)
#
#  dense_26 (Dense)            (None, 1)                 139
#
# =================================================================
#
# Total params: 1,460,091
#
# Trainable params: 1,460,091
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5882352941176471
# Params testing:
# {'batch_size': 34, 'dropout_rate': 0.250510896262644, 'embedding_dim': 134, 'epochs': 113, 'l2_val': 7.172227902016965e-06, 'learning_rate': 0.0002896290410403184, 'max_len': 55, 'max_words': 5000, 'n_units': 29, 'share_valid': 0.25377391303356245}
# Model: "sequential_27"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_27 (Embedding)    (None, 55, 134)           670000
#
#  bidirectional_27 (Bidirecti  (None, 58)               38048
#
#  onal)
#
#  dense_27 (Dense)            (None, 1)                 59
#
# =================================================================
#
# Total params: 708,107
#
# Trainable params: 708,107
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5398773006134969
# Params testing:
# {'batch_size': 91, 'dropout_rate': 0.5532276476264203, 'embedding_dim': 188, 'epochs': 103, 'l2_val': 2.5433404914337206e-06, 'learning_rate': 9.429712043547253e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 133, 'share_valid': 0.19329071875238998}
# Model: "sequential_28"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_28 (Embedding)    (None, 55, 188)           940000
#
#  bidirectional_28 (Bidirecti  (None, 266)              342608
#
#  onal)
#
#  dense_28 (Dense)            (None, 1)                 267
#
# =================================================================
#
# Total params: 1,282,875
#
# Trainable params: 1,282,875
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5
# Params testing:
# {'batch_size': 22, 'dropout_rate': 0.4551912243445351, 'embedding_dim': 81, 'epochs': 120, 'l2_val': 1.900284867807216e-05, 'learning_rate': 0.0009679769904668248, 'max_len': 55, 'max_words': 5000, 'n_units': 166, 'share_valid': 0.22448426029142088}
# Model: "sequential_29"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_29 (Embedding)    (None, 55, 81)            405000
#
#  bidirectional_29 (Bidirecti  (None, 332)              329344
#
#  onal)
#
#  dense_29 (Dense)            (None, 1)                 333
#
# =================================================================
#
# Total params: 734,677
#
# Trainable params: 734,677
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.45871559633027525
# Params testing:
# {'batch_size': 113, 'dropout_rate': 0.31356875962997266, 'embedding_dim': 127, 'epochs': 85, 'l2_val': 1.0331891711715783e-06, 'learning_rate': 3.7652454906824834e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 68, 'share_valid': 0.21127270003219342}
# Model: "sequential_30"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_30 (Embedding)    (None, 55, 127)           635000
#
#  bidirectional_30 (Bidirecti  (None, 136)              106624
#
#  onal)
#
#  dense_30 (Dense)            (None, 1)                 137
#
# =================================================================
#
# Total params: 741,761
#
# Trainable params: 741,761
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.583941605839416
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.4189503984060472, 'embedding_dim': 224, 'epochs': 97, 'l2_val': 7.002536783105311e-05, 'learning_rate': 2.4176994171105486e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 197, 'share_valid': 0.16413936842499946}
# Model: "sequential_31"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_31 (Embedding)    (None, 55, 224)           1120000
#
#  bidirectional_31 (Bidirecti  (None, 394)              665072
#
#  onal)
#
#  dense_31 (Dense)            (None, 1)                 395
#
# =================================================================
#
# Total params: 1,785,467
#
# Trainable params: 1,785,467
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.591304347826087
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.2847124409254914, 'embedding_dim': 112, 'epochs': 87, 'l2_val': 5.93274985741929e-06, 'learning_rate': 0.00030246490654901404, 'max_len': 55, 'max_words': 5000, 'n_units': 99, 'share_valid': 0.20314763303628108}
# Model: "sequential_32"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_32 (Embedding)    (None, 55, 112)           560000
#
#  bidirectional_32 (Bidirecti  (None, 198)              167904
#
#  onal)
#
#  dense_32 (Dense)            (None, 1)                 199
#
# =================================================================
#
# Total params: 728,103
#
# Trainable params: 728,103
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5255474452554746
# Params testing:
# {'batch_size': 51, 'dropout_rate': 0.34738650549138395, 'embedding_dim': 253, 'epochs': 70, 'l2_val': 1.9151314031499596e-05, 'learning_rate': 0.0005511699384705336, 'max_len': 55, 'max_words': 5000, 'n_units': 123, 'share_valid': 0.24791173355471224}
# Model: "sequential_33"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_33 (Embedding)    (None, 55, 253)           1265000
#
#  bidirectional_33 (Bidirecti  (None, 246)              370968
#
#  onal)
#
#  dense_33 (Dense)            (None, 1)                 247
#
# =================================================================
#
# Total params: 1,636,215
#
# Trainable params: 1,636,215
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5764705882352941
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.4813706625763488, 'embedding_dim': 206, 'epochs': 48, 'l2_val': 0.0001632040482346818, 'learning_rate': 6.154308660534538e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 146, 'share_valid': 0.28130726927657784}
# Model: "sequential_34"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_34 (Embedding)    (None, 55, 206)           1030000
#
#  bidirectional_34 (Bidirecti  (None, 292)              412304
#
#  onal)
#
#  dense_34 (Dense)            (None, 1)                 293
#
# =================================================================
#
# Total params: 1,442,597
#
# Trainable params: 1,442,597
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5549738219895288
# Params testing:
# {'batch_size': 92, 'dropout_rate': 0.6835000890546837, 'embedding_dim': 140, 'epochs': 106, 'l2_val': 4.813925290157665e-05, 'learning_rate': 0.00011303201594173816, 'max_len': 55, 'max_words': 5000, 'n_units': 76, 'share_valid': 0.1837864743815265}
# Model: "sequential_35"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_35 (Embedding)    (None, 55, 140)           700000
#
#  bidirectional_35 (Bidirecti  (None, 152)              131936
#
#  onal)
#
#  dense_35 (Dense)            (None, 1)                 153
#
# =================================================================
#
# Total params: 832,089
#
# Trainable params: 832,089
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5362318840579711
# Params testing:
# {'batch_size': 25, 'dropout_rate': 0.5413501077387447, 'embedding_dim': 183, 'epochs': 81, 'l2_val': 1.242243789630207e-05, 'learning_rate': 0.0003084656502210301, 'max_len': 55, 'max_words': 5000, 'n_units': 36, 'share_valid': 0.16600397371706752}
# Model: "sequential_36"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_36 (Embedding)    (None, 55, 183)           915000
#
#  bidirectional_36 (Bidirecti  (None, 72)               63360
#
#  onal)
#
#  dense_36 (Dense)            (None, 1)                 73
#
# =================================================================
#
# Total params: 978,433
#
# Trainable params: 978,433
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.4705882352941177
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.615101111071663, 'embedding_dim': 198, 'epochs': 97, 'l2_val': 7.569169951594104e-06, 'learning_rate': 0.00011691673577554798, 'max_len': 55, 'max_words': 5000, 'n_units': 190, 'share_valid': 0.15103947552642494}
# Model: "sequential_37"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_37 (Embedding)    (None, 55, 198)           990000
#
#  bidirectional_37 (Bidirecti  (None, 380)              591280
#
#  onal)
#
#  dense_37 (Dense)            (None, 1)                 381
#
# =================================================================
#
# Total params: 1,581,661
#
# Trainable params: 1,581,661
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5806451612903226
# Params testing:
# {'batch_size': 32, 'dropout_rate': 0.3144903980905591, 'embedding_dim': 89, 'epochs': 126, 'l2_val': 2.3903339047266074e-05, 'learning_rate': 0.0007040062573551945, 'max_len': 55, 'max_words': 5000, 'n_units': 54, 'share_valid': 0.2620076583601058}
# Model: "sequential_38"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_38 (Embedding)    (None, 55, 89)            445000
#
#  bidirectional_38 (Bidirecti  (None, 108)              62208
#
#  onal)
#
#  dense_38 (Dense)            (None, 1)                 109
#
# =================================================================
#
# Total params: 507,317
#
# Trainable params: 507,317
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5549132947976878
# Params testing:
# {'batch_size': 81, 'dropout_rate': 0.3746369365932518, 'embedding_dim': 116, 'epochs': 115, 'l2_val': 5.568241351550615e-05, 'learning_rate': 3.124019509272098e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 215, 'share_valid': 0.13567225278352082}
# Model: "sequential_39"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_39 (Embedding)    (None, 55, 116)           580000
#
#  bidirectional_39 (Bidirecti  (None, 430)              571040
#
#  onal)
#
#  dense_39 (Dense)            (None, 1)                 431
#
# =================================================================
#
# Total params: 1,151,471
#
# Trainable params: 1,151,471
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5806451612903226
# Params testing:
# {'batch_size': 127, 'dropout_rate': 0.45222766080340376, 'embedding_dim': 233, 'epochs': 52, 'l2_val': 0.000999768602180011, 'learning_rate': 0.00023529127631333625, 'max_len': 55, 'max_words': 5000, 'n_units': 93, 'share_valid': 0.2366442144201506}
# Model: "sequential_40"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_40 (Embedding)    (None, 55, 233)           1165000
#
#  bidirectional_40 (Bidirecti  (None, 186)              243288
#
#  onal)
#
#  dense_40 (Dense)            (None, 1)                 187
#
# =================================================================
#
# Total params: 1,408,475
#
# Trainable params: 1,408,475
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5256410256410257
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.41395354655673267, 'embedding_dim': 162, 'epochs': 74, 'l2_val': 2.642687852578854e-06, 'learning_rate': 1.5158326345274647e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 183, 'share_valid': 0.2187773203914649}
# Model: "sequential_41"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_41 (Embedding)    (None, 55, 162)           810000
#
#  bidirectional_41 (Bidirecti  (None, 366)              506544
#
#  onal)
#
#  dense_41 (Dense)            (None, 1)                 367
#
# =================================================================
#
# Total params: 1,316,911
#
# Trainable params: 1,316,911
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5644171779141104
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.2799383904894116, 'embedding_dim': 144, 'epochs': 24, 'l2_val': 4.724542555441922e-06, 'learning_rate': 0.0006616180598998553, 'max_len': 55, 'max_words': 5000, 'n_units': 123, 'share_valid': 0.1203895452654521}
# Model: "sequential_42"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_42 (Embedding)    (None, 55, 144)           720000
#
#  bidirectional_42 (Bidirecti  (None, 246)              263712
#
#  onal)
#
#  dense_42 (Dense)            (None, 1)                 247
#
# =================================================================
#
# Total params: 983,959
#
# Trainable params: 983,959
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.6
# Params testing:
# {'batch_size': 73, 'dropout_rate': 0.5892839426974832, 'embedding_dim': 183, 'epochs': 69, 'l2_val': 8.567825057539453e-06, 'learning_rate': 0.0009823029429937772, 'max_len': 55, 'max_words': 5000, 'n_units': 81, 'share_valid': 0.20132240169920437}
# Model: "sequential_43"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_43 (Embedding)    (None, 55, 183)           915000
#
#  bidirectional_43 (Bidirecti  (None, 162)              171720
#
#  onal)
#
#  dense_43 (Dense)            (None, 1)                 163
#
# =================================================================
#
# Total params: 1,086,883
#
# Trainable params: 1,086,883
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.525
# Params testing:
# {'batch_size': 100, 'dropout_rate': 0.6854932032364738, 'embedding_dim': 226, 'epochs': 90, 'l2_val': 0.00018404484273311467, 'learning_rate': 0.00015695607369741244, 'max_len': 55, 'max_words': 5000, 'n_units': 9, 'share_valid': 0.290518269385485}
# Model: "sequential_44"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_44 (Embedding)    (None, 55, 226)           1130000
#
#  bidirectional_44 (Bidirecti  (None, 18)               16992
#
#  onal)
#
#  dense_44 (Dense)            (None, 1)                 19
#
# =================================================================
#
# Total params: 1,147,011
#
# Trainable params: 1,147,011
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.46153846153846156
# Params testing:
# {'batch_size': 46, 'dropout_rate': 0.34918479775802963, 'embedding_dim': 201, 'epochs': 119, 'l2_val': 1.3786851052128592e-05, 'learning_rate': 4.768070213687885e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 21, 'share_valid': 0.24431438853368895}
# Model: "sequential_45"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_45 (Embedding)    (None, 55, 201)           1005000
#
#  bidirectional_45 (Bidirecti  (None, 42)               37464
#
#  onal)
#
#  dense_45 (Dense)            (None, 1)                 43
#
# =================================================================
#
# Total params: 1,042,507
#
# Trainable params: 1,042,507
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5503355704697986
# Params testing:
# {'batch_size': 68, 'dropout_rate': 0.4801610014587596, 'embedding_dim': 169, 'epochs': 81, 'l2_val': 1.4573094680065017e-06, 'learning_rate': 1.0457277463344194e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 45, 'share_valid': 0.26326247220806187}
# Model: "sequential_46"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_46 (Embedding)    (None, 55, 169)           845000
#
#  bidirectional_46 (Bidirecti  (None, 90)               77400
#
#  onal)
#
#  dense_46 (Dense)            (None, 1)                 91
#
# =================================================================
#
# Total params: 922,491
#
# Trainable params: 922,491
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5277777777777778
# Params testing:
# {'batch_size': 37, 'dropout_rate': 0.5409951046599293, 'embedding_dim': 234, 'epochs': 96, 'l2_val': 2.682604233073478e-05, 'learning_rate': 8.184131549170674e-05, 'max_len': 55, 'max_words': 5000, 'n_units': 170, 'share_valid': 0.23363069182309315}
# Model: "sequential_47"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_47 (Embedding)    (None, 55, 234)           1170000
#
#  bidirectional_47 (Bidirecti  (None, 340)              550800
#
#  onal)
#
#  dense_47 (Dense)            (None, 1)                 341
#
# =================================================================
#
# Total params: 1,721,141
#
# Trainable params: 1,721,141
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
# DONE!
#  F1 = 0.5325443786982248
# Params testing:
# {'batch_size': 16, 'dropout_rate': 0.2589730165310159, 'embedding_dim': 219, 'epochs': 108, 'l2_val': 7.101193109167185e-05, 'learning_rate': 0.00036880609604001286, 'max_len': 55, 'max_words': 5000, 'n_units': 213, 'share_valid': 0.18597551476834323}
# Model: "sequential_48"
#
# _________________________________________________________________
#
#  Layer (type)                Output Shape              Param #
#
# =================================================================
#
#  embedding_48 (Embedding)    (None, 55, 219)           1095000
#
#  bidirectional_48 (Bidirecti  (None, 426)              737832
#
#  onal)
#
#  dense_48 (Dense)            (None, 1)                 427
#
# =================================================================
#
# Total params: 1,833,259
#
# Trainable params: 1,833,259
#
# Non-trainable params: 0
#
# _________________________________________________________________
#
#  10%|▉         | 48/500 [49:53<8:46:55, 69.95s/it, best loss: -0.6259541984732825]
