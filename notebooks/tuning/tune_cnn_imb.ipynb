# %% [markdown]
# # Tuning the CNN neural classifier
#
# Hyperparameter sweep for the **convolutional neural network classifier** for producing results with various **degrees of dataset imbalance**. Optimize the hyperparameters for the worst-case imbalance configuration. Optimization conducted by means of the tree-structured Parzen estimator.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import copy

# %%
# Sci-kit learn for machine learning tasks
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer

# %%
# TensorFlow and Keras for neural networks
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras import layers
from keras.regularizers import l2
from keras import metrics
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# HyperOptfor Bayesian optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope
import sys

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# ## Load and process data

# %%
# Load training set
train_set_file  = "train_set_imb_0.csv"
train_set = pd.read_csv(train_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])

# %%
# Tokenize texts and get features
max_words = 5000
max_len = 55
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(texts_train)
sequences_train = tokenizer.texts_to_sequences(texts_train)
features_train = sequence.pad_sequences(sequences_train, maxlen=max_len, padding='post', truncating='post')

# %% [markdown]
# ## Define hyperparameter search space and objective function

# %%
# Define the search space for hyperparameterss
hyperparam_space = {'n_filters': scope.int(hp.quniform('n_filters', 4, 128, q=1)),
                    'kernel_size': scope.int(hp.quniform('kernel_size', 2, 16, q=1)),
                    'dropout_rate': hp.uniform('dropout_rate', 0.25, 0.75),
                    'l2_val': hp.loguniform('l2_val', np.log(1e-6), np.log(1e-3)),
                    'embedding_dim' : scope.int(hp.quniform('embedding_dim', 64, 256, q=1)),
                    'max_words' : max_words,
                    'max_len' : max_len,
                    'batch_size' : scope.int(hp.quniform('batch_size', 16, 128, q=1)),
                    'epochs' : scope.int(hp.quniform('epochs', 16, 128, q=1)),
                    'learning_rate': hp.loguniform('learning_rate', np.log(1e-7), np.log(1e-4))
                             }

# %%
# Define the objective function for optimization
def objective(params):   
    print ('Params testing: ', params)

    # Split dataset into training validation sets
    inp_train, inp_valid, lbl_train, lbl_valid = train_test_split(features_train, labels_train, 
                                                                  test_size=0.15, 
                                                                  random_state=12345, 
                                                                  stratify=labels_train)
    
    # Compute class weights for compensation the imbalance in classes
    class_weights = class_weight.compute_class_weight(class_weight = "balanced",
                                        classes = np.unique(lbl_train),
                                        y = lbl_train)
    class_weights = dict(zip(np.unique(lbl_train), class_weights))

    # Define optimizer
    opt = Adam(learning_rate=params['learning_rate'], 
                   beta_1 = 0.9,
                   beta_2 = 0.99,
                   epsilon = 1e-07,
                   amsgrad = False)

    # Define sequential neural arhitecture
    model = Sequential()
    model.add(layers.Embedding(params['max_words'], params['embedding_dim'], input_length=params['max_len']))
    model.add(layers.Dropout(params['dropout_rate']))
    model.add(layers.Conv1D(filters=params['n_filters'], kernel_size=params['kernel_size'], kernel_initializer='glorot_uniform', padding='same', activation='relu', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))
    model.add(layers.MaxPooling1D())
    model.add(layers.Flatten())
    model.add(layers.Dense(1, kernel_initializer='glorot_uniform', activation='sigmoid', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))

    # Build model
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=[metrics.AUC(name='auc_pr', curve="PR")])
    #model.summary()

    # Fit model
    model.fit(inp_train, lbl_train, epochs=params['epochs'], batch_size=params['batch_size'], verbose = 0, class_weight=class_weights)

    # Compute performance of the trial
    pred_scores = (model.predict(inp_valid) > 0.5).astype("int32")
    f1 = f1_score(lbl_valid, pred_scores)
    print('DONE!      F1 = ' + str(f1))
    sys.stdout.flush() 
    return {'loss': -f1, 'status': STATUS_OK}

# %% [markdown]
# ## Run Bayesian optimization with Tree Parzen Estimator

# %%
trials = Trials()
best = fmin(objective, hyperparam_space, algo=tpe.suggest, max_evals=500, trials=trials)
print('Best hyperparams: ', best)
# Out:
# Params testing:
# {'batch_size': 109, 'dropout_rate': 0.4783174874796243, 'embedding_dim': 201, 'epochs': 58, 'kernel_size': 14, 'l2_val': 9.90822931775982e-05, 'learning_rate': 6.210853630482823e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 127}
# DONE!      F1 = 0.24309392265193372
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.6194478376751777, 'embedding_dim': 223, 'epochs': 73, 'kernel_size': 11, 'l2_val': 6.727534731707914e-05, 'learning_rate': 3.488530716431959e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 65}
# DONE!      F1 = 0.607142857142857
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.34962518775820844, 'embedding_dim': 91, 'epochs': 25, 'kernel_size': 14, 'l2_val': 0.000508332274656428, 'learning_rate': 1.6663577810464724e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 47}
# DONE!      F1 = 0.16666666666666669
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.6893764616579192, 'embedding_dim': 82, 'epochs': 62, 'kernel_size': 12, 'l2_val': 2.7628550388222407e-06, 'learning_rate': 6.931073065401125e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 5}
# DONE!      F1 = 0.09302325581395349
# Params testing:
# {'batch_size': 51, 'dropout_rate': 0.5092323451565217, 'embedding_dim': 246, 'epochs': 24, 'kernel_size': 4, 'l2_val': 0.000664193484928589, 'learning_rate': 1.0012027899002562e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 68}
# DONE!      F1 = 0.14044213263979194
# Params testing:
# {'batch_size': 49, 'dropout_rate': 0.3636953270746065, 'embedding_dim': 225, 'epochs': 52, 'kernel_size': 7, 'l2_val': 2.7443712190957302e-05, 'learning_rate': 6.164486466186534e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 18}
# DONE!      F1 = 0.5769230769230769
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.39132015006947923, 'embedding_dim': 188, 'epochs': 58, 'kernel_size': 15, 'l2_val': 0.0004191468914116927, 'learning_rate': 1.513538711984451e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 90}
# DONE!      F1 = 0.17467248908296945
# Params testing:
# {'batch_size': 122, 'dropout_rate': 0.30895134179198325, 'embedding_dim': 94, 'epochs': 39, 'kernel_size': 3, 'l2_val': 9.08334157711114e-06, 'learning_rate': 1.2579906446038392e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 63}
# DONE!      F1 = 0.12389380530973451
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.6113891493162746, 'embedding_dim': 133, 'epochs': 76, 'kernel_size': 4, 'l2_val': 2.0316882257892546e-06, 'learning_rate': 3.3959769075573776e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 54}
# DONE!      F1 = 0.11180124223602485
# Params testing:
# {'batch_size': 46, 'dropout_rate': 0.6674806503611369, 'embedding_dim': 164, 'epochs': 109, 'kernel_size': 4, 'l2_val': 7.173927698783351e-06, 'learning_rate': 2.811067532609064e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 124}
# DONE!      F1 = 0.1414141414141414
# Params testing:
# {'batch_size': 91, 'dropout_rate': 0.5022864958282087, 'embedding_dim': 93, 'epochs': 26, 'kernel_size': 12, 'l2_val': 0.00040567914158762334, 'learning_rate': 7.344536726961565e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 36}
# DONE!      F1 = 0.5755395683453238
# Params testing:
# {'batch_size': 45, 'dropout_rate': 0.5099401440800163, 'embedding_dim': 178, 'epochs': 117, 'kernel_size': 9, 'l2_val': 0.00016901716784930288, 'learning_rate': 5.338014148835867e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 64}
# DONE!      F1 = 0.21621621621621623
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.4796304893069745, 'embedding_dim': 241, 'epochs': 116, 'kernel_size': 14, 'l2_val': 0.0003238874766459752, 'learning_rate': 3.332281765068929e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 78}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.6983606176194861, 'embedding_dim': 153, 'epochs': 42, 'kernel_size': 8, 'l2_val': 4.855622486440359e-05, 'learning_rate': 3.4055677098289045e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 11}
# DONE!      F1 = 0.11666666666666667
# Params testing:
# {'batch_size': 26, 'dropout_rate': 0.5940995758124124, 'embedding_dim': 135, 'epochs': 77, 'kernel_size': 8, 'l2_val': 0.0004221575658670141, 'learning_rate': 1.48068063946691e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 90}
# DONE!      F1 = 0.06557377049180327
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.4663960503093639, 'embedding_dim': 186, 'epochs': 48, 'kernel_size': 7, 'l2_val': 0.00011149656666881085, 'learning_rate': 1.4294366736989187e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 39}
# DONE!      F1 = 0.5333333333333333
# Params testing:
# {'batch_size': 47, 'dropout_rate': 0.7187527381344816, 'embedding_dim': 193, 'epochs': 85, 'kernel_size': 12, 'l2_val': 5.572249424282362e-06, 'learning_rate': 7.406038882022681e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 97}
# DONE!      F1 = 0.3448275862068965
# Params testing:
# {'batch_size': 49, 'dropout_rate': 0.6477225489468628, 'embedding_dim': 246, 'epochs': 37, 'kernel_size': 5, 'l2_val': 2.0960160608670358e-06, 'learning_rate': 1.5938646000468306e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 40}
# DONE!      F1 = 0.13268608414239483
# Params testing:
# {'batch_size': 25, 'dropout_rate': 0.7354760927874577, 'embedding_dim': 126, 'epochs': 70, 'kernel_size': 5, 'l2_val': 3.1415591780433377e-06, 'learning_rate': 3.684882992883631e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 29}
# DONE!      F1 = 0.1386138613861386
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.543372650432258, 'embedding_dim': 65, 'epochs': 82, 'kernel_size': 3, 'l2_val': 3.1897979071593706e-06, 'learning_rate': 1.6899230122695491e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 75}
# DONE!      F1 = 0.13636363636363638
# Params testing:
# {'batch_size': 86, 'dropout_rate': 0.5866528836507113, 'embedding_dim': 221, 'epochs': 97, 'kernel_size': 10, 'l2_val': 0.0002066283153642648, 'learning_rate': 3.4958511138609736e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 104}
# DONE!      F1 = 0.594059405940594
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.5796216132609671, 'embedding_dim': 220, 'epochs': 96, 'kernel_size': 10, 'l2_val': 3.605932783543696e-05, 'learning_rate': 3.23632544411671e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 110}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.5528277205364244, 'embedding_dim': 214, 'epochs': 97, 'kernel_size': 11, 'l2_val': 2.262185040008666e-05, 'learning_rate': 3.316948019814227e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 110}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 98, 'dropout_rate': 0.4333454480732193, 'embedding_dim': 231, 'epochs': 97, 'kernel_size': 10, 'l2_val': 6.180218228669453e-05, 'learning_rate': 9.306161972021397e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 115}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 101, 'dropout_rate': 0.415980325525405, 'embedding_dim': 254, 'epochs': 127, 'kernel_size': 16, 'l2_val': 1.4485865488119504e-05, 'learning_rate': 8.10257838341007e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 81}
# DONE!      F1 = 0.625
# Params testing:
# {'batch_size': 123, 'dropout_rate': 0.26345343368189456, 'embedding_dim': 255, 'epochs': 122, 'kernel_size': 15, 'l2_val': 1.3858103069308112e-05, 'learning_rate': 1.5216712974569752e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 84}
# DONE!      F1 = 0.5982905982905983
# Params testing:
# {'batch_size': 111, 'dropout_rate': 0.4194319645498013, 'embedding_dim': 255, 'epochs': 126, 'kernel_size': 16, 'l2_val': 1.1732152327824747e-05, 'learning_rate': 5.780912657675672e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 57}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.25217130079529404, 'embedding_dim': 204, 'epochs': 17, 'kernel_size': 16, 'l2_val': 1.3102775100479782e-06, 'learning_rate': 7.638143272761617e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 71}
# DONE!      F1 = 0.1342281879194631
# Params testing:
# {'batch_size': 106, 'dropout_rate': 0.6406512955888678, 'embedding_dim': 205, 'epochs': 109, 'kernel_size': 13, 'l2_val': 7.618618861120109e-05, 'learning_rate': 2.9916420910548744e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 81}
# DONE!      F1 = 0.1509433962264151
# Params testing:
# {'batch_size': 76, 'dropout_rate': 0.3037349654702485, 'embedding_dim': 235, 'epochs': 64, 'kernel_size': 13, 'l2_val': 1.8503300012081542e-05, 'learning_rate': 9.868251907799035e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 57}
# DONE!      F1 = 0.6
# Params testing:
# {'batch_size': 106, 'dropout_rate': 0.4452156693695189, 'embedding_dim': 256, 'epochs': 90, 'kernel_size': 15, 'l2_val': 9.920905139320238e-05, 'learning_rate': 2.0223102631505893e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 127}
# DONE!      F1 = 0.5945945945945946
# Params testing:
# {'batch_size': 62, 'dropout_rate': 0.394139605280116, 'embedding_dim': 165, 'epochs': 106, 'kernel_size': 13, 'l2_val': 4.024106952892238e-05, 'learning_rate': 1.029265523490155e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 92}
# DONE!      F1 = 0.549618320610687
# Params testing:
# {'batch_size': 115, 'dropout_rate': 0.5408269833910881, 'embedding_dim': 210, 'epochs': 104, 'kernel_size': 11, 'l2_val': 5.088089293328497e-06, 'learning_rate': 3.0516308539388947e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 51}
# DONE!      F1 = 0.24675324675324672
# Params testing:
# {'batch_size': 100, 'dropout_rate': 0.3261290674654606, 'embedding_dim': 113, 'epochs': 29, 'kernel_size': 14, 'l2_val': 0.0008166889284574326, 'learning_rate': 4.8658832169557305e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 22}
# DONE!      F1 = 0.1607142857142857
# Params testing:
# {'batch_size': 93, 'dropout_rate': 0.3589034375287669, 'embedding_dim': 174, 'epochs': 52, 'kernel_size': 7, 'l2_val': 0.00015788959897528818, 'learning_rate': 5.286756484449896e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 48}
# DONE!      F1 = 0.6126126126126126
# Params testing:
# {'batch_size': 93, 'dropout_rate': 0.3744266932530347, 'embedding_dim': 148, 'epochs': 50, 'kernel_size': 6, 'l2_val': 0.00018636711395313878, 'learning_rate': 2.224452279484567e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 47}
# DONE!      F1 = 0.5037037037037037
# Params testing:
# {'batch_size': 128, 'dropout_rate': 0.2807336744027846, 'embedding_dim': 171, 'epochs': 67, 'kernel_size': 7, 'l2_val': 0.00013377175502367756, 'learning_rate': 4.665695877469145e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 28}
# DONE!      F1 = 0.5344827586206896
# Params testing:
# {'batch_size': 118, 'dropout_rate': 0.3405447172701507, 'embedding_dim': 106, 'epochs': 59, 'kernel_size': 6, 'l2_val': 0.0002603969575550024, 'learning_rate': 9.364032091177342e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 68}
# DONE!      F1 = 0.5294117647058822
# Params testing:
# {'batch_size': 78, 'dropout_rate': 0.35175245716807724, 'embedding_dim': 72, 'epochs': 35, 'kernel_size': 9, 'l2_val': 1.6247551493487483e-05, 'learning_rate': 5.14069582608546e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 6}
# DONE!      F1 = 0.47540983606557374
# Params testing:
# {'batch_size': 101, 'dropout_rate': 0.39613555185401267, 'embedding_dim': 145, 'epochs': 18, 'kernel_size': 6, 'l2_val': 2.5696523691466805e-05, 'learning_rate': 5.416507231070813e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 43}
# DONE!      F1 = 0.15300546448087432
# Params testing:
# {'batch_size': 65, 'dropout_rate': 0.28751614063773034, 'embedding_dim': 196, 'epochs': 54, 'kernel_size': 2, 'l2_val': 1.0433905432045588e-06, 'learning_rate': 1.187724470190589e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 63}
# DONE!      F1 = 0.32679738562091504
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.46233338590877676, 'embedding_dim': 111, 'epochs': 73, 'kernel_size': 8, 'l2_val': 0.0006140503618489952, 'learning_rate': 2.416840006930143e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 31}
# DONE!      F1 = 0.5648854961832062
# Params testing:
# {'batch_size': 127, 'dropout_rate': 0.42546362129425186, 'embedding_dim': 178, 'epochs': 46, 'kernel_size': 2, 'l2_val': 6.49645172429601e-05, 'learning_rate': 1.5812562841795609e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 19}
# DONE!      F1 = 0.1275626423690205
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.37282590759428375, 'embedding_dim': 83, 'epochs': 31, 'kernel_size': 5, 'l2_val': 4.6377743027845e-05, 'learning_rate': 8.180261728097487e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 101}
# DONE!      F1 = 0.6000000000000001
# Params testing:
# {'batch_size': 112, 'dropout_rate': 0.3172478219715657, 'embedding_dim': 134, 'epochs': 56, 'kernel_size': 8, 'l2_val': 6.759724620398845e-06, 'learning_rate': 8.345108808177994e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 73}
# DONE!      F1 = 0.022727272727272724
# Params testing:
# {'batch_size': 17, 'dropout_rate': 0.5229380841339606, 'embedding_dim': 159, 'epochs': 21, 'kernel_size': 3, 'l2_val': 1.0058381446441152e-05, 'learning_rate': 4.392382995562068e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 84}
# DONE!      F1 = 0.6115702479338843
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.4867632080261859, 'embedding_dim': 183, 'epochs': 43, 'kernel_size': 7, 'l2_val': 4.455595810392233e-06, 'learning_rate': 1.5171852601862924e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 12}
# DONE!      F1 = 0.14246575342465753
# Params testing:
# {'batch_size': 122, 'dropout_rate': 0.34727052937812986, 'embedding_dim': 239, 'epochs': 79, 'kernel_size': 9, 'l2_val': 0.0009051912280895342, 'learning_rate': 7.18725714171459e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 60}
# DONE!      F1 = 0.5333333333333333
# Params testing:
# {'batch_size': 105, 'dropout_rate': 0.44990120444881104, 'embedding_dim': 124, 'epochs': 88, 'kernel_size': 12, 'l2_val': 3.116709374543946e-05, 'learning_rate': 8.564226045582666e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 52}
# DONE!      F1 = 0.2972972972972973
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.40687451370527294, 'embedding_dim': 229, 'epochs': 116, 'kernel_size': 4, 'l2_val': 0.00013703120650254133, 'learning_rate': 4.481396843508612e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 120}
# DONE!      F1 = 0.3170731707317073
# Params testing:
# {'batch_size': 116, 'dropout_rate': 0.49083369809250893, 'embedding_dim': 247, 'epochs': 61, 'kernel_size': 10, 'l2_val': 0.0002468494153748489, 'learning_rate': 2.554046077079813e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 47}
# DONE!      F1 = 0.5757575757575758
# Params testing:
# {'batch_size': 81, 'dropout_rate': 0.37379160817772594, 'embedding_dim': 195, 'epochs': 67, 'kernel_size': 6, 'l2_val': 7.994136086531492e-05, 'learning_rate': 2.1937711411245082e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 95}
# DONE!      F1 = 0.16541353383458648
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.5142493955660669, 'embedding_dim': 99, 'epochs': 35, 'kernel_size': 11, 'l2_val': 0.0003262960834483253, 'learning_rate': 1.7117145790589266e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 88}
# DONE!      F1 = 0.2818791946308725
# Params testing:
# {'batch_size': 90, 'dropout_rate': 0.28922457004713514, 'embedding_dim': 215, 'epochs': 42, 'kernel_size': 7, 'l2_val': 7.527697978789729e-06, 'learning_rate': 5.155527720321614e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 35}
# DONE!      F1 = 0.09433962264150943
# Params testing:
# {'batch_size': 40, 'dropout_rate': 0.2635802643498053, 'embedding_dim': 143, 'epochs': 72, 'kernel_size': 5, 'l2_val': 2.0717529807205714e-05, 'learning_rate': 7.144130168275833e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 24}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 103, 'dropout_rate': 0.330544938862212, 'embedding_dim': 122, 'epochs': 91, 'kernel_size': 9, 'l2_val': 1.7930844412780505e-06, 'learning_rate': 4.0548277637371154e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 77}
# DONE!      F1 = 0.5436893203883495
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.46583899217544456, 'embedding_dim': 174, 'epochs': 82, 'kernel_size': 3, 'l2_val': 0.0005146328140004482, 'learning_rate': 2.3056518126524114e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 67}
# DONE!      F1 = 0.13424657534246576
# Params testing:
# {'batch_size': 108, 'dropout_rate': 0.41593578340318405, 'embedding_dim': 81, 'epochs': 128, 'kernel_size': 8, 'l2_val': 0.00013920808904710382, 'learning_rate': 1.0030001138809815e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 103}
# DONE!      F1 = 0.03571428571428572
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.6142354503627754, 'embedding_dim': 157, 'epochs': 121, 'kernel_size': 4, 'l2_val': 4.350399521855301e-06, 'learning_rate': 1.1161660735229817e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 14}
# DONE!      F1 = 0.5362318840579711
# Params testing:
# {'batch_size': 98, 'dropout_rate': 0.5621268231777039, 'embedding_dim': 249, 'epochs': 50, 'kernel_size': 16, 'l2_val': 5.524277975227342e-05, 'learning_rate': 6.189587314292629e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 43}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 95, 'dropout_rate': 0.4471241295714255, 'embedding_dim': 185, 'epochs': 26, 'kernel_size': 10, 'l2_val': 1.1795287612867768e-05, 'learning_rate': 2.7621044443225903e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 81}
# DONE!      F1 = 0.4782608695652174
# Params testing:
# {'batch_size': 65, 'dropout_rate': 0.3895984421272704, 'embedding_dim': 65, 'epochs': 77, 'kernel_size': 12, 'l2_val': 3.0664120966837224e-05, 'learning_rate': 1.6703578650861848e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 107}
# DONE!      F1 = 0.5588235294117647
# Params testing:
# {'batch_size': 119, 'dropout_rate': 0.29986289126629867, 'embedding_dim': 201, 'epochs': 101, 'kernel_size': 15, 'l2_val': 9.124127259044628e-05, 'learning_rate': 3.6110393959601864e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 55}
# DONE!      F1 = 0.5882352941176471
# Params testing:
# {'batch_size': 88, 'dropout_rate': 0.5678482027946836, 'embedding_dim': 226, 'epochs': 62, 'kernel_size': 14, 'l2_val': 3.936048294013193e-05, 'learning_rate': 2.2397103670697095e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 98}
# DONE!      F1 = 0.16149068322981366
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.5331721191844234, 'embedding_dim': 166, 'epochs': 112, 'kernel_size': 11, 'l2_val': 3.225657799732208e-06, 'learning_rate': 6.29945112218168e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 119}
# DONE!      F1 = 0.546875
# Params testing:
# {'batch_size': 19, 'dropout_rate': 0.5224215201010393, 'embedding_dim': 157, 'epochs': 22, 'kernel_size': 3, 'l2_val': 9.033143243091911e-06, 'learning_rate': 4.146157564851081e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 71}
# DONE!      F1 = 0.5873015873015874
# Params testing:
# {'batch_size': 35, 'dropout_rate': 0.5016718254559736, 'embedding_dim': 149, 'epochs': 39, 'kernel_size': 2, 'l2_val': 1.0531725794899793e-05, 'learning_rate': 5.6189684289946254e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 86}
# DONE!      F1 = 0.5739130434782609
# Params testing:
# {'batch_size': 17, 'dropout_rate': 0.6635467589875661, 'embedding_dim': 138, 'epochs': 18, 'kernel_size': 3, 'l2_val': 1.803588271323032e-05, 'learning_rate': 1.8880685396703008e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 92}
# DONE!      F1 = 0.2040816326530612
# Params testing:
# {'batch_size': 79, 'dropout_rate': 0.5921468724197567, 'embedding_dim': 163, 'epochs': 30, 'kernel_size': 4, 'l2_val': 1.3963049019883183e-05, 'learning_rate': 1.3541428233810413e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 80}
# DONE!      F1 = 0.1818181818181818
# Params testing:
# {'batch_size': 112, 'dropout_rate': 0.360390931021356, 'embedding_dim': 191, 'epochs': 22, 'kernel_size': 5, 'l2_val': 2.3337083490510773e-05, 'learning_rate': 2.9631982171892097e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 59}
# DONE!      F1 = 0.19642857142857145
# Params testing:
# {'batch_size': 59, 'dropout_rate': 0.4332219747493435, 'embedding_dim': 119, 'epochs': 33, 'kernel_size': 6, 'l2_val': 6.357358979125438e-06, 'learning_rate': 9.610424514874248e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 70}
# DONE!      F1 = 0.5242718446601942
# Params testing:
# {'batch_size': 84, 'dropout_rate': 0.630044686885066, 'embedding_dim': 130, 'epochs': 53, 'kernel_size': 2, 'l2_val': 9.338090056660598e-06, 'learning_rate': 4.776110587457409e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 84}
# DONE!      F1 = 0.5970149253731343
# Params testing:
# {'batch_size': 73, 'dropout_rate': 0.5258911954496444, 'embedding_dim': 174, 'epochs': 39, 'kernel_size': 13, 'l2_val': 2.692228143337809e-06, 'learning_rate': 9.157616375312209e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 113}
# DONE!      F1 = 0.14705882352941174
# Params testing:
# {'batch_size': 94, 'dropout_rate': 0.7128043387986663, 'embedding_dim': 138, 'epochs': 46, 'kernel_size': 5, 'l2_val': 1.4466775708237199e-05, 'learning_rate': 8.013397809284723e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 74}
# DONE!      F1 = 0.5901639344262295
# Params testing:
# {'batch_size': 124, 'dropout_rate': 0.47974675471521, 'embedding_dim': 209, 'epochs': 56, 'kernel_size': 4, 'l2_val': 1.5713184666686761e-06, 'learning_rate': 6.637283499949631e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 64}
# DONE!      F1 = 0.5405405405405406
# Params testing:
# {'batch_size': 99, 'dropout_rate': 0.7475463707309955, 'embedding_dim': 199, 'epochs': 22, 'kernel_size': 8, 'l2_val': 5.147439215723288e-05, 'learning_rate': 2.138118330220462e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 50}
# DONE!      F1 = 0.21395348837209302
# Params testing:
# {'batch_size': 109, 'dropout_rate': 0.38555879286511474, 'embedding_dim': 181, 'epochs': 67, 'kernel_size': 7, 'l2_val': 7.951054841158169e-06, 'learning_rate': 1.1726096058342373e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 34}
# DONE!      F1 = 0.075
# Params testing:
# {'batch_size': 102, 'dropout_rate': 0.40281694935536155, 'embedding_dim': 100, 'epochs': 92, 'kernel_size': 3, 'l2_val': 3.977581020419689e-06, 'learning_rate': 9.82427053289971e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 96}
# DONE!      F1 = 0.5631067961165047
# Params testing:
# {'batch_size': 76, 'dropout_rate': 0.5774965206905587, 'embedding_dim': 153, 'epochs': 85, 'kernel_size': 15, 'l2_val': 2.5460043256827155e-06, 'learning_rate': 4.4230888407273124e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 77}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'batch_size': 91, 'dropout_rate': 0.6036128999134616, 'embedding_dim': 169, 'epochs': 46, 'kernel_size': 6, 'l2_val': 3.655028511357015e-05, 'learning_rate': 1.2514709181844269e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 40}
# DONE!      F1 = 0.14814814814814814
# Params testing:
# {'batch_size': 97, 'dropout_rate': 0.4568132811856298, 'embedding_dim': 189, 'epochs': 74, 'kernel_size': 10, 'l2_val': 0.00011022261744051494, 'learning_rate': 5.324575644573579e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 61}
# DONE!      F1 = 0.5192307692307692
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.5525279395134378, 'embedding_dim': 129, 'epochs': 28, 'kernel_size': 11, 'l2_val': 5.632646128048378e-06, 'learning_rate': 4.360629957156197e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 91}
# DONE!      F1 = 0.14285714285714285
# Params testing:
# {'batch_size': 87, 'dropout_rate': 0.4733254795163126, 'embedding_dim': 216, 'epochs': 16, 'kernel_size': 9, 'l2_val': 2.6912650829788634e-05, 'learning_rate': 3.3044959009870774e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 43}
# DONE!      F1 = 0.25210084033613445
# Params testing:
# {'batch_size': 114, 'dropout_rate': 0.43721922690878107, 'embedding_dim': 237, 'epochs': 70, 'kernel_size': 8, 'l2_val': 7.086132934180163e-05, 'learning_rate': 3.790589480643079e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 66}
# DONE!      F1 = 0.13445378151260504
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.5109443081164642, 'embedding_dim': 115, 'epochs': 102, 'kernel_size': 12, 'l2_val': 0.0003481647553019759, 'learning_rate': 8.473440143538167e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 87}
# DONE!      F1 = 0.5794392523364486
# Params testing:
# {'batch_size': 21, 'dropout_rate': 0.33000663379416995, 'embedding_dim': 159, 'epochs': 121, 'kernel_size': 7, 'l2_val': 0.00024247135488143984, 'learning_rate': 6.642107057896212e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 99}
# DONE!      F1 = 0.5920000000000001
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.41186577357897436, 'embedding_dim': 89, 'epochs': 113, 'kernel_size': 2, 'l2_val': 1.7302091937915107e-05, 'learning_rate': 2.4400063600051824e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 128}
# DONE!      F1 = 0.5882352941176471
# Params testing:
# {'batch_size': 104, 'dropout_rate': 0.2541678441776314, 'embedding_dim': 107, 'epochs': 64, 'kernel_size': 5, 'l2_val': 1.1491833800086207e-06, 'learning_rate': 3.8190318677881445e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 108}
# DONE!      F1 = 0.5882352941176472
# Params testing:
# {'batch_size': 58, 'dropout_rate': 0.3551803159142307, 'embedding_dim': 143, 'epochs': 49, 'kernel_size': 14, 'l2_val': 4.30632329569335e-05, 'learning_rate': 1.5077070870821774e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 54}
# DONE!      F1 = 0.42580645161290326
# Params testing:
# {'batch_size': 120, 'dropout_rate': 0.3144845341094914, 'embedding_dim': 252, 'epochs': 81, 'kernel_size': 16, 'l2_val': 0.0001585218154991574, 'learning_rate': 9.536217919280558e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 46}
# DONE!      F1 = 0.3832335329341317
# Params testing:
# {'batch_size': 108, 'dropout_rate': 0.27684966587305393, 'embedding_dim': 233, 'epochs': 94, 'kernel_size': 4, 'l2_val': 0.0006841070025428757, 'learning_rate': 6.142712104465246e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 94}
# DONE!      F1 = 0.5283018867924528
# Params testing:
# {'batch_size': 24, 'dropout_rate': 0.3407577719884151, 'embedding_dim': 72, 'epochs': 124, 'kernel_size': 13, 'l2_val': 2.292018744169829e-06, 'learning_rate': 6.296102748822758e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 50}
# DONE!      F1 = 0.13559322033898305
# Params testing:
# {'batch_size': 125, 'dropout_rate': 0.6848358853700028, 'embedding_dim': 205, 'epochs': 86, 'kernel_size': 7, 'l2_val': 3.7059094160220756e-06, 'learning_rate': 3.077492219517618e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 83}
# DONE!      F1 = 0.576271186440678
# Params testing:
# {'batch_size': 63, 'dropout_rate': 0.49294678746070464, 'embedding_dim': 222, 'epochs': 58, 'kernel_size': 6, 'l2_val': 5.254155024587069e-06, 'learning_rate': 7.4251304268662465e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 27}
# DONE!      F1 = 0.19753086419753085
# Params testing:
# {'batch_size': 33, 'dropout_rate': 0.37476158490238165, 'embedding_dim': 241, 'epochs': 36, 'kernel_size': 9, 'l2_val': 5.80293678520764e-05, 'learning_rate': 2.009104860101177e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 4}
# DONE!      F1 = 0.2905027932960894
# Params testing:
# {'batch_size': 117, 'dropout_rate': 0.42794175345037544, 'embedding_dim': 179, 'epochs': 19, 'kernel_size': 3, 'l2_val': 8.614392526376809e-05, 'learning_rate': 2.0342117149962664e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 69}
# DONE!      F1 = 0.10029498525073746
# Params testing:
# {'batch_size': 75, 'dropout_rate': 0.38245860032693435, 'embedding_dim': 153, 'epochs': 43, 'kernel_size': 10, 'l2_val': 2.1525449294644385e-05, 'learning_rate': 2.7013795878906804e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 58}
# DONE!      F1 = 0.22916666666666666
# Params testing:
# {'batch_size': 78, 'dropout_rate': 0.44496497133296486, 'embedding_dim': 210, 'epochs': 33, 'kernel_size': 5, 'l2_val': 1.0931423127494035e-05, 'learning_rate': 3.910473280739024e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 101}
# DONE!      F1 = 0.14285714285714288
# Params testing:
# {'batch_size': 89, 'dropout_rate': 0.3650526399955196, 'embedding_dim': 139, 'epochs': 99, 'kernel_size': 2, 'l2_val': 1.2148757031125056e-05, 'learning_rate': 2.748304852439922e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 32}
# DONE!      F1 = 0.5873015873015874
# Params testing:
# {'batch_size': 50, 'dropout_rate': 0.47641808915098394, 'embedding_dim': 175, 'epochs': 106, 'kernel_size': 11, 'l2_val': 8.878763241930383e-06, 'learning_rate': 7.968659277982377e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 37}
# DONE!      F1 = 0.5945945945945946
# Params testing:
# {'batch_size': 85, 'dropout_rate': 0.40006259105405806, 'embedding_dim': 244, 'epochs': 40, 'kernel_size': 6, 'l2_val': 3.194133047879697e-05, 'learning_rate': 5.437479013758757e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 75}
# DONE!      F1 = 0.17857142857142858
# Params testing:
# {'batch_size': 96, 'dropout_rate': 0.5389554347460697, 'embedding_dim': 227, 'epochs': 27, 'kernel_size': 8, 'l2_val': 0.0004987721460921155, 'learning_rate': 5.227348369390677e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 62}
# DONE!      F1 = 0.5285714285714287
# Params testing:
# {'batch_size': 101, 'dropout_rate': 0.6248730126151171, 'embedding_dim': 163, 'epochs': 25, 'kernel_size': 4, 'l2_val': 1.538234022803401e-05, 'learning_rate': 1.793112794586972e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 121}
# DONE!      F1 = 0.23809523809523808
# Params testing:
# {'batch_size': 92, 'dropout_rate': 0.42096847405433707, 'embedding_dim': 169, 'epochs': 55, 'kernel_size': 12, 'l2_val': 0.00017121218037568654, 'learning_rate': 1.0743152760407331e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 115}
# DONE!      F1 = 0.22222222222222224
# Params testing:
# {'batch_size': 53, 'dropout_rate': 0.319156229561713, 'embedding_dim': 197, 'epochs': 32, 'kernel_size': 9, 'l2_val': 0.00011503702978029453, 'learning_rate': 1.0702347988714523e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 106}
# DONE!      F1 = 0.28915662650602414
# Params testing:
# {'batch_size': 47, 'dropout_rate': 0.29885492637922273, 'embedding_dim': 149, 'epochs': 52, 'kernel_size': 10, 'l2_val': 0.00022216488499202257, 'learning_rate': 7.209289443135022e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 8}
# DONE!      F1 = 0.6
# Params testing:
# {'batch_size': 110, 'dropout_rate': 0.4593962581638244, 'embedding_dim': 119, 'epochs': 118, 'kernel_size': 15, 'l2_val': 2.4512718045140547e-05, 'learning_rate': 2.2833561329936532e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 90}
# DONE!      F1 = 0.5504587155963303
# Params testing:
# {'batch_size': 113, 'dropout_rate': 0.2703876346263011, 'embedding_dim': 202, 'epochs': 75, 'kernel_size': 13, 'l2_val': 1.2691436931936674e-05, 'learning_rate': 4.6474034471845696e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 72}
# DONE!      F1 = 0.5660377358490566
# Params testing:
# {'batch_size': 39, 'dropout_rate': 0.5551666006409419, 'embedding_dim': 97, 'epochs': 79, 'kernel_size': 7, 'l2_val': 1.9773881062052128e-05, 'learning_rate': 3.597845986594597e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 79}
# DONE!      F1 = 0.6017699115044246
# Params testing:
# {'batch_size': 105, 'dropout_rate': 0.6445221081740107, 'embedding_dim': 218, 'epochs': 61, 'kernel_size': 4, 'l2_val': 0.0002976265183841074, 'learning_rate': 1.3727499072283456e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 45}
# DONE!      F1 = 0.22727272727272727
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.5208537198702691, 'embedding_dim': 187, 'epochs': 64, 'kernel_size': 3, 'l2_val': 6.107517682261978e-06, 'learning_rate': 8.42602866549009e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 83}
# DONE!      F1 = 0.2539682539682539
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.5778576206880586, 'embedding_dim': 212, 'epochs': 20, 'kernel_size': 8, 'l2_val': 7.394802025923986e-06, 'learning_rate': 8.750547847380589e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 124}
# DONE!      F1 = 0.6140350877192983
# Params testing:
# {'batch_size': 70, 'dropout_rate': 0.6078689669711876, 'embedding_dim': 251, 'epochs': 45, 'kernel_size': 9, 'l2_val': 1.3973383519752007e-06, 'learning_rate': 6.156285843719923e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 17}
# DONE!      F1 = 0.6086956521739131
# Params testing:
# {'batch_size': 56, 'dropout_rate': 0.659157353485003, 'embedding_dim': 192, 'epochs': 69, 'kernel_size': 8, 'l2_val': 1.8773957423446541e-06, 'learning_rate': 8.821009823427767e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 23}
# DONE!      F1 = 0.5660377358490566
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.5799345568512051, 'embedding_dim': 233, 'epochs': 109, 'kernel_size': 8, 'l2_val': 3.6207215201296694e-06, 'learning_rate': 9.839446786683952e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 126}
# DONE!      F1 = 0.6296296296296297
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.7049630367730229, 'embedding_dim': 256, 'epochs': 128, 'kernel_size': 8, 'l2_val': 3.1337833480741058e-06, 'learning_rate': 7.98236031166172e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 112}
# DONE!      F1 = 0.14117647058823532
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.7253255316439512, 'embedding_dim': 223, 'epochs': 108, 'kernel_size': 10, 'l2_val': 4.267120222174063e-06, 'learning_rate': 9.782427462799651e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 123}
# DONE!      F1 = 0.611111111111111
# Params testing:
# {'batch_size': 72, 'dropout_rate': 0.6890402757452044, 'embedding_dim': 231, 'epochs': 123, 'kernel_size': 11, 'l2_val': 7.21831233113193e-06, 'learning_rate': 6.760033989969349e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 123}
# DONE!      F1 = 0.5961538461538461
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.5813478192341902, 'embedding_dim': 245, 'epochs': 125, 'kernel_size': 12, 'l2_val': 4.7539869396043875e-06, 'learning_rate': 9.991388281284215e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 126}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.674328494401582, 'embedding_dim': 236, 'epochs': 113, 'kernel_size': 14, 'l2_val': 4.8558070062299885e-06, 'learning_rate': 1.0115575012597494e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 118}
# DONE!      F1 = 0.2014388489208633
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.5635140874927694, 'embedding_dim': 244, 'epochs': 126, 'kernel_size': 12, 'l2_val': 2.2937882883016295e-06, 'learning_rate': 4.047248137765144e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 127}
# DONE!      F1 = 0.616822429906542
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.5843951022165156, 'embedding_dim': 241, 'epochs': 120, 'kernel_size': 13, 'l2_val': 1.0264999985731739e-06, 'learning_rate': 3.0847374603217496e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 116}
# DONE!      F1 = 0.5849056603773585
# Params testing:
# {'batch_size': 48, 'dropout_rate': 0.6551256926991236, 'embedding_dim': 256, 'epochs': 111, 'kernel_size': 11, 'l2_val': 3.4749868590700272e-06, 'learning_rate': 1.2904397487847077e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 110}
# DONE!      F1 = 0.13025780189959293
# Params testing:
# {'batch_size': 45, 'dropout_rate': 0.6317432767234687, 'embedding_dim': 249, 'epochs': 115, 'kernel_size': 16, 'l2_val': 2.77215746317044e-06, 'learning_rate': 7.524915874554148e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 105}
# DONE!      F1 = 0.6126126126126126
# Params testing:
# {'batch_size': 67, 'dropout_rate': 0.5016716302031988, 'embedding_dim': 252, 'epochs': 118, 'kernel_size': 14, 'l2_val': 1.5730504729816681e-06, 'learning_rate': 1.2636920154902519e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 125}
# DONE!      F1 = 0.15384615384615385
# Params testing:
# {'batch_size': 83, 'dropout_rate': 0.5421333682518974, 'embedding_dim': 233, 'epochs': 126, 'kernel_size': 16, 'l2_val': 1.290426858623098e-06, 'learning_rate': 2.1603229416171685e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 113}
# DONE!      F1 = 0.2077922077922078
# Params testing:
# {'batch_size': 77, 'dropout_rate': 0.5987372057582123, 'embedding_dim': 226, 'epochs': 105, 'kernel_size': 15, 'l2_val': 8.302766383013877e-06, 'learning_rate': 4.557058496429505e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 103}
# DONE!      F1 = 0.16176470588235295
# Params testing:
# {'batch_size': 74, 'dropout_rate': 0.6750118015472455, 'embedding_dim': 208, 'epochs': 109, 'kernel_size': 13, 'l2_val': 4.716672845116366e-06, 'learning_rate': 2.672050645256289e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 119}
# DONE!      F1 = 0.1206896551724138
# Params testing:
# {'batch_size': 58, 'dropout_rate': 0.6361735141230003, 'embedding_dim': 221, 'epochs': 95, 'kernel_size': 14, 'l2_val': 5.907213733473108e-06, 'learning_rate': 5.726010305047133e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 100}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 53, 'dropout_rate': 0.6186937301632075, 'embedding_dim': 230, 'epochs': 102, 'kernel_size': 16, 'l2_val': 1.7094314508384022e-06, 'learning_rate': 1.5729719779263882e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 94}
# DONE!      F1 = 0.5932203389830508
# Params testing:
# {'batch_size': 87, 'dropout_rate': 0.5699462178369757, 'embedding_dim': 246, 'epochs': 124, 'kernel_size': 12, 'l2_val': 1.9702356077482925e-06, 'learning_rate': 5.555781932198859e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 109}
# DONE!      F1 = 0.38823529411764707
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.740538906368306, 'embedding_dim': 237, 'epochs': 119, 'kernel_size': 15, 'l2_val': 2.183173044009658e-06, 'learning_rate': 5.00439351041062e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 97}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 36, 'dropout_rate': 0.5318036437439602, 'embedding_dim': 241, 'epochs': 99, 'kernel_size': 9, 'l2_val': 1.0102956119420205e-05, 'learning_rate': 3.372608036014196e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 116}
# DONE!      F1 = 0.29139072847682124
# Params testing:
# {'batch_size': 56, 'dropout_rate': 0.5909409019944624, 'embedding_dim': 217, 'epochs': 88, 'kernel_size': 10, 'l2_val': 3.930038345399667e-06, 'learning_rate': 2.731496671787956e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 128}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 62, 'dropout_rate': 0.4714216673233271, 'embedding_dim': 254, 'epochs': 116, 'kernel_size': 12, 'l2_val': 3.037730436093066e-06, 'learning_rate': 9.979865253590131e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 87}
# DONE!      F1 = 0.625
# Params testing:
# {'batch_size': 44, 'dropout_rate': 0.486465161800554, 'embedding_dim': 253, 'epochs': 115, 'kernel_size': 11, 'l2_val': 2.939628547185496e-06, 'learning_rate': 3.694814679049509e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 86}
# DONE!      F1 = 0.5849056603773585
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.4490703941032244, 'embedding_dim': 205, 'epochs': 110, 'kernel_size': 7, 'l2_val': 1.1902708245780516e-06, 'learning_rate': 4.038538135800268e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 89}
# DONE!      F1 = 0.25210084033613445
# Params testing:
# {'batch_size': 41, 'dropout_rate': 0.5509570589315655, 'embedding_dim': 249, 'epochs': 107, 'kernel_size': 13, 'l2_val': 3.5145680673972077e-06, 'learning_rate': 1.2728628033003255e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 65}
# DONE!      F1 = 0.5901639344262295
# Params testing:
# {'batch_size': 50, 'dropout_rate': 0.5152588996528382, 'embedding_dim': 256, 'epochs': 128, 'kernel_size': 14, 'l2_val': 1.006763602535281e-06, 'learning_rate': 2.4412798286784552e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 77}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.495673194390423, 'embedding_dim': 214, 'epochs': 104, 'kernel_size': 10, 'l2_val': 2.479691348770917e-06, 'learning_rate': 7.434085917494748e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 56}
# DONE!      F1 = 0.6181818181818182
# Params testing:
# {'batch_size': 73, 'dropout_rate': 0.43624376974658274, 'embedding_dim': 226, 'epochs': 98, 'kernel_size': 15, 'l2_val': 6.521877053372002e-06, 'learning_rate': 2.0678783641869647e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 92}
# DONE!      F1 = 0.6037735849056604
# Params testing:
# {'batch_size': 65, 'dropout_rate': 0.4682311019241106, 'embedding_dim': 238, 'epochs': 93, 'kernel_size': 11, 'l2_val': 1.5819109115581366e-05, 'learning_rate': 1.7753627096846065e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 68}
# DONE!      F1 = 0.20833333333333334
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.41161605253347455, 'embedding_dim': 233, 'epochs': 122, 'kernel_size': 9, 'l2_val': 2.9085181775579303e-05, 'learning_rate': 2.6763315028655345e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 82}
# DONE!      F1 = 0.32704402515723274
# Params testing:
# {'batch_size': 62, 'dropout_rate': 0.48193248246406833, 'embedding_dim': 183, 'epochs': 89, 'kernel_size': 8, 'l2_val': 1.4993188329591042e-06, 'learning_rate': 4.314567405859682e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 79}
# DONE!      F1 = 0.5742574257425742
# Params testing:
# {'batch_size': 54, 'dropout_rate': 0.5028838192640893, 'embedding_dim': 194, 'epochs': 115, 'kernel_size': 6, 'l2_val': 1.2816017348684444e-05, 'learning_rate': 6.60233624714033e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 74}
# DONE!      F1 = 0.5981308411214953
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.6502380308290062, 'embedding_dim': 244, 'epochs': 125, 'kernel_size': 12, 'l2_val': 5.440818860101592e-06, 'learning_rate': 9.401472809333164e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 102}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 57, 'dropout_rate': 0.615135830542653, 'embedding_dim': 247, 'epochs': 101, 'kernel_size': 12, 'l2_val': 9.318479394848294e-06, 'learning_rate': 5.539293770489601e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 112}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.572560500832331, 'embedding_dim': 229, 'epochs': 113, 'kernel_size': 13, 'l2_val': 7.849470272437496e-06, 'learning_rate': 9.793240130512459e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 105}
# DONE!      F1 = 0.625
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.5486706247797414, 'embedding_dim': 221, 'epochs': 113, 'kernel_size': 13, 'l2_val': 3.566431922318027e-05, 'learning_rate': 8.211584739344426e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 98}
# DONE!      F1 = 0.6181818181818182
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.535410980874819, 'embedding_dim': 229, 'epochs': 117, 'kernel_size': 14, 'l2_val': 1.8828942988556174e-05, 'learning_rate': 4.866901357062266e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 94}
# DONE!      F1 = 0.5871559633027522
# Params testing:
# {'batch_size': 75, 'dropout_rate': 0.5084207224523517, 'embedding_dim': 208, 'epochs': 128, 'kernel_size': 16, 'l2_val': 7.484438618449281e-06, 'learning_rate': 3.277557685979131e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 86}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 63, 'dropout_rate': 0.5695429072737634, 'embedding_dim': 240, 'epochs': 120, 'kernel_size': 14, 'l2_val': 1.4565272670818916e-05, 'learning_rate': 6.382765874569335e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 107}
# DONE!      F1 = 0.5981308411214953
# Params testing:
# {'batch_size': 37, 'dropout_rate': 0.6012212201049115, 'embedding_dim': 256, 'epochs': 103, 'kernel_size': 15, 'l2_val': 1.124681797391564e-05, 'learning_rate': 9.813599893295428e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 121}
# DONE!      F1 = 0.5982905982905983
# Params testing:
# {'batch_size': 48, 'dropout_rate': 0.4672528205628578, 'embedding_dim': 198, 'epochs': 110, 'kernel_size': 10, 'l2_val': 4.195177531314604e-06, 'learning_rate': 1.776450783789349e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 89}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 71, 'dropout_rate': 0.3941013322696626, 'embedding_dim': 235, 'epochs': 107, 'kernel_size': 15, 'l2_val': 2.3626075557860035e-05, 'learning_rate': 7.783592272993493e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 100}
# DONE!      F1 = 0.6140350877192983
# Params testing:
# {'batch_size': 82, 'dropout_rate': 0.5240532751698626, 'embedding_dim': 218, 'epochs': 84, 'kernel_size': 11, 'l2_val': 3.2893028159976576e-06, 'learning_rate': 3.888095527691429e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 105}
# DONE!      F1 = 0.5882352941176471
# Params testing:
# {'batch_size': 41, 'dropout_rate': 0.4585276653178354, 'embedding_dim': 252, 'epochs': 91, 'kernel_size': 16, 'l2_val': 6.606788269899129e-06, 'learning_rate': 5.761689256426672e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 96}
# DONE!      F1 = 0.5892857142857143
# Params testing:
# {'batch_size': 46, 'dropout_rate': 0.430685856182321, 'embedding_dim': 202, 'epochs': 97, 'kernel_size': 13, 'l2_val': 5.270607297629174e-06, 'learning_rate': 9.918175659643376e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 81}
# DONE!      F1 = 0.6296296296296297
# Params testing:
# {'batch_size': 35, 'dropout_rate': 0.5612509938985442, 'embedding_dim': 203, 'epochs': 97, 'kernel_size': 13, 'l2_val': 2.563966908978981e-06, 'learning_rate': 9.897955597009074e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 85}
# DONE!      F1 = 0.6017699115044246
# Params testing:
# {'batch_size': 51, 'dropout_rate': 0.42825469325443943, 'embedding_dim': 223, 'epochs': 100, 'kernel_size': 12, 'l2_val': 2.000468320566155e-06, 'learning_rate': 4.489558763465355e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 76}
# DONE!      F1 = 0.616822429906542
# Params testing:
# {'batch_size': 46, 'dropout_rate': 0.41962834532207294, 'embedding_dim': 213, 'epochs': 94, 'kernel_size': 15, 'l2_val': 5.476949530086936e-06, 'learning_rate': 6.986027978433627e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 65}
# DONE!      F1 = 0.6181818181818182
# Params testing:
# {'batch_size': 54, 'dropout_rate': 0.44294112893222726, 'embedding_dim': 199, 'epochs': 87, 'kernel_size': 11, 'l2_val': 1.7315150199689814e-06, 'learning_rate': 1.839786326250476e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 110}
# DONE!      F1 = 0.06593406593406594
# Params testing:
# {'batch_size': 21, 'dropout_rate': 0.3413399727484916, 'embedding_dim': 185, 'epochs': 83, 'kernel_size': 10, 'l2_val': 4.515453168107427e-05, 'learning_rate': 2.693607982405101e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 53}
# DONE!      F1 = 0.6019417475728155
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.37430317333396224, 'embedding_dim': 225, 'epochs': 80, 'kernel_size': 14, 'l2_val': 3.71711024906408e-06, 'learning_rate': 3.376948166941103e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 60}
# DONE!      F1 = 0.5961538461538461
# Params testing:
# {'batch_size': 128, 'dropout_rate': 0.36618585747182647, 'embedding_dim': 210, 'epochs': 105, 'kernel_size': 16, 'l2_val': 8.203672920312802e-06, 'learning_rate': 8.109632944947947e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 70}
# DONE!      F1 = 0.5818181818181818
# Params testing:
# {'batch_size': 24, 'dropout_rate': 0.4105466219957734, 'embedding_dim': 192, 'epochs': 115, 'kernel_size': 9, 'l2_val': 2.7927368421867407e-06, 'learning_rate': 5.152786036567599e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 80}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 42, 'dropout_rate': 0.486811692564735, 'embedding_dim': 206, 'epochs': 112, 'kernel_size': 13, 'l2_val': 1.1764099131053052e-06, 'learning_rate': 2.2104551006498892e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 117}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# ...
# DONE!      F1 = 0.5849056603773585
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.25200988413165887, 'embedding_dim': 196, 'epochs': 102, 'kernel_size': 13, 'l2_val': 0.00016202566611984108, 'learning_rate': 5.230915524825985e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 26}
# DONE!      F1 = 0.4605263157894737
# Params testing:
# {'batch_size': 34, 'dropout_rate': 0.2874507419256499, 'embedding_dim': 245, 'epochs': 117, 'kernel_size': 15, 'l2_val': 4.458559057685469e-05, 'learning_rate': 1.5202246885268644e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 22}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'batch_size': 44, 'dropout_rate': 0.26109241082677437, 'embedding_dim': 186, 'epochs': 69, 'kernel_size': 8, 'l2_val': 5.990467172585397e-05, 'learning_rate': 5.908318723067257e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 83}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 57, 'dropout_rate': 0.36984424092531215, 'embedding_dim': 207, 'epochs': 88, 'kernel_size': 10, 'l2_val': 3.872230591581413e-06, 'learning_rate': 3.22242339852575e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 73}
# DONE!      F1 = 0.5961538461538461
# Params testing:
# {'batch_size': 36, 'dropout_rate': 0.279181330629608, 'embedding_dim': 238, 'epochs': 76, 'kernel_size': 12, 'l2_val': 1.2344075787042968e-05, 'learning_rate': 8.490614318330911e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 55}
# DONE!      F1 = 0.607142857142857
# Params testing:
# {'batch_size': 18, 'dropout_rate': 0.34908311109449053, 'embedding_dim': 216, 'epochs': 123, 'kernel_size': 16, 'l2_val': 3.0386040213734005e-05, 'learning_rate': 3.72947908889609e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 29}
# DONE!      F1 = 0.6181818181818182
# Params testing:
# {'batch_size': 47, 'dropout_rate': 0.2522815674326974, 'embedding_dim': 252, 'epochs': 97, 'kernel_size': 14, 'l2_val': 0.0002648375177877019, 'learning_rate': 9.800580658761315e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 49}
# DONE!      F1 = 0.576
# Params testing:
# {'batch_size': 65, 'dropout_rate': 0.3175199410066236, 'embedding_dim': 225, 'epochs': 66, 'kernel_size': 9, 'l2_val': 1.0396839636221338e-06, 'learning_rate': 2.719753094598753e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 62}
# DONE!      F1 = 0.607142857142857
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.33212213704823085, 'embedding_dim': 189, 'epochs': 127, 'kernel_size': 7, 'l2_val': 5.120998134776958e-05, 'learning_rate': 1.7751916426174564e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 38}
# DONE!      F1 = 0.5769230769230769
# Params testing:
# {'batch_size': 61, 'dropout_rate': 0.2500955147757156, 'embedding_dim': 204, 'epochs': 81, 'kernel_size': 10, 'l2_val': 6.010463096258643e-06, 'learning_rate': 4.729078619861469e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 67}
# DONE!      F1 = 0.5849056603773585
# Params testing:
# {'batch_size': 40, 'dropout_rate': 0.2664543728024556, 'embedding_dim': 213, 'epochs': 91, 'kernel_size': 14, 'l2_val': 0.0004071639845118049, 'learning_rate': 1.148515479449096e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 51}
# DONE!      F1 = 0.6016260162601627
# Params testing:
# {'batch_size': 31, 'dropout_rate': 0.3010179743728189, 'embedding_dim': 233, 'epochs': 108, 'kernel_size': 13, 'l2_val': 1.4656782245595574e-05, 'learning_rate': 1.376033286848963e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 40}
# DONE!      F1 = 0.6181818181818182
# Params testing:
# {'batch_size': 22, 'dropout_rate': 0.3807002725177112, 'embedding_dim': 220, 'epochs': 112, 'kernel_size': 16, 'l2_val': 2.1054630962599082e-05, 'learning_rate': 2.0749202758727648e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 44}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 49, 'dropout_rate': 0.36382133845723397, 'embedding_dim': 183, 'epochs': 71, 'kernel_size': 11, 'l2_val': 4.2761297260741205e-06, 'learning_rate': 5.6711864761797705e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 60}
# DONE!      F1 = 0.26573426573426573
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.2840938096601721, 'embedding_dim': 160, 'epochs': 60, 'kernel_size': 6, 'l2_val': 0.00011867690505999864, 'learning_rate': 6.681038041301543e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 36}
# DONE!      F1 = 0.5882352941176471
# Params testing:
# {'batch_size': 26, 'dropout_rate': 0.4092777819241131, 'embedding_dim': 197, 'epochs': 106, 'kernel_size': 15, 'l2_val': 3.654401073039614e-05, 'learning_rate': 2.9616897421674254e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 32}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 34, 'dropout_rate': 0.3909148096073932, 'embedding_dim': 177, 'epochs': 110, 'kernel_size': 12, 'l2_val': 4.10991528518375e-05, 'learning_rate': 2.3442594624716575e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 53}
# DONE!      F1 = 0.594059405940594
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.4233407037396616, 'embedding_dim': 210, 'epochs': 115, 'kernel_size': 8, 'l2_val': 6.653864002136268e-05, 'learning_rate': 3.792694604542475e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 33}
# DONE!      F1 = 0.5660377358490566
# Params testing:
# {'batch_size': 18, 'dropout_rate': 0.2934118406529011, 'embedding_dim': 255, 'epochs': 101, 'kernel_size': 3, 'l2_val': 3.0502790196718176e-05, 'learning_rate': 1.8489772756808828e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 42}
# DONE!      F1 = 0.5825242718446602
# Params testing:
# {'batch_size': 55, 'dropout_rate': 0.34062845952123433, 'embedding_dim': 201, 'epochs': 87, 'kernel_size': 11, 'l2_val': 3.3673362684556027e-06, 'learning_rate': 6.917439923703039e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 74}
# DONE!      F1 = 0.45070422535211263
# Params testing:
# {'batch_size': 28, 'dropout_rate': 0.3079771061673021, 'embedding_dim': 192, 'epochs': 104, 'kernel_size': 15, 'l2_val': 2.7064503334158387e-05, 'learning_rate': 4.123154994471052e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 9}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 46, 'dropout_rate': 0.273631295851329, 'embedding_dim': 228, 'epochs': 99, 'kernel_size': 13, 'l2_val': 7.690371608767628e-05, 'learning_rate': 5.730455798634872e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 86}
# DONE!      F1 = 0.6140350877192983
# Params testing:
# {'batch_size': 32, 'dropout_rate': 0.31951901440394825, 'embedding_dim': 171, 'epochs': 111, 'kernel_size': 12, 'l2_val': 4.789092111380037e-05, 'learning_rate': 8.691937624857986e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 46}
# DONE!      F1 = 0.5967741935483871
# Params testing:
# {'batch_size': 23, 'dropout_rate': 0.358037137723155, 'embedding_dim': 142, 'epochs': 107, 'kernel_size': 7, 'l2_val': 2.2273986327917874e-05, 'learning_rate': 1.634628411166309e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 26}
# DONE!      F1 = 0.5499999999999999
# Params testing:
# {'batch_size': 51, 'dropout_rate': 0.32610540590436293, 'embedding_dim': 216, 'epochs': 84, 'kernel_size': 9, 'l2_val': 2.3817442020899164e-06, 'learning_rate': 7.424889806395477e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 69}
# DONE!      F1 = 0.5945945945945946
# Params testing:
# {'batch_size': 60, 'dropout_rate': 0.25012492073509535, 'embedding_dim': 222, 'epochs': 93, 'kernel_size': 10, 'l2_val': 7.806997869554723e-06, 'learning_rate': 4.727018397386821e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 66}
# DONE!      F1 = 0.5794392523364486
# Params testing:
# {'batch_size': 75, 'dropout_rate': 0.28687739795206973, 'embedding_dim': 204, 'epochs': 77, 'kernel_size': 11, 'l2_val': 1.3560602754875725e-06, 'learning_rate': 8.864155117692826e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 79}
# DONE!      F1 = 0.6017699115044246
# Params testing:
# {'batch_size': 25, 'dropout_rate': 0.3979417155839122, 'embedding_dim': 242, 'epochs': 120, 'kernel_size': 14, 'l2_val': 1.6866417246333886e-05, 'learning_rate': 3.213273257776186e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 55}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 39, 'dropout_rate': 0.25904501723634865, 'embedding_dim': 167, 'epochs': 98, 'kernel_size': 16, 'l2_val': 9.619733896670556e-05, 'learning_rate': 1.2724803088844183e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 58}
# DONE!      F1 = 0.607142857142857
# Params testing:
# {'batch_size': 43, 'dropout_rate': 0.2701062789700173, 'embedding_dim': 199, 'epochs': 56, 'kernel_size': 5, 'l2_val': 0.0001800855279692462, 'learning_rate': 7.501961832794507e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 89}
# DONE!      F1 = 0.3488372093023256
# Params testing:
# {'batch_size': 45, 'dropout_rate': 0.3042724835289511, 'embedding_dim': 232, 'epochs': 89, 'kernel_size': 13, 'l2_val': 8.111016711646883e-05, 'learning_rate': 2.578283674293794e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 48}
# DONE!      F1 = 0.6055045871559633
# Params testing:
# {'batch_size': 36, 'dropout_rate': 0.2789694214604726, 'embedding_dim': 208, 'epochs': 96, 'kernel_size': 12, 'l2_val': 0.00013536919056315075, 'learning_rate': 1.0310835469035277e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 51}
# DONE!      F1 = 0.5853658536585364
# Params testing:
# {'batch_size': 52, 'dropout_rate': 0.3351280469147707, 'embedding_dim': 186, 'epochs': 82, 'kernel_size': 9, 'l2_val': 4.71154680154298e-06, 'learning_rate': 9.969442645018044e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 64}
# DONE!      F1 = 0.6194690265486726
# Params testing:
# {'batch_size': 33, 'dropout_rate': 0.35052185594409524, 'embedding_dim': 247, 'epochs': 118, 'kernel_size': 8, 'l2_val': 5.527859209790758e-05, 'learning_rate': 2.0144219433214538e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 17}
# DONE!      F1 = 0.6285714285714286
# Params testing:
# {'batch_size': 49, 'dropout_rate': 0.3120479071738208, 'embedding_dim': 194, 'epochs': 79, 'kernel_size': 10, 'l2_val': 1.6205203718429535e-06, 'learning_rate': 1.2565262211695623e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 71}
# DONE!      F1 = 0.22972972972972974
# Params testing:
# {'batch_size': 69, 'dropout_rate': 0.37650502050662665, 'embedding_dim': 224, 'epochs': 52, 'kernel_size': 11, 'l2_val': 2.812117507381588e-06, 'learning_rate': 4.909257644320679e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 60}
# DONE!      F1 = 0.09195402298850575
# Params testing:
# {'batch_size': 29, 'dropout_rate': 0.29553688904025144, 'embedding_dim': 238, 'epochs': 113, 'kernel_size': 4, 'l2_val': 1.0547947865129113e-05, 'learning_rate': 2.2893947579027118e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 29}
# DONE!      F1 = 0.52
# Params testing:
# {'batch_size': 21, 'dropout_rate': 0.3647542713987819, 'embedding_dim': 212, 'epochs': 104, 'kernel_size': 7, 'l2_val': 3.320265923223466e-05, 'learning_rate': 3.513297948206284e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 41}
# DONE!      F1 = 0.5904761904761904
# Params testing:
# {'batch_size': 35, 'dropout_rate': 0.3460304532626328, 'embedding_dim': 235, 'epochs': 125, 'kernel_size': 14, 'l2_val': 1.9645946064576352e-05, 'learning_rate': 1.5278806908820175e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 54}
# DONE!      F1 = 0.5961538461538461
# Params testing:
# {'batch_size': 41, 'dropout_rate': 0.27073217515162284, 'embedding_dim': 181, 'epochs': 92, 'kernel_size': 15, 'l2_val': 0.0003508785309575851, 'learning_rate': 6.694186260146197e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 84}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 53, 'dropout_rate': 0.32527265555930884, 'embedding_dim': 175, 'epochs': 68, 'kernel_size': 10, 'l2_val': 1.0057131296970544e-06, 'learning_rate': 4.587707555753774e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 77}
# DONE!      F1 = 0.15873015873015875
# Params testing:
# {'batch_size': 16, 'dropout_rate': 0.46519116701074725, 'embedding_dim': 252, 'epochs': 101, 'kernel_size': 16, 'l2_val': 1.3485387963624716e-05, 'learning_rate': 2.9969164534248694e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 39}
# DONE!      F1 = 0.5925925925925926
# Params testing:
# {'batch_size': 125, 'dropout_rate': 0.3125767577275098, 'embedding_dim': 189, 'epochs': 73, 'kernel_size': 12, 'l2_val': 6.700662709022725e-06, 'learning_rate': 6.858243511422565e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 57}
# DONE!      F1 = 0.16666666666666666
# Params testing:
# {'batch_size': 116, 'dropout_rate': 0.3342494179706597, 'embedding_dim': 220, 'epochs': 122, 'kernel_size': 13, 'l2_val': 2.362181597444283e-05, 'learning_rate': 1.1905266988415424e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 44}
# DONE!      F1 = 0.5365853658536585
# Params testing:
# {'batch_size': 64, 'dropout_rate': 0.43430981701646576, 'embedding_dim': 203, 'epochs': 85, 'kernel_size': 11, 'l2_val': 5.748231980082578e-06, 'learning_rate': 5.095845819192178e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 62}
# DONE!      F1 = 0.6078431372549019
# Params testing:
# {'batch_size': 58, 'dropout_rate': 0.2914811591648812, 'embedding_dim': 206, 'epochs': 90, 'kernel_size': 9, 'l2_val': 3.2581674918628906e-06, 'learning_rate': 9.866576700205782e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 67}
# DONE!      F1 = 0.6260869565217392
# Params testing:
# {'batch_size': 38, 'dropout_rate': 0.3003392526330296, 'embedding_dim': 162, 'epochs': 115, 'kernel_size': 2, 'l2_val': 3.977229485141863e-05, 'learning_rate': 4.3633224036214345e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 20}
# DONE!      F1 = 0.594059405940594
# Params testing:
# {'batch_size': 45, 'dropout_rate': 0.2520828063675697, 'embedding_dim': 214, 'epochs': 62, 'kernel_size': 14, 'l2_val': 0.00027884964726047575, 'learning_rate': 6.188166095339566e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 36}
# DONE!      F1 = 0.30303030303030304
# Params testing:
# {'batch_size': 42, 'dropout_rate': 0.2768704034540749, 'embedding_dim': 228, 'epochs': 95, 'kernel_size': 6, 'l2_val': 0.0002056483440918587, 'learning_rate': 5.8219364612435594e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 31}
# DONE!      F1 = 0.5576923076923076
# Params testing:
# {'batch_size': 56, 'dropout_rate': 0.38318524828051764, 'embedding_dim': 197, 'epochs': 16, 'kernel_size': 11, 'l2_val': 2.2952088629813476e-06, 'learning_rate': 3.6958398232442496e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 80}
# DONE!      F1 = 0.1408450704225352
# Params testing:
# {'batch_size': 80, 'dropout_rate': 0.7467954641154338, 'embedding_dim': 219, 'epochs': 87, 'kernel_size': 10, 'l2_val': 1.152170188931354e-06, 'learning_rate': 7.570002224500923e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 74}
# DONE!      F1 = 0.6285714285714286
# Params testing:
# {'batch_size': 47, 'dropout_rate': 0.2508688378738652, 'embedding_dim': 240, 'epochs': 95, 'kernel_size': 15, 'l2_val': 0.00022311319890767255, 'learning_rate': 9.363580207708369e-06, 'max_len': 55, 'max_words': 5000, 'n_filters': 48}
# DONE!      F1 = 0.5801526717557252
# Params testing:
# {'batch_size': 26, 'dropout_rate': 0.4133331348473266, 'embedding_dim': 180, 'epochs': 128, 'kernel_size': 13, 'l2_val': 6.321398904923308e-05, 'learning_rate': 1.449795413967076e-05, 'max_len': 55, 'max_words': 5000, 'n_filters': 51}
# DONE!      F1 = 0.6126126126126126
# Params testing:
# {'batch_size': 40, 'dropout_rate': 0.28339811430398554, 'embedding_dim': 231, 'epochs': 83, 'kernel_size': 14, 'l2_val': 0.0005183524730425377, 'learning_rate': 2.2435422561713068e-07, 'max_len': 55, 'max_words': 5000, 'n_filters': 14}
# DONE!      F1 = 0.11363636363636363
# 100%|██████████| 500/500 [6:00:43<00:00, 43.29s/it, best loss: -0.6545454545454545]
# Best hyperparams:  {'batch_size': 30.0, 'dropout_rate': 0.3312500326531685, 'embedding_dim': 184.0, 'epochs': 99.0, 'kernel_size': 11.0, 'l2_val': 2.86715299646219e-05, 'learning_rate': 1.553281918810298e-05, 'n_filters': 44.0}
