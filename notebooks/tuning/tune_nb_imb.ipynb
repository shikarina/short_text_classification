# %% [markdown]
# # Tuning the NB classifier
#
# Hyperparameter sweep for the **multinomial naive Bayes classifier** for producing results with various **degrees of dataset imbalance**. Optimize the hyperparameters for the worst-case imbalance configuration. Optimization conducted by means of the tree-structured Parzen estimator.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import copy
import sys

# %%
# Sci-kit learn for machine learning tasks
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# HyperOptfor Bayesian optimization
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# ## Load and process data

# %%
# Load training set
train_set_file  = "train_set_imb_0.csv"
train_set = pd.read_csv(train_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])

# %% [markdown]
# ## Define hyperparameter search space and objective function

# %%
# Define the search space for hyperparameterss
hyperparam_space = {'alpha': hp.uniform('alpha', 0.1, 0.7),
                    'max_features': scope.int(hp.qloguniform('max_features', np.log(5e4), np.log(5e5), q=1)),
                    'vectorizer': hp.choice('vectorizer', ['tfidf', 'count']),
                    'fit_prior': hp.choice('fit_prior', [True, False])
                    }

# %%
# Define the objective function for optimization
def objective(params):   
    print ('Params testing: ', params)

    # Split dataset into training validation sets
    inp_train, inp_valid, lbl_train, lbl_valid = train_test_split(texts_train, labels_train, 
                                                                  test_size=0.15, 
                                                                  random_state=12345, 
                                                                  stratify=labels_train)
    
    # Compute class weights for compensation the imbalance in classes
    class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes = np.unique(lbl_train), y = lbl_train)
    class_weights = dict(zip(np.unique(lbl_train), class_weights))

    # Set vectorizer
    if params['vectorizer']=='tfidf':
        vectorizer = TfidfVectorizer(max_features=params['max_features'], lowercase=True, analyzer='word', dtype=np.float32)
    elif params['vectorizer']=='count':
        vectorizer = CountVectorizer()
    else:
        sys.exit("Unsupported vectorizer!")

    # Fit vectorizer
    vectorizer.fit(inp_train)
    features_train = vectorizer.transform(inp_train)
    features_valid = vectorizer.transform(inp_valid)

    # Define the model
    model = MultinomialNB(alpha=params['alpha'], fit_prior=params['fit_prior'], class_prior=None)
    
    # Fit the model
    model.fit(features_train, lbl_train)

    # Compute performance of the trial
    pred_scores = (model.predict(features_valid) > 0.5).astype("int32")
    f1 = f1_score(lbl_valid, pred_scores)
    print('DONE!      F1 = ' + str(f1))
    sys.stdout.flush() 
    return {'loss': -f1, 'status': STATUS_OK}

# %% [markdown]
# ## Run Bayesian optimization with Tree Parzen Estimator

# %%
trials = Trials()
best = fmin(objective, hyperparam_space, algo=tpe.suggest, max_evals=1e3, trials=trials)
print('Best hyperparams: ', best)
# Out:
# Params testing:
# {'alpha': 0.21368187052301807, 'fit_prior': False, 'max_features': 76693, 'vectorizer': 'count'}
# DONE!      F1 = 0.5063291139240507
# Params testing:
# {'alpha': 0.6568232659715779, 'fit_prior': False, 'max_features': 494977, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5510204081632653
# Params testing:
# {'alpha': 0.6694769892855779, 'fit_prior': True, 'max_features': 63791, 'vectorizer': 'count'}
# DONE!      F1 = 0.6122448979591837
# Params testing:
# {'alpha': 0.3865344776474846, 'fit_prior': False, 'max_features': 68756, 'vectorizer': 'count'}
# DONE!      F1 = 0.5270270270270271
# Params testing:
# {'alpha': 0.5798302538595695, 'fit_prior': False, 'max_features': 280349, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5631067961165047
# Params testing:
# {'alpha': 0.49735690671659927, 'fit_prior': True, 'max_features': 374511, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.16599202802888463, 'fit_prior': True, 'max_features': 104772, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'alpha': 0.5515926515639515, 'fit_prior': True, 'max_features': 184404, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.3622012156018498, 'fit_prior': False, 'max_features': 107723, 'vectorizer': 'count'}
# DONE!      F1 = 0.52
# Params testing:
# {'alpha': 0.6964943964881587, 'fit_prior': False, 'max_features': 116331, 'vectorizer': 'count'}
# DONE!      F1 = 0.5693430656934306
# Params testing:
# {'alpha': 0.29811749942014065, 'fit_prior': True, 'max_features': 135309, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.22056773237229005, 'fit_prior': True, 'max_features': 121353, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.6283002816729742, 'fit_prior': False, 'max_features': 262732, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5742574257425742
# Params testing:
# {'alpha': 0.47498058463138726, 'fit_prior': False, 'max_features': 154414, 'vectorizer': 'count'}
# DONE!      F1 = 0.5454545454545454
# Params testing:
# {'alpha': 0.21701178256256973, 'fit_prior': True, 'max_features': 300288, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'alpha': 0.2325517295538847, 'fit_prior': True, 'max_features': 249914, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.25396825396825395
# Params testing:
# {'alpha': 0.5432488441842444, 'fit_prior': True, 'max_features': 138663, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.5754454169458589, 'fit_prior': True, 'max_features': 214910, 'vectorizer': 'count'}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'alpha': 0.1722870558379086, 'fit_prior': True, 'max_features': 95939, 'vectorizer': 'count'}
# DONE!      F1 = 0.6495726495726496
# Params testing:
# {'alpha': 0.350680789450332, 'fit_prior': True, 'max_features': 274227, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.13559322033898305
# Params testing:
# {'alpha': 0.2905361598045226, 'fit_prior': True, 'max_features': 85236, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3023295887128888, 'fit_prior': True, 'max_features': 81934, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.2964033347934755, 'fit_prior': True, 'max_features': 50297, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.12043258238069898, 'fit_prior': True, 'max_features': 54070, 'vectorizer': 'count'}
# DONE!      F1 = 0.6440677966101694
# Params testing:
# {'alpha': 0.42880118834254494, 'fit_prior': True, 'max_features': 79395, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.31190025490757317, 'fit_prior': True, 'max_features': 51368, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4320953775199007, 'fit_prior': True, 'max_features': 54134, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.2652750803296004, 'fit_prior': True, 'max_features': 88842, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.13364911606022942, 'fit_prior': True, 'max_features': 64712, 'vectorizer': 'count'}
# DONE!      F1 = 0.6440677966101694
# Params testing:
# {'alpha': 0.2609891369450277, 'fit_prior': True, 'max_features': 70384, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.33118982667580044, 'fit_prior': True, 'max_features': 84039, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.17162399671510886, 'fit_prior': True, 'max_features': 61152, 'vectorizer': 'count'}
# DONE!      F1 = 0.6495726495726496
# Params testing:
# {'alpha': 0.38947393347306025, 'fit_prior': False, 'max_features': 51408, 'vectorizer': 'count'}
# DONE!      F1 = 0.5342465753424658
# Params testing:
# {'alpha': 0.42988435746220344, 'fit_prior': True, 'max_features': 172302, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.48201964524524066, 'fit_prior': False, 'max_features': 59468, 'vectorizer': 'count'}
# DONE!      F1 = 0.5454545454545454
# Params testing:
# {'alpha': 0.1000979113048962, 'fit_prior': True, 'max_features': 90316, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.37681159420289856
# Params testing:
# {'alpha': 0.26372934812837756, 'fit_prior': True, 'max_features': 457295, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.33346300755109176, 'fit_prior': False, 'max_features': 51641, 'vectorizer': 'count'}
# DONE!      F1 = 0.513157894736842
# Params testing:
# {'alpha': 0.40717093714318653, 'fit_prior': True, 'max_features': 73514, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.19080490485520712, 'fit_prior': True, 'max_features': 356507, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.36645096204994626, 'fit_prior': False, 'max_features': 102471, 'vectorizer': 'count'}
# DONE!      F1 = 0.52
# Params testing:
# {'alpha': 0.1439547851384275, 'fit_prior': True, 'max_features': 134132, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.3076923076923077
# Params testing:
# {'alpha': 0.28861330593409656, 'fit_prior': True, 'max_features': 204926, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3243184699633567, 'fit_prior': False, 'max_features': 75295, 'vectorizer': 'count'}
# DONE!      F1 = 0.5098039215686275
# Params testing:
# {'alpha': 0.5215322143749079, 'fit_prior': True, 'max_features': 58089, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.24934241111070587, 'fit_prior': True, 'max_features': 66500, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.644106643514154, 'fit_prior': False, 'max_features': 204549, 'vectorizer': 'count'}
# DONE!      F1 = 0.5652173913043479
# Params testing:
# {'alpha': 0.45671430629845244, 'fit_prior': True, 'max_features': 108361, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.6073241598649347, 'fit_prior': True, 'max_features': 229802, 'vectorizer': 'count'}
# DONE!      F1 = 0.6213592233009707
# Params testing:
# {'alpha': 0.19299234902821621, 'fit_prior': False, 'max_features': 331436, 'vectorizer': 'count'}
# DONE!      F1 = 0.5095541401273885
# Params testing:
# {'alpha': 0.367211125873619, 'fit_prior': True, 'max_features': 154302, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.13559322033898305
# Params testing:
# {'alpha': 0.24030964041011385, 'fit_prior': True, 'max_features': 123084, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.5086226160414495, 'fit_prior': True, 'max_features': 430557, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.19451143032714432, 'fit_prior': False, 'max_features': 172120, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.557142857142857
# Params testing:
# {'alpha': 0.6943625338186492, 'fit_prior': True, 'max_features': 56221, 'vectorizer': 'count'}
# DONE!      F1 = 0.5979381443298969
# Params testing:
# {'alpha': 0.4063324659104782, 'fit_prior': True, 'max_features': 101304, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.28427450125659753, 'fit_prior': True, 'max_features': 203688, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.2218647452267893, 'fit_prior': True, 'max_features': 115115, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.3427634144621325, 'fit_prior': True, 'max_features': 89124, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4495083278027047, 'fit_prior': False, 'max_features': 142572, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5739130434782609
# Params testing:
# {'alpha': 0.32377743391023156, 'fit_prior': True, 'max_features': 80058, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.10399922070706577, 'fit_prior': True, 'max_features': 70136, 'vectorizer': 'count'}
# DONE!      F1 = 0.6440677966101694
# Params testing:
# {'alpha': 0.5616498174371071, 'fit_prior': True, 'max_features': 93162, 'vectorizer': 'count'}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'alpha': 0.1516258944191895, 'fit_prior': False, 'max_features': 301289, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5405405405405405
# Params testing:
# {'alpha': 0.30220813150155695, 'fit_prior': True, 'max_features': 83562, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.38574010499969064, 'fit_prior': True, 'max_features': 235808, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3812925937734927, 'fit_prior': True, 'max_features': 221596, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3845240902249803, 'fit_prior': True, 'max_features': 239280, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.4735835501571232, 'fit_prior': True, 'max_features': 241015, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.42127095800979925, 'fit_prior': True, 'max_features': 184666, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3949715701406325, 'fit_prior': True, 'max_features': 288893, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.5229487092955969, 'fit_prior': True, 'max_features': 395151, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.3521481693429467, 'fit_prior': True, 'max_features': 290299, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.45010743313223034, 'fit_prior': True, 'max_features': 264355, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3804133452403304, 'fit_prior': True, 'max_features': 491285, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.49868589333818786, 'fit_prior': True, 'max_features': 474976, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.4647726582054695, 'fit_prior': True, 'max_features': 315131, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.5432123929753424, 'fit_prior': True, 'max_features': 403405, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.4873062690644533, 'fit_prior': True, 'max_features': 357585, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.5873157462847102, 'fit_prior': True, 'max_features': 489020, 'vectorizer': 'count'}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'alpha': 0.2786482473077611, 'fit_prior': False, 'max_features': 166828, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5757575757575758
# Params testing:
# {'alpha': 0.4167495518474137, 'fit_prior': True, 'max_features': 261178, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.44240299488389145, 'fit_prior': True, 'max_features': 185400, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3774803205040225, 'fit_prior': True, 'max_features': 212567, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3746346639658633, 'fit_prior': True, 'max_features': 331980, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.40760727147711817, 'fit_prior': False, 'max_features': 422144, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5811965811965812
# Params testing:
# {'alpha': 0.3111444606338103, 'fit_prior': True, 'max_features': 334444, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3978733262674768, 'fit_prior': True, 'max_features': 217422, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.6060185530760314, 'fit_prior': True, 'max_features': 277283, 'vectorizer': 'count'}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'alpha': 0.34598215752801187, 'fit_prior': False, 'max_features': 375270, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5483870967741936
# Params testing:
# {'alpha': 0.35829534439523925, 'fit_prior': True, 'max_features': 150068, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3641542193036212, 'fit_prior': True, 'max_features': 146512, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.2767619254668594, 'fit_prior': True, 'max_features': 127954, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.4356217528196542, 'fit_prior': True, 'max_features': 194669, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3154396231150991, 'fit_prior': False, 'max_features': 163898, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5625
# Params testing:
# {'alpha': 0.2551780614730165, 'fit_prior': True, 'max_features': 220009, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.33404544581940837, 'fit_prior': True, 'max_features': 443025, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.5241334049136186, 'fit_prior': True, 'max_features': 245538, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.5062878475262033, 'fit_prior': False, 'max_features': 253335, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5688073394495413
# Params testing:
# {'alpha': 0.22402492495087828, 'fit_prior': True, 'max_features': 111220, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.470080013766246, 'fit_prior': True, 'max_features': 328088, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.3590682386451301, 'fit_prior': True, 'max_features': 153464, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.48540832302367987, 'fit_prior': True, 'max_features': 136401, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.41899577043614844, 'fit_prior': False, 'max_features': 226401, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5862068965517241
# Params testing:
# {'alpha': 0.3708410558375122, 'fit_prior': True, 'max_features': 193402, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.240839005259561, 'fit_prior': True, 'max_features': 194455, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.39866231610875585, 'fit_prior': True, 'max_features': 121738, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.1976342966963377, 'fit_prior': True, 'max_features': 97415, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.5524426757376234, 'fit_prior': True, 'max_features': 174858, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.5380878636732096, 'fit_prior': False, 'max_features': 161520, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5660377358490566
# Params testing:
# {'alpha': 0.26564975362575105, 'fit_prior': True, 'max_features': 145404, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.15899690071861955, 'fit_prior': True, 'max_features': 157315, 'vectorizer': 'count'}
# DONE!      F1 = 0.6495726495726496
# Params testing:
# {'alpha': 0.45754696612494805, 'fit_prior': True, 'max_features': 496650, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.2989689973766987, 'fit_prior': True, 'max_features': 294900, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3885149254366789, 'fit_prior': False, 'max_features': 385338, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.18035817360469522, 'fit_prior': True, 'max_features': 129468, 'vectorizer': 'count'}
# DONE!      F1 = 0.6495726495726496
# Params testing:
# {'alpha': 0.20855820017949853, 'fit_prior': True, 'max_features': 309434, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.4006754145926365, 'fit_prior': True, 'max_features': 353664, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.5751546177013356, 'fit_prior': True, 'max_features': 266260, 'vectorizer': 'count'}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'alpha': 0.3215590905041008, 'fit_prior': False, 'max_features': 412174, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5511811023622047
# Params testing:
# {'alpha': 0.435810141762746, 'fit_prior': True, 'max_features': 196561, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.12901054170544674, 'fit_prior': True, 'max_features': 147391, 'vectorizer': 'count'}
# DONE!      F1 = 0.6440677966101694
# Params testing:
# {'alpha': 0.3528658800389836, 'fit_prior': True, 'max_features': 175626, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.33502089174243943, 'fit_prior': True, 'max_features': 237288, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.6491727947611072, 'fit_prior': False, 'max_features': 276013, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5510204081632653
# Params testing:
# {'alpha': 0.36277448264023465, 'fit_prior': True, 'max_features': 105690, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.6735058939718462, 'fit_prior': True, 'max_features': 63103, 'vectorizer': 'count'}
# DONE!      F1 = 0.6122448979591837
# Params testing:
# {'alpha': 0.3749725750598611, 'fit_prior': True, 'max_features': 210920, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.27021222609832396, 'fit_prior': True, 'max_features': 210570, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.28852882209002256, 'fit_prior': False, 'max_features': 113965, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5801526717557252
# Params testing:
# {'alpha': 0.3084661069669681, 'fit_prior': True, 'max_features': 128859, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4129912031753908, 'fit_prior': True, 'max_features': 231245, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.42766839104184073, 'fit_prior': True, 'max_features': 355030, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.611340939665296, 'fit_prior': True, 'max_features': 187634, 'vectorizer': 'count'}
# DONE!      F1 = 0.6213592233009707
# Params testing:
# {'alpha': 0.44906069721023967, 'fit_prior': False, 'max_features': 323568, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5739130434782609
# Params testing:
# {'alpha': 0.4694835420379515, 'fit_prior': True, 'max_features': 140808, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.24762590236934517, 'fit_prior': True, 'max_features': 254287, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.4811369617950383, 'fit_prior': True, 'max_features': 451561, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.34180393224334754, 'fit_prior': True, 'max_features': 181818, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4970224257556358, 'fit_prior': True, 'max_features': 118012, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.23043404651876512, 'fit_prior': False, 'max_features': 288289, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5629629629629629
# Params testing:
# {'alpha': 0.5318707587000967, 'fit_prior': True, 'max_features': 342899, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.5145814674315099, 'fit_prior': True, 'max_features': 309700, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.2942121702075757, 'fit_prior': True, 'max_features': 98770, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.1125696094061654, 'fit_prior': True, 'max_features': 169304, 'vectorizer': 'count'}
# DONE!      F1 = 0.6440677966101694
# Params testing:
# {'alpha': 0.3516057722025531, 'fit_prior': True, 'max_features': 178213, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3913416868863754, 'fit_prior': True, 'max_features': 75749, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.4583463756657089, 'fit_prior': True, 'max_features': 223829, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.377171537696253, 'fit_prior': True, 'max_features': 370775, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.31916590948212115, 'fit_prior': True, 'max_features': 76969, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.42081401122216094, 'fit_prior': True, 'max_features': 256702, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4416293180970802, 'fit_prior': True, 'max_features': 65995, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.49487515395166165, 'fit_prior': True, 'max_features': 212432, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.36974316033853877, 'fit_prior': True, 'max_features': 94726, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3321417293182775, 'fit_prior': True, 'max_features': 86032, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.40382068766516543, 'fit_prior': True, 'max_features': 465503, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.3063589868279778, 'fit_prior': True, 'max_features': 435567, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3604060755364565, 'fit_prior': True, 'max_features': 134669, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.42672725535645917, 'fit_prior': True, 'max_features': 132875, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.37609959523012015, 'fit_prior': True, 'max_features': 101736, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.2783220572100645, 'fit_prior': True, 'max_features': 153569, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.3443385290945214, 'fit_prior': False, 'max_features': 107435, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5483870967741936
# Params testing:
# {'alpha': 0.39210287710392205, 'fit_prior': True, 'max_features': 72177, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.41126993016593255, 'fit_prior': True, 'max_features': 68995, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.21520898807712158, 'fit_prior': True, 'max_features': 55451, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.4483128993684363, 'fit_prior': True, 'max_features': 284361, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.25784187055331864, 'fit_prior': True, 'max_features': 201145, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.3187253744432419, 'fit_prior': False, 'max_features': 404182, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5511811023622047
# Params testing:
# {'alpha': 0.2392357049806379, 'fit_prior': True, 'max_features': 118405, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.3633888261298859, 'fit_prior': True, 'max_features': 124586, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.5543315134886321, 'fit_prior': True, 'max_features': 374464, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.5681090231354333, 'fit_prior': True, 'max_features': 244947, 'vectorizer': 'count'}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'alpha': 0.3281679333029132, 'fit_prior': False, 'max_features': 148424, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5555555555555555
# Params testing:
# {'alpha': 0.3837110849129655, 'fit_prior': True, 'max_features': 367080, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.205755041556132, 'fit_prior': True, 'max_features': 138400, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.5050627577554456, 'fit_prior': True, 'max_features': 268700, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.4326645544313366, 'fit_prior': True, 'max_features': 58941, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.5871775430298619, 'fit_prior': True, 'max_features': 420770, 'vectorizer': 'count'}
# DONE!      F1 = 0.6153846153846153
# Params testing:
# {'alpha': 0.4663652127309737, 'fit_prior': False, 'max_features': 301770, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.18219189024101146, 'fit_prior': True, 'max_features': 110825, 'vectorizer': 'count'}
# DONE!      F1 = 0.6551724137931035
# Params testing:
# {'alpha': 0.28769789504381105, 'fit_prior': True, 'max_features': 91806, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.35556382254743435, 'fit_prior': True, 'max_features': 162583, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.27053981357568574, 'fit_prior': True, 'max_features': 157817, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.2981195460779563, 'fit_prior': False, 'max_features': 238769, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5692307692307692
# Params testing:
# {'alpha': 0.4784136552821295, 'fit_prior': True, 'max_features': 83359, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.39753792943539734, 'fit_prior': True, 'max_features': 345505, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3399954585974165, 'fit_prior': True, 'max_features': 169177, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4178816385426882, 'fit_prior': True, 'max_features': 205929, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.48848503848229374, 'fit_prior': True, 'max_features': 462866, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.3674088719682755, 'fit_prior': True, 'max_features': 124123, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.36763854568652193, 'fit_prior': True, 'max_features': 123137, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.24857162515207315, 'fit_prior': False, 'max_features': 120058, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.43949606011480247, 'fit_prior': True, 'max_features': 185992, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.310704427853571, 'fit_prior': True, 'max_features': 231288, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3817155609559874, 'fit_prior': True, 'max_features': 397704, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3241917146371802, 'fit_prior': True, 'max_features': 101590, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.45995488484218167, 'fit_prior': True, 'max_features': 73882, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4051080963675039, 'fit_prior': False, 'max_features': 323060, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.576271186440678
# Params testing:
# {'alpha': 0.38697547030375, 'fit_prior': True, 'max_features': 52164, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.5286538555145484, 'fit_prior': True, 'max_features': 63103, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.4269833666280799, 'fit_prior': True, 'max_features': 367733, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.5140371617532395, 'fit_prior': True, 'max_features': 71028, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.45153220446296816, 'fit_prior': True, 'max_features': 86752, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.2802067262149759, 'fit_prior': False, 'max_features': 95125, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5757575757575758
# Params testing:
# {'alpha': 0.3456449691315648, 'fit_prior': True, 'max_features': 244040, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.2968578688756128, 'fit_prior': True, 'max_features': 103494, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.26746812659174923, 'fit_prior': True, 'max_features': 132659, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.23078166368141337, 'fit_prior': True, 'max_features': 154076, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.46991015807123493, 'fit_prior': True, 'max_features': 60930, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.1394096011387111, 'fit_prior': False, 'max_features': 89906, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5333333333333333
# Params testing:
# {'alpha': 0.41320205573445645, 'fit_prior': True, 'max_features': 222596, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.33543414253081677, 'fit_prior': True, 'max_features': 81958, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.37530048808071886, 'fit_prior': True, 'max_features': 75269, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3939373295106249, 'fit_prior': True, 'max_features': 67204, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.43797831630662815, 'fit_prior': True, 'max_features': 79097, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3552890454573878, 'fit_prior': False, 'max_features': 142031, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5573770491803278
# Params testing:
# {'alpha': 0.6318538413920475, 'fit_prior': True, 'max_features': 57486, 'vectorizer': 'count'}
# DONE!      F1 = 0.6
# Params testing:
# {'alpha': 0.48227648903869513, 'fit_prior': True, 'max_features': 277820, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.40702925501332726, 'fit_prior': True, 'max_features': 94885, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.3077112870691188, 'fit_prior': True, 'max_features': 294153, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.32691538046651547, 'fit_prior': False, 'max_features': 176156, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5555555555555555
# Params testing:
# {'alpha': 0.16906011184710237, 'fit_prior': True, 'max_features': 107396, 'vectorizer': 'count'}
# DONE!      F1 = 0.6495726495726496
# Params testing:
# {'alpha': 0.688371056201603, 'fit_prior': True, 'max_features': 53270, 'vectorizer': 'count'}
# DONE!      F1 = 0.5979381443298969
# Params testing:
# {'alpha': 0.257950318652826, 'fit_prior': True, 'max_features': 312819, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.5442020854068905, 'fit_prior': True, 'max_features': 339466, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.42716654440612556, 'fit_prior': True, 'max_features': 385145, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.39654992034299485, 'fit_prior': True, 'max_features': 113759, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.5163011630496105, 'fit_prior': True, 'max_features': 78700, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.36718235266962884, 'fit_prior': False, 'max_features': 126397, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5619834710743802
# Params testing:
# {'alpha': 0.28554991350437176, 'fit_prior': True, 'max_features': 135999, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.31501381981252147, 'fit_prior': True, 'max_features': 196056, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4945332251742457, 'fit_prior': True, 'max_features': 217904, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.45416369897554754, 'fit_prior': True, 'max_features': 393898, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3450289156135114, 'fit_prior': False, 'max_features': 56170, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5483870967741936
# Params testing:
# {'alpha': 0.5019064620768515, 'fit_prior': True, 'max_features': 50728, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.20440104982638307, 'fit_prior': True, 'max_features': 481675, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.3855717651310025, 'fit_prior': True, 'max_features': 111995, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.5636553480712496, 'fit_prior': True, 'max_features': 203810, 'vectorizer': 'count'}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'alpha': 0.4416374062668995, 'fit_prior': True, 'max_features': 255383, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.33412654687956844, 'fit_prior': False, 'max_features': 189137, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.56
# Params testing:
# {'alpha': 0.2430399627498076, 'fit_prior': True, 'max_features': 100857, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.3636955251051254, 'fit_prior': True, 'max_features': 128541, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.22508938999250186, 'fit_prior': True, 'max_features': 143728, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.41538997010322265, 'fit_prior': True, 'max_features': 329239, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4729542242036684, 'fit_prior': True, 'max_features': 72072, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.40185004484598924, 'fit_prior': False, 'max_features': 269011, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.576271186440678
# Params testing:
# {'alpha': 0.29833793726684193, 'fit_prior': True, 'max_features': 114994, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.34991428108857403, 'fit_prior': True, 'max_features': 88125, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.46166041324595825, 'fit_prior': True, 'max_features': 430720, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.613817206847665, 'fit_prior': True, 'max_features': 226711, 'vectorizer': 'count'}
# DONE!      F1 = 0.6213592233009707
# Params testing:
# {'alpha': 0.27774693395682754, 'fit_prior': True, 'max_features': 160230, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.31654423376585566, 'fit_prior': True, 'max_features': 103826, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.1825658158595956, 'fit_prior': False, 'max_features': 64539, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5531914893617021
# Params testing:
# {'alpha': 0.26422109836713276, 'fit_prior': True, 'max_features': 84220, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.37512603611437506, 'fit_prior': True, 'max_features': 98109, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.42855689981336315, 'fit_prior': True, 'max_features': 284646, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.5305247514448475, 'fit_prior': True, 'max_features': 180826, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.39769912367351057, 'fit_prior': True, 'max_features': 254730, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3851322214265291, 'fit_prior': True, 'max_features': 357575, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3818271879745232, 'fit_prior': True, 'max_features': 232868, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.4208060157841617, 'fit_prior': True, 'max_features': 232335, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3559409450470852, 'fit_prior': True, 'max_features': 297135, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.32699144240544187, 'fit_prior': True, 'max_features': 124837, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.44952165111012826, 'fit_prior': True, 'max_features': 406700, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.33678319163494713, 'fit_prior': True, 'max_features': 149830, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.36150261466163053, 'fit_prior': True, 'max_features': 164041, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.40499492843505336, 'fit_prior': True, 'max_features': 164657, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.4351823921229624, 'fit_prior': True, 'max_features': 210481, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.30636283440542683, 'fit_prior': True, 'max_features': 498122, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3465073296559898, 'fit_prior': True, 'max_features': 452400, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.37673719137969486, 'fit_prior': True, 'max_features': 97119, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3741155846923031, 'fit_prior': True, 'max_features': 77676, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3884658809111005, 'fit_prior': True, 'max_features': 61726, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.41235707725694204, 'fit_prior': True, 'max_features': 116778, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.2857136035395663, 'fit_prior': True, 'max_features': 107984, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.48371372672127133, 'fit_prior': True, 'max_features': 92574, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.319164788698769, 'fit_prior': True, 'max_features': 171388, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.46178245128486417, 'fit_prior': True, 'max_features': 52843, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3948876917086607, 'fit_prior': True, 'max_features': 265106, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3922628377237607, 'fit_prior': True, 'max_features': 69421, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.44753262174033526, 'fit_prior': False, 'max_features': 68060, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5739130434782609
# Params testing:
# {'alpha': 0.364519025656989, 'fit_prior': True, 'max_features': 142540, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.2525622582157155, 'fit_prior': True, 'max_features': 138408, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.41618490603874686, 'fit_prior': True, 'max_features': 73336, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3035963835035024, 'fit_prior': True, 'max_features': 127639, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.34047315092119795, 'fit_prior': True, 'max_features': 319110, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3559346210310814, 'fit_prior': True, 'max_features': 192760, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4747626061580983, 'fit_prior': False, 'max_features': 157305, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5765765765765765
# Params testing:
# {'alpha': 0.43471472979102893, 'fit_prior': True, 'max_features': 59730, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4894458780121332, 'fit_prior': True, 'max_features': 354511, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.32756507031376675, 'fit_prior': True, 'max_features': 85896, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.29257035823878735, 'fit_prior': True, 'max_features': 179602, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4256138737930159, 'fit_prior': True, 'max_features': 81368, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.349381401285501, 'fit_prior': True, 'max_features': 202636, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3851610163687716, 'fit_prior': False, 'max_features': 50206, 'vectorizer': 'count'}
# DONE!      F1 = 0.5270270270270271
# Params testing:
# {'alpha': 0.40445102762014046, 'fit_prior': True, 'max_features': 148467, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.5078772461964918, 'fit_prior': True, 'max_features': 275369, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.3125535143158375, 'fit_prior': True, 'max_features': 336587, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.37432779204963584, 'fit_prior': True, 'max_features': 378803, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.27162911218319286, 'fit_prior': True, 'max_features': 423676, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.45321278868200443, 'fit_prior': True, 'max_features': 255964, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.33754226007513805, 'fit_prior': False, 'max_features': 94123, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5483870967741936
# Params testing:
# {'alpha': 0.4404340700015118, 'fit_prior': True, 'max_features': 173032, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.37435669171695773, 'fit_prior': True, 'max_features': 65204, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.21317843310064666, 'fit_prior': True, 'max_features': 218090, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.46610687112930105, 'fit_prior': True, 'max_features': 306346, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.3957832127889976, 'fit_prior': True, 'max_features': 62473, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3271411408576758, 'fit_prior': True, 'max_features': 89755, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4175031510389353, 'fit_prior': False, 'max_features': 74558, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5862068965517241
# Params testing:
# {'alpha': 0.3571229284307983, 'fit_prior': True, 'max_features': 473960, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.28211525441694074, 'fit_prior': True, 'max_features': 108686, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.4044136198118685, 'fit_prior': True, 'max_features': 121148, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.29889597202317253, 'fit_prior': True, 'max_features': 111705, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.5487223969309997, 'fit_prior': True, 'max_features': 239554, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.4218166616152103, 'fit_prior': True, 'max_features': 121554, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3625983301280797, 'fit_prior': False, 'max_features': 135380, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5619834710743802
# Params testing:
# {'alpha': 0.26420153699890686, 'fit_prior': True, 'max_features': 436561, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.57987221997608, 'fit_prior': True, 'max_features': 56750, 'vectorizer': 'count'}
# DONE!      F1 = 0.6095238095238096
# Params testing:
# {'alpha': 0.3440513308482614, 'fit_prior': True, 'max_features': 369234, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.5377558118219736, 'fit_prior': True, 'max_features': 68240, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.4980085918177097, 'fit_prior': True, 'max_features': 98685, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.4766343946131695, 'fit_prior': False, 'max_features': 198563, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5765765765765765
# Params testing:
# {'alpha': 0.4532449938166236, 'fit_prior': True, 'max_features': 117095, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.23392826438467468, 'fit_prior': True, 'max_features': 100836, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# ...
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3835277802054747, 'fit_prior': True, 'max_features': 85010, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.4361944771867104, 'fit_prior': True, 'max_features': 306306, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4909406944395453, 'fit_prior': False, 'max_features': 408646, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5818181818181818
# Params testing:
# {'alpha': 0.3353175486169997, 'fit_prior': True, 'max_features': 102202, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.40017050368863616, 'fit_prior': True, 'max_features': 55380, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.42011440151610296, 'fit_prior': True, 'max_features': 434509, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3828093829319705, 'fit_prior': True, 'max_features': 197748, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.4421368220025374, 'fit_prior': True, 'max_features': 247741, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4698664351964777, 'fit_prior': True, 'max_features': 451928, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.3479036577942249, 'fit_prior': True, 'max_features': 117372, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.34293809882255744, 'fit_prior': True, 'max_features': 128351, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3590556026860822, 'fit_prior': True, 'max_features': 137718, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3722284352651474, 'fit_prior': False, 'max_features': 122368, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.45873583360474646, 'fit_prior': True, 'max_features': 79646, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.32229226866790706, 'fit_prior': True, 'max_features': 109233, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.39713115338781774, 'fit_prior': True, 'max_features': 354007, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.39855653642448097, 'fit_prior': True, 'max_features': 322030, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.428894356322667, 'fit_prior': True, 'max_features': 440675, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3581603846455465, 'fit_prior': True, 'max_features': 146412, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3043837259746518, 'fit_prior': True, 'max_features': 334970, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4143952314076407, 'fit_prior': True, 'max_features': 65182, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.4350492697403308, 'fit_prior': True, 'max_features': 495747, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.37207398155305493, 'fit_prior': False, 'max_features': 51780, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.34079082120705007, 'fit_prior': True, 'max_features': 142954, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.45333541687419177, 'fit_prior': True, 'max_features': 60029, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3279495761500584, 'fit_prior': True, 'max_features': 120393, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.35212914526722205, 'fit_prior': True, 'max_features': 375777, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4906976235453331, 'fit_prior': True, 'max_features': 447510, 'vectorizer': 'count'}
# DONE!      F1 = 0.6481481481481481
# Params testing:
# {'alpha': 0.3677007432066786, 'fit_prior': True, 'max_features': 56542, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.2983396611940925, 'fit_prior': True, 'max_features': 93378, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4073670125640356, 'fit_prior': False, 'max_features': 100291, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5811965811965812
# Params testing:
# {'alpha': 0.3148170230627325, 'fit_prior': True, 'max_features': 77151, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.37647239557585843, 'fit_prior': True, 'max_features': 75754, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3498294138066782, 'fit_prior': True, 'max_features': 133620, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.3806213488945891, 'fit_prior': True, 'max_features': 369928, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.41857443446898496, 'fit_prior': True, 'max_features': 387855, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4625154597275899, 'fit_prior': True, 'max_features': 351115, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.28765341327683347, 'fit_prior': True, 'max_features': 175965, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.33368186695808194, 'fit_prior': True, 'max_features': 57948, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.26277387291930077, 'fit_prior': True, 'max_features': 139526, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.39246252101524653, 'fit_prior': False, 'max_features': 132018, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.3211462595920418, 'fit_prior': True, 'max_features': 97756, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.36350248063508156, 'fit_prior': True, 'max_features': 300726, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.2502195451020567, 'fit_prior': True, 'max_features': 106168, 'vectorizer': 'count'}
# DONE!      F1 = 0.6608695652173913
# Params testing:
# {'alpha': 0.4097563118180019, 'fit_prior': True, 'max_features': 133103, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.4238560006383918, 'fit_prior': True, 'max_features': 280972, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4501102238726245, 'fit_prior': True, 'max_features': 401241, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.39450582930695444, 'fit_prior': True, 'max_features': 332913, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.38829372964472936, 'fit_prior': True, 'max_features': 117871, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.36814908129771723, 'fit_prior': True, 'max_features': 50079, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.34566683414441113, 'fit_prior': True, 'max_features': 55602, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.38671189621569413, 'fit_prior': False, 'max_features': 149328, 'vectorizer': 'count'}
# DONE!      F1 = 0.5306122448979591
# Params testing:
# {'alpha': 0.408848418977013, 'fit_prior': True, 'max_features': 72087, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.5204171655108291, 'fit_prior': True, 'max_features': 395991, 'vectorizer': 'count'}
# DONE!      F1 = 0.6226415094339622
# Params testing:
# {'alpha': 0.3583716074489086, 'fit_prior': True, 'max_features': 213690, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.33419508611912435, 'fit_prior': True, 'max_features': 418105, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.3131665139390579, 'fit_prior': True, 'max_features': 202334, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.4807369060897315, 'fit_prior': True, 'max_features': 304459, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.44316687030338753, 'fit_prior': True, 'max_features': 220188, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.40487581955258045, 'fit_prior': True, 'max_features': 155919, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.4320011731408672, 'fit_prior': True, 'max_features': 178847, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.2869552570485369, 'fit_prior': False, 'max_features': 83316, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5801526717557252
# Params testing:
# {'alpha': 0.35634204649415496, 'fit_prior': True, 'max_features': 88612, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.42313694908135274, 'fit_prior': True, 'max_features': 358969, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3386370994766249, 'fit_prior': True, 'max_features': 373612, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.38124265096791465, 'fit_prior': True, 'max_features': 90498, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.37727478237711803, 'fit_prior': True, 'max_features': 69665, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3039068369678519, 'fit_prior': True, 'max_features': 499167, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.32158029157032186, 'fit_prior': True, 'max_features': 426438, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.35034504204135825, 'fit_prior': True, 'max_features': 165928, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.26850877497911174, 'fit_prior': True, 'max_features': 269408, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.5027608517638193, 'fit_prior': True, 'max_features': 143586, 'vectorizer': 'count'}
# DONE!      F1 = 0.6355140186915889
# Params testing:
# {'alpha': 0.44545055689478535, 'fit_prior': False, 'max_features': 480047, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5739130434782609
# Params testing:
# {'alpha': 0.3603251462107013, 'fit_prior': True, 'max_features': 53313, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.38948587918966077, 'fit_prior': True, 'max_features': 54181, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.3298696216672025, 'fit_prior': True, 'max_features': 125648, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.4646465376257463, 'fit_prior': True, 'max_features': 109814, 'vectorizer': 'count'}
# DONE!      F1 = 0.6605504587155963
# Params testing:
# {'alpha': 0.3642135241260425, 'fit_prior': True, 'max_features': 161674, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.29989045316086116, 'fit_prior': True, 'max_features': 317101, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.33679099988689776, 'fit_prior': True, 'max_features': 164261, 'vectorizer': 'count'}
# DONE!      F1 = 0.6607142857142858
# Params testing:
# {'alpha': 0.2796167263379766, 'fit_prior': True, 'max_features': 168879, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666665
# Params testing:
# {'alpha': 0.40097747884513624, 'fit_prior': True, 'max_features': 50735, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.42025488829528346, 'fit_prior': True, 'max_features': 84552, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.36697286434740056, 'fit_prior': False, 'max_features': 64615, 'vectorizer': 'count'}
# DONE!      F1 = 0.52
# Params testing:
# {'alpha': 0.47454719401949147, 'fit_prior': True, 'max_features': 102727, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.07017543859649122
# Params testing:
# {'alpha': 0.3477171012061697, 'fit_prior': True, 'max_features': 61727, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.31571195550955017, 'fit_prior': True, 'max_features': 378383, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.43065210286143574, 'fit_prior': True, 'max_features': 73644, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.4049271798421279, 'fit_prior': True, 'max_features': 79097, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.3851952549958147, 'fit_prior': True, 'max_features': 94445, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.41059657635545077, 'fit_prior': True, 'max_features': 96619, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.41910880998166933, 'fit_prior': True, 'max_features': 68745, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3782659538697474, 'fit_prior': False, 'max_features': 66932, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5714285714285714
# Params testing:
# {'alpha': 0.43845203847212566, 'fit_prior': True, 'max_features': 240631, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.39587026769945866, 'fit_prior': True, 'max_features': 263427, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.45833596318074876, 'fit_prior': True, 'max_features': 187949, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.3719974567736967, 'fit_prior': True, 'max_features': 393933, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.6893985573012386, 'fit_prior': True, 'max_features': 387818, 'vectorizer': 'count'}
# DONE!      F1 = 0.5979381443298969
# Params testing:
# {'alpha': 0.4007443752379494, 'fit_prior': True, 'max_features': 225093, 'vectorizer': 'count'}
# DONE!      F1 = 0.6666666666666666
# Params testing:
# {'alpha': 0.29136259645748314, 'fit_prior': True, 'max_features': 340343, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.32881310390596347, 'fit_prior': True, 'max_features': 431784, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.44467937935440666, 'fit_prior': False, 'max_features': 315308, 'vectorizer': 'tfidf'}
# DONE!      F1 = 0.5739130434782609
# Params testing:
# {'alpha': 0.31067618414055903, 'fit_prior': True, 'max_features': 114122, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# Params testing:
# {'alpha': 0.38021902812152186, 'fit_prior': True, 'max_features': 65610, 'vectorizer': 'count'}
# DONE!      F1 = 0.6785714285714286
# Params testing:
# {'alpha': 0.427580014354611, 'fit_prior': True, 'max_features': 494791, 'vectorizer': 'count'}
# DONE!      F1 = 0.6545454545454545
# Params testing:
# {'alpha': 0.34483609566635715, 'fit_prior': True, 'max_features': 265827, 'vectorizer': 'count'}
# DONE!      F1 = 0.6725663716814159
# 100%|██████████| 1000/1000.0 [03:41<00:00,  4.51it/s, best loss: -0.6785714285714286]
# Best hyperparams:  {'alpha': 0.38574010499969064, 'fit_prior': 0, 'max_features': 235808.0, 'vectorizer': 1}
