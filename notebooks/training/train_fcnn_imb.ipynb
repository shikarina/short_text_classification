# %% [markdown]
# # Train the FCNN classifier
#
# Training of the **fully-connected neural network classifier** for producing results with various **degrees of dataset imbalance**. The trained model is further saved to reproduce the results for testing.

# %% [markdown]
# ## Import useful packages

# %%
# Generic packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy

# %%
# Sci-kit learn for machine learning tasks
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, roc_curve, auc, f1_score, make_scorer

# %%
# TensorFlow and Keras for neural networks
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.models import Sequential
from keras import layers
from keras.layers.wrappers import Bidirectional
from keras.regularizers import l2
from keras import metrics
from tensorflow.keras.optimizers import Adam

# %%
# NLTK for natural language processing
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Custom helper-functions script (supplied to Colab manually)
import utils as uu

# %% [markdown]
# ## Define the neural architecture

# %% [markdown]
# Best hyperparams:  {'batch_size': 30.0, 'dropout_rate': 0.3312500326531685, 'embedding_dim': 184.0, 'epochs': 99.0, 'kernel_size': 11.0, 'l2_val': 2.86715299646219e-05, 'learning_rate': 1.553281918810298e-05, 'n_filters': 44.0}

# %% [markdown]
# Best hyperparams:  {'batch_size': 26.0, 'dropout_rate': 0.412649987050131, 'embedding_dim': 173.0, 'epochs': 99.0, 'l2_val': 1.1319794133260141e-05, 'learning_rate': 1.935639771089876e-05, 'n_units': 184.0}

# %%
# Set parameters tuned beforehand via Bayesian optimization
params = {'batch_size':     26,
          'dropout_rate':   0.412649987050131,
          'embedding_dim':  173,
          'epochs':         99,
          'l2_val':         1.1319794133260141e-05,
          'learning_rate':  1.935639771089876e-05,
          'max_words':      5000,
          'max_len':        55,
          'n_units':        184
          }

# %%
# Define the neural model
def create_model(params, word_index):
    
    # Define optimizer
    opt = Adam(learning_rate=params['learning_rate'], 
               beta_1 = 0.9,
               beta_2 = 0.99,
               epsilon = 1e-07,
               amsgrad = False)

    # Define sequential neural arhitecture
    model = Sequential()
    model.add(layers.Embedding(params['max_words'], params['embedding_dim'], input_length=params['max_len']))
    model.add(layers.Dropout(params['dropout_rate']))
    model.add(layers.Dense(units=params['n_units'], input_dim=params['embedding_dim'], kernel_initializer='glorot_uniform', activation='relu', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))
    model.add(layers.Flatten())
    model.add(layers.Dense(1, input_dim=params['n_units'], kernel_initializer='glorot_uniform', activation='sigmoid', kernel_regularizer=l2(params['l2_val']), bias_regularizer=l2(params['l2_val'])))

    # Build model
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=[metrics.AUC(name='auc_pr', curve="PR")])
    #model.compile(loss=[uu.focal_loss], optimizer=opt, metrics=[metrics.AUC(name='auc_pr', curve="PR")])
    model.summary()

    return model

# %% [markdown]
# ## Load the datasets

# %%
# Set file names
train_set_file  = "train_set_imb_4.csv"
test_set_file   = "test_set_imb_4.csv"
model_file      = "model_fcnn_imb_4.h5"

# %%
# Read train and test sets as dataframes
train_set = pd.read_csv(train_set_file)
test_set = pd.read_csv(test_set_file)

# %%
# Preprocess texts
train_set['text'] = train_set['text'].apply(str)
train_set['text'] = train_set['text'].apply(uu.preprocess_text)
test_set['text'] = test_set['text'].apply(str)
test_set['text'] = test_set['text'].apply(uu.preprocess_text)

# %%
# Decouple texts and labels (deep copy to not modfy the original datasets accidentally)
texts_train = copy.deepcopy(train_set['text'])
labels_train = copy.deepcopy(train_set['is_about_cc'])
texts_test = copy.deepcopy(test_set['text'])
labels_test = copy.deepcopy(test_set['is_about_cc'])

# %%
# Show the test obtained set fraction (should be 15%)
share_test = len(labels_test)/(len(labels_train)+len(labels_test))
print(share_test)
# Out:
# 0.15

# %% [markdown]
# ## Create features and fit the model

# %%
# Tokenize texts and get features
tokenizer = Tokenizer(num_words=params['max_words'])
tokenizer.fit_on_texts(texts_train)
sequences_train = tokenizer.texts_to_sequences(texts_train)
features_train = sequence.pad_sequences(sequences_train, maxlen=params['max_len'], padding='post', truncating='post')
sequences_test = tokenizer.texts_to_sequences(texts_test)
features_test = sequence.pad_sequences(sequences_test, maxlen=params['max_len'], padding='post', truncating='post')
word_index = tokenizer.word_index

# %%
# Create the model
model = create_model(params, word_index=tokenizer.word_index)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 55, 173)           865000
#
#  dropout_4 (Dropout)         (None, 55, 173)           0
#
#  dense_8 (Dense)             (None, 55, 184)           32016
#
#  flatten_4 (Flatten)         (None, 10120)             0
#
#  dense_9 (Dense)             (None, 1)                 10121
#
# =================================================================
# Total params: 907,137
# Trainable params: 907,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compute class weights for compensation the imbalance in classes
class_weights = class_weight.compute_class_weight(class_weight = "balanced", classes = np.unique(labels_train), y = labels_train)
class_weights = dict(zip(np.unique(labels_train), class_weights))
print(class_weights)
# Out:
# {0: 1.0, 1: 1.0}

# %%
# Fit the model
history = model.fit(features_train, labels_train, 
                    epochs=params['epochs'], 
                    verbose=True, 
                    batch_size=params['batch_size'], 
                    class_weight=class_weights)
# Out:
# Epoch 1/99
# 348/348 [==============================] - 4s 7ms/step - loss: 0.6942 - auc_pr: 0.5421
# Epoch 2/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.6910 - auc_pr: 0.6592
# Epoch 3/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.6854 - auc_pr: 0.8386
# Epoch 4/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.6745 - auc_pr: 0.9440
# Epoch 5/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.6532 - auc_pr: 0.9751
# Epoch 6/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.6138 - auc_pr: 0.9839
# Epoch 7/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.5513 - auc_pr: 0.9858
# Epoch 8/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.4654 - auc_pr: 0.9882
# Epoch 9/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.3680 - auc_pr: 0.9885
# Epoch 10/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.2775 - auc_pr: 0.9902
# Epoch 11/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.2074 - auc_pr: 0.9905
# Epoch 12/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.1628 - auc_pr: 0.9916
# Epoch 13/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.1374 - auc_pr: 0.9923
# Epoch 14/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.1228 - auc_pr: 0.9927
# Epoch 15/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.1135 - auc_pr: 0.9932
# Epoch 16/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.1072 - auc_pr: 0.9937
# Epoch 17/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.1024 - auc_pr: 0.9942
# Epoch 18/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0990 - auc_pr: 0.9945
# Epoch 19/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0936 - auc_pr: 0.9951
# Epoch 20/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0903 - auc_pr: 0.9955
# Epoch 21/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0881 - auc_pr: 0.9955
# Epoch 22/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0840 - auc_pr: 0.9960
# Epoch 23/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0824 - auc_pr: 0.9961
# Epoch 24/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0784 - auc_pr: 0.9963
# Epoch 25/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0774 - auc_pr: 0.9965
# Epoch 26/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0741 - auc_pr: 0.9967
# Epoch 27/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0717 - auc_pr: 0.9968
# Epoch 28/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0695 - auc_pr: 0.9973
# Epoch 29/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0681 - auc_pr: 0.9971
# Epoch 30/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0652 - auc_pr: 0.9973
# Epoch 31/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0647 - auc_pr: 0.9975
# Epoch 32/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0622 - auc_pr: 0.9975
# Epoch 33/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0613 - auc_pr: 0.9976
# Epoch 34/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0599 - auc_pr: 0.9977
# Epoch 35/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0576 - auc_pr: 0.9979
# Epoch 36/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0564 - auc_pr: 0.9979
# Epoch 37/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0552 - auc_pr: 0.9982
# Epoch 38/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0542 - auc_pr: 0.9981
# Epoch 39/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0525 - auc_pr: 0.9981
# Epoch 40/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0513 - auc_pr: 0.9982
# Epoch 41/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0513 - auc_pr: 0.9982
# Epoch 42/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0496 - auc_pr: 0.9983
# Epoch 43/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0480 - auc_pr: 0.9984
# Epoch 44/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0478 - auc_pr: 0.9984
# Epoch 45/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0469 - auc_pr: 0.9984
# Epoch 46/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0457 - auc_pr: 0.9985
# Epoch 47/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0446 - auc_pr: 0.9986
# Epoch 48/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0436 - auc_pr: 0.9986
# Epoch 49/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0422 - auc_pr: 0.9987
# Epoch 50/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0425 - auc_pr: 0.9987
# Epoch 51/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0421 - auc_pr: 0.9987
# Epoch 52/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0405 - auc_pr: 0.9987
# Epoch 53/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0397 - auc_pr: 0.9988
# Epoch 54/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0385 - auc_pr: 0.9988
# Epoch 55/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0380 - auc_pr: 0.9988
# Epoch 56/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0371 - auc_pr: 0.9989
# Epoch 57/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0370 - auc_pr: 0.9988
# Epoch 58/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0365 - auc_pr: 0.9989
# Epoch 59/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0354 - auc_pr: 0.9990
# Epoch 60/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0346 - auc_pr: 0.9990
# Epoch 61/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0331 - auc_pr: 0.9991
# Epoch 62/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0338 - auc_pr: 0.9990
# Epoch 63/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0334 - auc_pr: 0.9990
# Epoch 64/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0330 - auc_pr: 0.9990
# Epoch 65/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0320 - auc_pr: 0.9991
# Epoch 66/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0315 - auc_pr: 0.9991
# Epoch 67/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0307 - auc_pr: 0.9991
# Epoch 68/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0312 - auc_pr: 0.9991
# Epoch 69/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0304 - auc_pr: 0.9991
# Epoch 70/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0299 - auc_pr: 0.9991
# Epoch 71/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0283 - auc_pr: 0.9992
# Epoch 72/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0292 - auc_pr: 0.9992
# Epoch 73/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0285 - auc_pr: 0.9992
# Epoch 74/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0275 - auc_pr: 0.9992
# Epoch 75/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0274 - auc_pr: 0.9992
# Epoch 76/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0276 - auc_pr: 0.9992
# Epoch 77/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0272 - auc_pr: 0.9992
# Epoch 78/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0266 - auc_pr: 0.9992
# Epoch 79/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0262 - auc_pr: 0.9992
# Epoch 80/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0255 - auc_pr: 0.9992
# Epoch 81/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0250 - auc_pr: 0.9993
# Epoch 82/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0254 - auc_pr: 0.9992
# Epoch 83/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0243 - auc_pr: 0.9993
# Epoch 84/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0241 - auc_pr: 0.9993
# Epoch 85/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0244 - auc_pr: 0.9993
# Epoch 86/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0239 - auc_pr: 0.9993
# Epoch 87/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0235 - auc_pr: 0.9993
# Epoch 88/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0233 - auc_pr: 0.9993
# Epoch 89/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0227 - auc_pr: 0.9995
# Epoch 90/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0217 - auc_pr: 0.9993
# Epoch 91/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0218 - auc_pr: 0.9993
# Epoch 92/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0220 - auc_pr: 0.9993
# Epoch 93/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0224 - auc_pr: 0.9993
# Epoch 94/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0209 - auc_pr: 0.9996
# Epoch 95/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0212 - auc_pr: 0.9994
# Epoch 96/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0204 - auc_pr: 0.9996
# Epoch 97/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0205 - auc_pr: 0.9996
# Epoch 98/99
# 348/348 [==============================] - 3s 7ms/step - loss: 0.0200 - auc_pr: 0.9994
# Epoch 99/99
# 348/348 [==============================] - 2s 7ms/step - loss: 0.0202 - auc_pr: 0.9993

# %%
# Save the model (needs to be downloaded manyally from Colab)
model.save(model_file)

# %% [markdown]
# ## Test the model for performance

# %%
# Compute PR AUC score (area under the precision-recall curve)
prediction_scores = model.predict(features_test).ravel()
precs, recs = uu.compute_pr(labels_test, prediction_scores)
pr_auc = auc(recs, precs)
pr_auc
# Out:
# 0.9919179847507235

# %%
# Compute F1 score
predicted_labels = (model.predict(features_test) > 0.5).astype(int)
acc, prec, rec, f1 = uu.compute_perf_metrics(labels_test, predicted_labels)
print("f1 = ", f1)
# Out:
# f1 =  0.967741935483871

# %%
# Compute confusion matrix
confusion_mat = confusion_matrix(labels_test, predicted_labels)
print(confusion_mat)
uu.plot_confusion_matrix(confusion_mat, classes=[0, 1], title='Confusion matrix')
# Out:
# [[780  18]
#  [ 33 765]]

# %%
# Plot precision-recall curve
plt.plot(recs, precs, linewidth=1, label=' '.join(['FCNN', '(AUC = %0.2f)' % pr_auc]))
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc="lower left")
